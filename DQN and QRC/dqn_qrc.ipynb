# %%
import numpy as np
import matplotlib.pyplot as plt
import os, shutil
from tqdm import tqdm
from rl_glue import RLGlue

from tbu_gym.tbu_discrete import TruckBackerEnv_D
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# # DQN Agent

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque

class DQNAgent:
    def __init__(self, state_dim, action_dim, lr=1e-5, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, buffer_size=50000, batch_size=64):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size
        self.memory = deque(maxlen=buffer_size)
        # device, not needed, but needed if going on canada compute to specify gpu
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.q_nn = self.build_nn().to(self.device) # build q network
        self.target_net = self.build_nn().to(self.device) # build target network
        self.target_net.load_state_dict(self.q_nn.state_dict()) # make target net same as q net. initialization is random so need this
        self.optimizer = optim.Adam(self.q_nn.parameters(), lr=lr) 
        
    def build_nn(self): # to build the q network, 2 hiddne layer with relu and 128 neuronsin each
        return nn.Sequential(
            nn.Linear(self.state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.action_dim)
        )
    
    def agent_policy(self, state): # act e greedy
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.action_dim) # rand action
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device) # convert state to tensor, then add batch dimension, then move to device
        with torch.no_grad(): # dont calculate gradients, no need
            q_values = self.q_nn(state)
        return q_values.argmax().item()
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done)) # store transition sars, done is if terminal state
    
    def train_with_mem(self): # train with experience from memory using batch size set in agent
        if len(self.memory) < self.batch_size: # if not enought mem, could be changed to use what we have instead of skip
            return
        batch = random.sample(self.memory, self.batch_size) # get batch
        states, actions, rewards, next_states, dones = zip(*batch) # get batch features

        # convert data to tensors which can be used by pytorch
        states = torch.tensor(np.stack(states), dtype=torch.float32).to(self.device) 
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)

        # get current q values from q network
        q_values = self.q_nn(states).gather(1, actions)

        # use the samples from experience batch to calc target network q values
        with torch.no_grad(): # no need to calc gradients for target
            next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]  
        # target = r + gamma * max_a' Q(s', a') * (1 - done)
        target = rewards + self.gamma * next_q_values * (1 - dones)

        # mean squared error 
        errors = target - q_values
        squared_errors = errors ** 2
        mean_squared_error = torch.mean(squared_errors)

        self.optimizer.zero_grad()
        mean_squared_error.backward()
        self.optimizer.step()
 
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay 

    
    def update_target(self): # update target network replacing it with the current q network
        self.target_net.load_state_dict(self.q_nn.state_dict())

# %% [markdown]
# # QRC Agent

# %%
import random
from collections import deque
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

class QRCAgent:
    def __init__(
        self,
        state_dim,
        action_dim,
        lr=1e-3,
        gamma=0.99,
        lam=0.9,                # kept for API compatibility (not used here)
        epsilon=1.0,
        epsilon_decay=0.995,
        min_epsilon=0.01,
        buffer_size=50000,
        batch_size=64,
        beta=1.0,               # regularization strength for h (matches JAX self.beta)
        device=None,
    ):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.lr = lr
        self.gamma = gamma
        self.lam = lam
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.min_epsilon = min_epsilon
        self.batch_size = batch_size
        self.beta = beta

        # Replay memory
        self.memory = deque(maxlen=buffer_size)

        # Device
        self.device = device or (torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu"))

        # Networks
        self.q_net = self.build_nn(output_dim=self.action_dim).to(self.device)
        self.target_net = self.build_nn(output_dim=self.action_dim).to(self.device)
        self.h_net = self.build_nn(output_dim=self.action_dim).to(self.device)

        # init target
        self.target_net.load_state_dict(self.q_net.state_dict())

        # Optimizers
        self.q_optimizer = optim.Adam(self.q_net.parameters(), lr=self.lr)
        self.h_optimizer = optim.Adam(self.h_net.parameters(), lr=self.lr)

        # Steps counter
        self.steps = 0

    def build_nn(self, output_dim):
        """2 hidden layers with 128 neurons each"""
        return nn.Sequential(
            nn.Linear(self.state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )

    def agent_policy(self, state):
        """Epsilon-greedy policy returning an int action"""
        if np.random.rand() < self.epsilon:
            return int(np.random.randint(self.action_dim))
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.q_net(state)
        return int(q_values.argmax(dim=1).item())

    def remember(self, state, action, reward, next_state, done):
        """Store transition tuple"""
        self.memory.append((state, action, reward, next_state, done))

    def train_with_mem(self):
        """Train using experience replay. Returns total loss (q_loss + h_loss) for logging."""
        if len(self.memory) < self.batch_size:
            return 0.0

        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.tensor(np.stack(states), dtype=torch.float32).to(self.device)         # (B, state_dim)
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)     # (B,1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)  # (B,1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)      # (B,1)

        # Current Q for taken actions (B,1)
        q_all = self.q_net(states)                                  # (B, A)
        q_values = q_all.gather(1, actions)                         # (B,1)

        # h-values for taken actions (B,1)
        h_all = self.h_net(states)
        h_values = h_all.gather(1, actions)                         # (B,1)

        # Next-state greedy value (use target_net), detach it
        with torch.no_grad():
            next_q_all = self.target_net(next_states)               # (B,A)
            # greedy next action value: max_a Q'(s', a)
            vtp1 = next_q_all.max(dim=1, keepdim=True)[0]          # (B,1)
            vtp1 = vtp1.detach()

            # Q target (standard Q-learning greedy target)
            target = rewards + self.gamma * vtp1 * (1.0 - dones)   # (B,1)
            target = target.detach()

        # TD error (not detached yet)
        delta = target - q_values                                   # (B,1)

        # Build v_loss and h_loss per-sample exactly like JAX:
        # v_loss_i = 0.5 * delta^2 + gamma * stop_gradient(delta_hat) * vtp1
        # h_loss_i = 0.5 * (stop_gradient(delta) - delta_hat)^2
        v_loss_terms = 0.5 * (delta ** 2) + self.gamma * h_values.detach() * vtp1
        h_loss_terms = 0.5 * (delta.detach() - h_values) ** 2

        v_loss = v_loss_terms.mean()
        h_loss = h_loss_terms.mean()

        # --- Update Q-network (q_net) ---
        self.q_optimizer.zero_grad()
        v_loss.backward(retain_graph=True)   # retain_graph because h_loss backward next might need graph if shared (here nets separate so optional)
        self.q_optimizer.step()

        # --- Update h-network (h_net) ---
        self.h_optimizer.zero_grad()
        h_loss.backward()
        self.h_optimizer.step()

        # --- Apply explicit decay / regularization on h parameters (beta term) ---
        # This approximates: params_h <- params_h - stepsize * beta * params_h
        # i.e. multiplicative shrinkage: p *= (1 - lr * beta)
        if self.beta != 0.0:
            decay_factor = 1.0 - (self.lr * self.beta)
            # clamp decay_factor to a sensible positive number
            decay_factor = max(decay_factor, 0.0)
            with torch.no_grad():
                for p in self.h_net.parameters():
                    p.mul_(decay_factor)

        # Decay epsilon
        if self.epsilon > self.min_epsilon:
            self.epsilon *= self.epsilon_decay
            if self.epsilon < self.min_epsilon:
                self.epsilon = self.min_epsilon

        total_loss = v_loss.item() + h_loss.item()
        return total_loss

    def update_target(self):
        """Hard update target network weights from q_net"""
        self.target_net.load_state_dict(self.q_net.state_dict())

# %% [markdown]
# # Common Hyperparameters

# %%
num_episodes = 1000
max_steps_per_episode = 500
gamma = 0.99
learning_rate = 1e-3
epsilon_start = 1.0
epsilon_decay = 0.99997
epsilon_min = 0.01
batch_size = 64
target_update_freq = 10

num_runs = 20  # number of independent simulations


# env = TruckBackerEnv_D(render_mode=None)
# state_dim = env.observation_space.shape[0]
# action_dim = env.action_space.n

# %% [markdown]
# # DQN Testing

# %%
#hyper params, these are set by default in the agent but can be changed here
# num_episodes = 1000
# max_steps_per_episode = 500
# gamma = 0.99
# learning_rate = 1e-3
# epsilon_start = 1.0
# epsilon_decay = 0.99997
# epsilon_min = 0.01
# batch_size = 64
# target_update_freq = 5

#agent env setup
env = TruckBackerEnv_D(render_mode=None)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

agent = DQNAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    lr=learning_rate,
    gamma=gamma,
    epsilon=epsilon_start,
    epsilon_decay=epsilon_decay,
    epsilon_min=epsilon_min,
    batch_size=batch_size
)

#training
episode_rewards_dqn = []

for episode in range(1, num_episodes + 1):
    state = env.reset()
    total_reward = 0

    for t in range(max_steps_per_episode):
  
        action = agent.agent_policy(state) # e greedy action
  
        # step env
        next_state, reward, done, info = env.step(action) # do a observe s',r and if terminal
        total_reward += reward

        #store transition in memory
        agent.remember(state, action, reward, next_state, done) # set s' = s a r and if terminal

        # train agent with memory, will train with batch size set in agent
        agent.train_with_mem() 

        state = next_state #s = s'

        if done: # if terminal state
            break


    if episode % target_update_freq == 0:
        agent.update_target()

    episode_rewards_dqn.append(total_reward)
    
    print(f"Episode {episode}, Reward: {total_reward}, Epsilon: {agent.epsilon:.3f}")
# Out:
# Episode 1, Reward: -300, Epsilon: 0.993
# Episode 2, Reward: -300, Epsilon: 0.984
# Episode 3, Reward: -300, Epsilon: 0.975
# Episode 4, Reward: -300, Epsilon: 0.966
# Episode 5, Reward: -300, Epsilon: 0.958
# Episode 6, Reward: -300, Epsilon: 0.949
# Episode 7, Reward: -300, Epsilon: 0.941
# Episode 8, Reward: -300, Epsilon: 0.932
# Episode 9, Reward: -300, Epsilon: 0.924
# Episode 10, Reward: -300, Epsilon: 0.916
# Episode 11, Reward: -300, Epsilon: 0.907
# Episode 12, Reward: -300, Epsilon: 0.899
# Episode 13, Reward: -300, Epsilon: 0.891
# Episode 14, Reward: -300, Epsilon: 0.883
# Episode 15, Reward: -300, Epsilon: 0.875
# Episode 16, Reward: -300, Epsilon: 0.868
# Episode 17, Reward: -300, Epsilon: 0.860
# Episode 18, Reward: -300, Epsilon: 0.852
# Episode 19, Reward: -300, Epsilon: 0.844
# Episode 20, Reward: -300, Epsilon: 0.837
# Episode 21, Reward: -300, Epsilon: 0.829
# Episode 22, Reward: -300, Epsilon: 0.822
# Episode 23, Reward: -300, Epsilon: 0.815
# Episode 24, Reward: -300, Epsilon: 0.807
# Episode 25, Reward: -300, Epsilon: 0.800
# Episode 26, Reward: -300, Epsilon: 0.793
# Episode 27, Reward: -300, Epsilon: 0.786
# Episode 28, Reward: -300, Epsilon: 0.779
# Episode 29, Reward: -300, Epsilon: 0.772
# Episode 30, Reward: -300, Epsilon: 0.765
# Episode 31, Reward: -300, Epsilon: 0.758
# Episode 32, Reward: -300, Epsilon: 0.751
# Episode 33, Reward: -300, Epsilon: 0.744
# Episode 34, Reward: -300, Epsilon: 0.738
# Episode 35, Reward: -300, Epsilon: 0.731
# Episode 36, Reward: -300, Epsilon: 0.725
# Episode 37, Reward: -300, Epsilon: 0.718
# Episode 38, Reward: -300, Epsilon: 0.712
# Episode 39, Reward: -300, Epsilon: 0.705
# Episode 40, Reward: -300, Epsilon: 0.699
# Episode 41, Reward: -300, Epsilon: 0.693
# Episode 42, Reward: -300, Epsilon: 0.687
# Episode 43, Reward: -300, Epsilon: 0.680
# Episode 44, Reward: -300, Epsilon: 0.674
# Episode 45, Reward: -300, Epsilon: 0.668
# Episode 46, Reward: -300, Epsilon: 0.662
# Episode 47, Reward: -300, Epsilon: 0.656
# Episode 48, Reward: -300, Epsilon: 0.650
# Episode 49, Reward: -300, Epsilon: 0.645
# Episode 50, Reward: -300, Epsilon: 0.639
# Episode 51, Reward: -300, Epsilon: 0.633
# Episode 52, Reward: -300, Epsilon: 0.627
# Episode 53, Reward: -300, Epsilon: 0.622
# Episode 54, Reward: -300, Epsilon: 0.616
# Episode 55, Reward: -300, Epsilon: 0.611
# Episode 56, Reward: -300, Epsilon: 0.605
# Episode 57, Reward: -300, Epsilon: 0.600
# Episode 58, Reward: -300, Epsilon: 0.594
# Episode 59, Reward: -300, Epsilon: 0.589
# Episode 60, Reward: -300, Epsilon: 0.584
# Episode 61, Reward: -300, Epsilon: 0.579
# Episode 62, Reward: -300, Epsilon: 0.573
# Episode 63, Reward: -300, Epsilon: 0.568
# Episode 64, Reward: -300, Epsilon: 0.563
# Episode 65, Reward: -300, Epsilon: 0.558
# Episode 66, Reward: -300, Epsilon: 0.553
# Episode 67, Reward: -300, Epsilon: 0.548
# Episode 68, Reward: -300, Epsilon: 0.543
# Episode 69, Reward: -300, Epsilon: 0.538
# Episode 70, Reward: -300, Epsilon: 0.534
# Episode 71, Reward: -300, Epsilon: 0.529
# Episode 72, Reward: -300, Epsilon: 0.524
# Episode 73, Reward: -300, Epsilon: 0.519
# Episode 74, Reward: -300, Epsilon: 0.515
# Episode 75, Reward: -300, Epsilon: 0.510
# Episode 76, Reward: -300, Epsilon: 0.506
# Episode 77, Reward: -300, Epsilon: 0.501
# Episode 78, Reward: -300, Epsilon: 0.497
# Episode 79, Reward: -300, Epsilon: 0.492
# Episode 80, Reward: -300, Epsilon: 0.488
# Episode 81, Reward: -300, Epsilon: 0.483
# Episode 82, Reward: -300, Epsilon: 0.479
# Episode 83, Reward: -300, Epsilon: 0.475
# Episode 84, Reward: -300, Epsilon: 0.470
# Episode 85, Reward: -300, Epsilon: 0.466
# Episode 86, Reward: -300, Epsilon: 0.462
# Episode 87, Reward: -300, Epsilon: 0.458
# Episode 88, Reward: -300, Epsilon: 0.454
# Episode 89, Reward: -300, Epsilon: 0.450
# Episode 90, Reward: -300, Epsilon: 0.446
# Episode 91, Reward: -300, Epsilon: 0.442
# Episode 92, Reward: -300, Epsilon: 0.438
# Episode 93, Reward: -300, Epsilon: 0.434
# Episode 94, Reward: -300, Epsilon: 0.430
# Episode 95, Reward: -300, Epsilon: 0.426
# Episode 96, Reward: -300, Epsilon: 0.422
# Episode 97, Reward: -300, Epsilon: 0.418
# Episode 98, Reward: -300, Epsilon: 0.415
# Episode 99, Reward: 50, Epsilon: 0.414
# Episode 100, Reward: -300, Epsilon: 0.410
# Episode 101, Reward: -300, Epsilon: 0.407
# Episode 102, Reward: -300, Epsilon: 0.403
# Episode 103, Reward: -300, Epsilon: 0.399
# Episode 104, Reward: -300, Epsilon: 0.396
# Episode 105, Reward: -300, Epsilon: 0.392
# Episode 106, Reward: -300, Epsilon: 0.389
# Episode 107, Reward: -300, Epsilon: 0.385
# Episode 108, Reward: -300, Epsilon: 0.382
# Episode 109, Reward: -300, Epsilon: 0.378
# Episode 110, Reward: -300, Epsilon: 0.375
# Episode 111, Reward: -300, Epsilon: 0.372
# Episode 112, Reward: -300, Epsilon: 0.368
# Episode 113, Reward: -300, Epsilon: 0.365
# Episode 114, Reward: -300, Epsilon: 0.362
# Episode 115, Reward: -300, Epsilon: 0.359
# Episode 116, Reward: -300, Epsilon: 0.355
# Episode 117, Reward: -300, Epsilon: 0.352
# Episode 118, Reward: -300, Epsilon: 0.349
# Episode 119, Reward: -300, Epsilon: 0.346
# Episode 120, Reward: -300, Epsilon: 0.343
# Episode 121, Reward: -300, Epsilon: 0.340
# Episode 122, Reward: -300, Epsilon: 0.337
# Episode 123, Reward: -300, Epsilon: 0.334
# Episode 124, Reward: -300, Epsilon: 0.331
# Episode 125, Reward: -300, Epsilon: 0.328
# Episode 126, Reward: -300, Epsilon: 0.325
# Episode 127, Reward: -300, Epsilon: 0.322
# Episode 128, Reward: -300, Epsilon: 0.319
# Episode 129, Reward: -300, Epsilon: 0.316
# Episode 130, Reward: -300, Epsilon: 0.313
# Episode 131, Reward: -300, Epsilon: 0.310
# Episode 132, Reward: -300, Epsilon: 0.308
# Episode 133, Reward: -300, Epsilon: 0.305
# Episode 134, Reward: -300, Epsilon: 0.302
# Episode 135, Reward: -300, Epsilon: 0.299
# Episode 136, Reward: -300, Epsilon: 0.297
# Episode 137, Reward: -300, Epsilon: 0.294
# Episode 138, Reward: -300, Epsilon: 0.292
# Episode 139, Reward: -300, Epsilon: 0.289
# Episode 140, Reward: -300, Epsilon: 0.286
# Episode 141, Reward: -300, Epsilon: 0.284
# Episode 142, Reward: -300, Epsilon: 0.281
# Episode 143, Reward: -300, Epsilon: 0.279
# Episode 144, Reward: -300, Epsilon: 0.276
# Episode 145, Reward: -300, Epsilon: 0.274
# Episode 146, Reward: -300, Epsilon: 0.271
# Episode 147, Reward: -300, Epsilon: 0.269
# Episode 148, Reward: -300, Epsilon: 0.266
# Episode 149, Reward: -300, Epsilon: 0.264
# Episode 150, Reward: -300, Epsilon: 0.262
# Episode 151, Reward: -300, Epsilon: 0.259
# Episode 152, Reward: -300, Epsilon: 0.257
# Episode 153, Reward: -300, Epsilon: 0.255
# Episode 154, Reward: -300, Epsilon: 0.252
# Episode 155, Reward: -300, Epsilon: 0.250
# Episode 156, Reward: -300, Epsilon: 0.248
# Episode 157, Reward: -300, Epsilon: 0.246
# Episode 158, Reward: -300, Epsilon: 0.243
# Episode 159, Reward: -300, Epsilon: 0.241
# Episode 160, Reward: -300, Epsilon: 0.239
# Episode 161, Reward: -300, Epsilon: 0.237
# Episode 162, Reward: -300, Epsilon: 0.235
# Episode 163, Reward: -300, Epsilon: 0.233
# Episode 164, Reward: -300, Epsilon: 0.231
# Episode 165, Reward: -300, Epsilon: 0.229
# Episode 166, Reward: -300, Epsilon: 0.227
# Episode 167, Reward: -300, Epsilon: 0.225
# Episode 168, Reward: -300, Epsilon: 0.223
# Episode 169, Reward: -300, Epsilon: 0.221
# Episode 170, Reward: -300, Epsilon: 0.219
# Episode 171, Reward: -300, Epsilon: 0.217
# Episode 172, Reward: -300, Epsilon: 0.215
# Episode 173, Reward: -300, Epsilon: 0.213
# Episode 174, Reward: -300, Epsilon: 0.211
# Episode 175, Reward: -300, Epsilon: 0.209
# Episode 176, Reward: -300, Epsilon: 0.207
# Episode 177, Reward: -300, Epsilon: 0.205
# Episode 178, Reward: -300, Epsilon: 0.203
# Episode 179, Reward: -300, Epsilon: 0.202
# Episode 180, Reward: -300, Epsilon: 0.200
# Episode 181, Reward: -9, Epsilon: 0.199
# Episode 182, Reward: -300, Epsilon: 0.197
# Episode 183, Reward: -300, Epsilon: 0.196
# Episode 184, Reward: -300, Epsilon: 0.194
# Episode 185, Reward: -300, Epsilon: 0.192
# Episode 186, Reward: -300, Epsilon: 0.190
# Episode 187, Reward: -300, Epsilon: 0.189
# Episode 188, Reward: -300, Epsilon: 0.187
# Episode 189, Reward: -300, Epsilon: 0.185
# Episode 190, Reward: -300, Epsilon: 0.184
# Episode 191, Reward: -300, Epsilon: 0.182
# Episode 192, Reward: -300, Epsilon: 0.180
# Episode 193, Reward: -300, Epsilon: 0.179
# Episode 194, Reward: -300, Epsilon: 0.177
# Episode 195, Reward: -300, Epsilon: 0.176
# Episode 196, Reward: -300, Epsilon: 0.174
# Episode 197, Reward: -300, Epsilon: 0.172
# Episode 198, Reward: -300, Epsilon: 0.171
# Episode 199, Reward: -300, Epsilon: 0.169
# Episode 200, Reward: -300, Epsilon: 0.168
# Episode 201, Reward: -300, Epsilon: 0.166
# Episode 202, Reward: -300, Epsilon: 0.165
# Episode 203, Reward: -300, Epsilon: 0.163
# Episode 204, Reward: -300, Epsilon: 0.162
# Episode 205, Reward: -300, Epsilon: 0.160
# Episode 206, Reward: -300, Epsilon: 0.159
# Episode 207, Reward: -300, Epsilon: 0.158
# Episode 208, Reward: -300, Epsilon: 0.156
# Episode 209, Reward: -300, Epsilon: 0.155
# Episode 210, Reward: -300, Epsilon: 0.153
# Episode 211, Reward: -300, Epsilon: 0.152
# Episode 212, Reward: -300, Epsilon: 0.151
# Episode 213, Reward: -300, Epsilon: 0.149
# Episode 214, Reward: -300, Epsilon: 0.148
# Episode 215, Reward: -300, Epsilon: 0.147
# Episode 216, Reward: -300, Epsilon: 0.145
# Episode 217, Reward: -300, Epsilon: 0.144
# Episode 218, Reward: -300, Epsilon: 0.143
# Episode 219, Reward: -300, Epsilon: 0.141
# Episode 220, Reward: -300, Epsilon: 0.140
# Episode 221, Reward: -300, Epsilon: 0.139
# Episode 222, Reward: -300, Epsilon: 0.138
# Episode 223, Reward: -300, Epsilon: 0.136
# Episode 224, Reward: -300, Epsilon: 0.135
# Episode 225, Reward: -300, Epsilon: 0.134
# Episode 226, Reward: -300, Epsilon: 0.133
# Episode 227, Reward: -300, Epsilon: 0.132
# Episode 228, Reward: -300, Epsilon: 0.130
# Episode 229, Reward: -300, Epsilon: 0.129
# Episode 230, Reward: -300, Epsilon: 0.128
# Episode 231, Reward: -300, Epsilon: 0.127
# Episode 232, Reward: -300, Epsilon: 0.126
# Episode 233, Reward: -300, Epsilon: 0.125
# Episode 234, Reward: -300, Epsilon: 0.124
# Episode 235, Reward: -300, Epsilon: 0.122
# Episode 236, Reward: -300, Epsilon: 0.121
# Episode 237, Reward: -300, Epsilon: 0.120
# Episode 238, Reward: -300, Epsilon: 0.119
# Episode 239, Reward: -300, Epsilon: 0.118
# Episode 240, Reward: -300, Epsilon: 0.117
# Episode 241, Reward: -300, Epsilon: 0.116
# Episode 242, Reward: -300, Epsilon: 0.115
# Episode 243, Reward: -300, Epsilon: 0.114
# Episode 244, Reward: -300, Epsilon: 0.113
# Episode 245, Reward: -300, Epsilon: 0.112
# Episode 246, Reward: -300, Epsilon: 0.111
# Episode 247, Reward: -300, Epsilon: 0.110
# Episode 248, Reward: -300, Epsilon: 0.109
# Episode 249, Reward: -300, Epsilon: 0.108
# Episode 250, Reward: -300, Epsilon: 0.107
# Episode 251, Reward: -300, Epsilon: 0.106
# Episode 252, Reward: -300, Epsilon: 0.105
# Episode 253, Reward: -300, Epsilon: 0.104
# Episode 254, Reward: -300, Epsilon: 0.103
# Episode 255, Reward: -300, Epsilon: 0.102
# Episode 256, Reward: -300, Epsilon: 0.101
# Episode 257, Reward: -300, Epsilon: 0.100
# Episode 258, Reward: -300, Epsilon: 0.100
# Episode 259, Reward: -300, Epsilon: 0.099
# Episode 260, Reward: -300, Epsilon: 0.098
# Episode 261, Reward: -300, Epsilon: 0.097
# Episode 262, Reward: -300, Epsilon: 0.096
# Episode 263, Reward: -300, Epsilon: 0.095
# Episode 264, Reward: -300, Epsilon: 0.094
# Episode 265, Reward: -300, Epsilon: 0.093
# Episode 266, Reward: -300, Epsilon: 0.093
# Episode 267, Reward: -300, Epsilon: 0.092
# Episode 268, Reward: -300, Epsilon: 0.091
# Episode 269, Reward: -300, Epsilon: 0.090
# Episode 270, Reward: -300, Epsilon: 0.089
# Episode 271, Reward: -300, Epsilon: 0.089
# Episode 272, Reward: -300, Epsilon: 0.088
# Episode 273, Reward: -300, Epsilon: 0.087
# Episode 274, Reward: -300, Epsilon: 0.086
# Episode 275, Reward: -300, Epsilon: 0.085
# Episode 276, Reward: -300, Epsilon: 0.085
# Episode 277, Reward: -300, Epsilon: 0.084
# Episode 278, Reward: -300, Epsilon: 0.083
# Episode 279, Reward: -300, Epsilon: 0.082
# Episode 280, Reward: -300, Epsilon: 0.082
# Episode 281, Reward: -300, Epsilon: 0.081
# Episode 282, Reward: -300, Epsilon: 0.080
# Episode 283, Reward: -300, Epsilon: 0.080
# Episode 284, Reward: -300, Epsilon: 0.079
# Episode 285, Reward: -300, Epsilon: 0.078
# Episode 286, Reward: -300, Epsilon: 0.077
# Episode 287, Reward: -300, Epsilon: 0.077
# Episode 288, Reward: -300, Epsilon: 0.076
# Episode 289, Reward: -300, Epsilon: 0.075
# Episode 290, Reward: -300, Epsilon: 0.075
# Episode 291, Reward: -300, Epsilon: 0.074
# Episode 292, Reward: -300, Epsilon: 0.073
# Episode 293, Reward: -300, Epsilon: 0.073
# Episode 294, Reward: -159, Epsilon: 0.072
# Episode 295, Reward: -300, Epsilon: 0.071
# Episode 296, Reward: -40, Epsilon: 0.071
# Episode 297, Reward: -300, Epsilon: 0.071
# Episode 298, Reward: -300, Epsilon: 0.070
# Episode 299, Reward: -300, Epsilon: 0.069
# Episode 300, Reward: -300, Epsilon: 0.069
# Episode 301, Reward: -300, Epsilon: 0.068
# Episode 302, Reward: -300, Epsilon: 0.067
# Episode 303, Reward: -300, Epsilon: 0.067
# Episode 304, Reward: -300, Epsilon: 0.066
# Episode 305, Reward: -300, Epsilon: 0.066
# Episode 306, Reward: -300, Epsilon: 0.065
# Episode 307, Reward: -300, Epsilon: 0.064
# Episode 308, Reward: -300, Epsilon: 0.064
# Episode 309, Reward: -300, Epsilon: 0.063
# Episode 310, Reward: -300, Epsilon: 0.063
# Episode 311, Reward: -300, Epsilon: 0.062
# Episode 312, Reward: -300, Epsilon: 0.062
# Episode 313, Reward: -300, Epsilon: 0.061
# Episode 314, Reward: -300, Epsilon: 0.061
# Episode 315, Reward: -300, Epsilon: 0.060
# Episode 316, Reward: -300, Epsilon: 0.059
# Episode 317, Reward: -300, Epsilon: 0.059
# Episode 318, Reward: -300, Epsilon: 0.058
# Episode 319, Reward: -300, Epsilon: 0.058
# Episode 320, Reward: -300, Epsilon: 0.057
# Episode 321, Reward: -300, Epsilon: 0.057
# Episode 322, Reward: -300, Epsilon: 0.056
# Episode 323, Reward: -300, Epsilon: 0.056
# Episode 324, Reward: -300, Epsilon: 0.055
# Episode 325, Reward: -300, Epsilon: 0.055
# Episode 326, Reward: -300, Epsilon: 0.054
# Episode 327, Reward: -300, Epsilon: 0.054
# Episode 328, Reward: -300, Epsilon: 0.053
# Episode 329, Reward: -300, Epsilon: 0.053
# Episode 330, Reward: -300, Epsilon: 0.052
# Episode 331, Reward: -300, Epsilon: 0.052
# Episode 332, Reward: -300, Epsilon: 0.051
# Episode 333, Reward: -300, Epsilon: 0.051
# Episode 334, Reward: -300, Epsilon: 0.051
# Episode 335, Reward: -300, Epsilon: 0.050
# Episode 336, Reward: -300, Epsilon: 0.050
# Episode 337, Reward: -300, Epsilon: 0.049
# Episode 338, Reward: -300, Epsilon: 0.049
# Episode 339, Reward: -300, Epsilon: 0.048
# Episode 340, Reward: -300, Epsilon: 0.048
# Episode 341, Reward: -86, Epsilon: 0.048
# Episode 342, Reward: -300, Epsilon: 0.047
# Episode 343, Reward: -300, Epsilon: 0.047
# Episode 344, Reward: -300, Epsilon: 0.046
# Episode 345, Reward: -300, Epsilon: 0.046
# Episode 346, Reward: -300, Epsilon: 0.046
# Episode 347, Reward: -300, Epsilon: 0.045
# Episode 348, Reward: -300, Epsilon: 0.045
# Episode 349, Reward: -300, Epsilon: 0.044
# Episode 350, Reward: -300, Epsilon: 0.044
# Episode 351, Reward: -300, Epsilon: 0.044
# Episode 352, Reward: -300, Epsilon: 0.043
# Episode 353, Reward: -300, Epsilon: 0.043
# Episode 354, Reward: -300, Epsilon: 0.042
# Episode 355, Reward: -300, Epsilon: 0.042
# Episode 356, Reward: -300, Epsilon: 0.042
# Episode 357, Reward: -300, Epsilon: 0.041
# Episode 358, Reward: -300, Epsilon: 0.041
# Episode 359, Reward: -300, Epsilon: 0.040
# Episode 360, Reward: -300, Epsilon: 0.040
# Episode 361, Reward: -300, Epsilon: 0.040
# Episode 362, Reward: -300, Epsilon: 0.039
# Episode 363, Reward: -300, Epsilon: 0.039
# Episode 364, Reward: -300, Epsilon: 0.039
# Episode 365, Reward: -300, Epsilon: 0.038
# Episode 366, Reward: -300, Epsilon: 0.038
# Episode 367, Reward: -300, Epsilon: 0.038
# Episode 368, Reward: -300, Epsilon: 0.037
# Episode 369, Reward: -300, Epsilon: 0.037
# Episode 370, Reward: -300, Epsilon: 0.037
# Episode 371, Reward: -300, Epsilon: 0.036
# Episode 372, Reward: -300, Epsilon: 0.036
# Episode 373, Reward: -300, Epsilon: 0.036
# Episode 374, Reward: -300, Epsilon: 0.035
# Episode 375, Reward: -300, Epsilon: 0.035
# Episode 376, Reward: -300, Epsilon: 0.035
# Episode 377, Reward: -300, Epsilon: 0.034
# Episode 378, Reward: -300, Epsilon: 0.034
# Episode 379, Reward: -300, Epsilon: 0.034
# Episode 380, Reward: -300, Epsilon: 0.034
# Episode 381, Reward: -300, Epsilon: 0.033
# Episode 382, Reward: -300, Epsilon: 0.033
# Episode 383, Reward: -300, Epsilon: 0.033
# Episode 384, Reward: -300, Epsilon: 0.032
# Episode 385, Reward: -300, Epsilon: 0.032
# Episode 386, Reward: -300, Epsilon: 0.032
# Episode 387, Reward: -300, Epsilon: 0.031
# Episode 388, Reward: -300, Epsilon: 0.031
# Episode 389, Reward: -300, Epsilon: 0.031
# Episode 390, Reward: -300, Epsilon: 0.031
# Episode 391, Reward: -300, Epsilon: 0.030
# Episode 392, Reward: -300, Epsilon: 0.030
# Episode 393, Reward: -300, Epsilon: 0.030
# Episode 394, Reward: -300, Epsilon: 0.030
# Episode 395, Reward: -300, Epsilon: 0.029
# Episode 396, Reward: -300, Epsilon: 0.029
# Episode 397, Reward: -300, Epsilon: 0.029
# Episode 398, Reward: -300, Epsilon: 0.029
# Episode 399, Reward: -300, Epsilon: 0.028
# Episode 400, Reward: -300, Epsilon: 0.028
# Episode 401, Reward: -300, Epsilon: 0.028
# Episode 402, Reward: -300, Epsilon: 0.027
# Episode 403, Reward: -300, Epsilon: 0.027
# Episode 404, Reward: -300, Epsilon: 0.027
# Episode 405, Reward: -300, Epsilon: 0.027
# Episode 406, Reward: -300, Epsilon: 0.027
# Episode 407, Reward: -300, Epsilon: 0.026
# Episode 408, Reward: -300, Epsilon: 0.026
# Episode 409, Reward: -300, Epsilon: 0.026
# Episode 410, Reward: -300, Epsilon: 0.026
# Episode 411, Reward: -300, Epsilon: 0.025
# Episode 412, Reward: -300, Epsilon: 0.025
# Episode 413, Reward: -300, Epsilon: 0.025
# Episode 414, Reward: -300, Epsilon: 0.025
# Episode 415, Reward: -300, Epsilon: 0.024
# Episode 416, Reward: -300, Epsilon: 0.024
# Episode 417, Reward: -300, Epsilon: 0.024
# Episode 418, Reward: -300, Epsilon: 0.024
# Episode 419, Reward: -300, Epsilon: 0.024
# Episode 420, Reward: -300, Epsilon: 0.023
# Episode 421, Reward: -300, Epsilon: 0.023
# Episode 422, Reward: -300, Epsilon: 0.023
# Episode 423, Reward: -300, Epsilon: 0.023
# Episode 424, Reward: -300, Epsilon: 0.023
# Episode 425, Reward: -300, Epsilon: 0.022
# Episode 426, Reward: -300, Epsilon: 0.022
# Episode 427, Reward: -300, Epsilon: 0.022
# Episode 428, Reward: -300, Epsilon: 0.022
# Episode 429, Reward: -300, Epsilon: 0.022
# Episode 430, Reward: -300, Epsilon: 0.021
# Episode 431, Reward: -300, Epsilon: 0.021
# Episode 432, Reward: 63, Epsilon: 0.021
# Episode 433, Reward: -300, Epsilon: 0.021
# Episode 434, Reward: -300, Epsilon: 0.021
# Episode 435, Reward: -300, Epsilon: 0.021
# Episode 436, Reward: -300, Epsilon: 0.020
# Episode 437, Reward: -300, Epsilon: 0.020
# Episode 438, Reward: -300, Epsilon: 0.020
# Episode 439, Reward: -300, Epsilon: 0.020
# Episode 440, Reward: -300, Epsilon: 0.020
# Episode 441, Reward: -300, Epsilon: 0.020
# Episode 442, Reward: -300, Epsilon: 0.019
# Episode 443, Reward: -300, Epsilon: 0.019
# Episode 444, Reward: -300, Epsilon: 0.019
# Episode 445, Reward: -300, Epsilon: 0.019
# Episode 446, Reward: -45, Epsilon: 0.019
# Episode 447, Reward: -300, Epsilon: 0.019
# Episode 448, Reward: -300, Epsilon: 0.018
# Episode 449, Reward: -2, Epsilon: 0.018
# Episode 450, Reward: -300, Epsilon: 0.018
# Episode 451, Reward: -189, Epsilon: 0.018
# Episode 452, Reward: -300, Epsilon: 0.018
# Episode 453, Reward: -300, Epsilon: 0.018
# Episode 454, Reward: -300, Epsilon: 0.018
# Episode 455, Reward: -300, Epsilon: 0.017
# Episode 456, Reward: -300, Epsilon: 0.017
# Episode 457, Reward: -300, Epsilon: 0.017
# Episode 458, Reward: -300, Epsilon: 0.017
# Episode 459, Reward: -77, Epsilon: 0.017
# Episode 460, Reward: -300, Epsilon: 0.017
# Episode 461, Reward: -84, Epsilon: 0.017
# Episode 462, Reward: -300, Epsilon: 0.016
# Episode 463, Reward: -300, Epsilon: 0.016
# Episode 464, Reward: -300, Epsilon: 0.016
# Episode 465, Reward: -45, Epsilon: 0.016
# Episode 466, Reward: -300, Epsilon: 0.016
# Episode 467, Reward: -93, Epsilon: 0.016
# Episode 468, Reward: -300, Epsilon: 0.016
# Episode 469, Reward: -300, Epsilon: 0.016
# Episode 470, Reward: 29, Epsilon: 0.016
# Episode 471, Reward: 63, Epsilon: 0.016
# Episode 472, Reward: 59, Epsilon: 0.015
# Episode 473, Reward: -54, Epsilon: 0.015
# Episode 474, Reward: -300, Epsilon: 0.015
# Episode 475, Reward: -300, Epsilon: 0.015
# Episode 476, Reward: -30, Epsilon: 0.015
# Episode 477, Reward: -69, Epsilon: 0.015
# Episode 478, Reward: -52, Epsilon: 0.015
# Episode 479, Reward: -7, Epsilon: 0.015
# Episode 480, Reward: -70, Epsilon: 0.015
# Episode 481, Reward: -300, Epsilon: 0.015
# Episode 482, Reward: -41, Epsilon: 0.015
# Episode 483, Reward: -5, Epsilon: 0.015
# Episode 484, Reward: -300, Epsilon: 0.014
# Episode 485, Reward: -300, Epsilon: 0.014
# Episode 486, Reward: -300, Epsilon: 0.014
# Episode 487, Reward: -300, Epsilon: 0.014
# Episode 488, Reward: -300, Epsilon: 0.014
# Episode 489, Reward: -300, Epsilon: 0.014
# Episode 490, Reward: -300, Epsilon: 0.014
# Episode 491, Reward: -195, Epsilon: 0.014
# Episode 492, Reward: -21, Epsilon: 0.014
# Episode 493, Reward: 50, Epsilon: 0.013
# Episode 494, Reward: -197, Epsilon: 0.013
# Episode 495, Reward: -300, Epsilon: 0.013
# Episode 496, Reward: -49, Epsilon: 0.013
# Episode 497, Reward: -300, Epsilon: 0.013
# Episode 498, Reward: -300, Epsilon: 0.013
# Episode 499, Reward: -42, Epsilon: 0.013
# Episode 500, Reward: -300, Epsilon: 0.013
# Episode 501, Reward: -300, Epsilon: 0.013
# Episode 502, Reward: -300, Epsilon: 0.013
# Episode 503, Reward: -300, Epsilon: 0.012
# Episode 504, Reward: -155, Epsilon: 0.012
# Episode 505, Reward: -300, Epsilon: 0.012
# Episode 506, Reward: -300, Epsilon: 0.012
# Episode 507, Reward: -300, Epsilon: 0.012
# Episode 508, Reward: -300, Epsilon: 0.012
# Episode 509, Reward: -300, Epsilon: 0.012
# Episode 510, Reward: -300, Epsilon: 0.012
# Episode 511, Reward: -300, Epsilon: 0.012
# Episode 512, Reward: -300, Epsilon: 0.011
# Episode 513, Reward: -149, Epsilon: 0.011
# Episode 514, Reward: -300, Epsilon: 0.011
# Episode 515, Reward: -300, Epsilon: 0.011
# Episode 516, Reward: -300, Epsilon: 0.011
# Episode 517, Reward: -74, Epsilon: 0.011
# Episode 518, Reward: 1, Epsilon: 0.011
# Episode 519, Reward: 6, Epsilon: 0.011
# Episode 520, Reward: 37, Epsilon: 0.011
# Episode 521, Reward: -78, Epsilon: 0.011
# Episode 522, Reward: 49, Epsilon: 0.011
# Episode 523, Reward: -51, Epsilon: 0.011
# Episode 524, Reward: 45, Epsilon: 0.011
# Episode 525, Reward: -39, Epsilon: 0.011
# Episode 526, Reward: -132, Epsilon: 0.011
# Episode 527, Reward: -188, Epsilon: 0.011
# Episode 528, Reward: -32, Epsilon: 0.011
# Episode 529, Reward: -120, Epsilon: 0.010
# Episode 530, Reward: -300, Epsilon: 0.010
# Episode 531, Reward: -65, Epsilon: 0.010
# Episode 532, Reward: -300, Epsilon: 0.010
# Episode 533, Reward: 52, Epsilon: 0.010
# Episode 534, Reward: -70, Epsilon: 0.010
# Episode 535, Reward: 54, Epsilon: 0.010
# Episode 536, Reward: -300, Epsilon: 0.010
# Episode 537, Reward: 13, Epsilon: 0.010
# Episode 538, Reward: -300, Epsilon: 0.010
# Episode 539, Reward: 58, Epsilon: 0.010
# Episode 540, Reward: -300, Epsilon: 0.010
# Episode 541, Reward: 8, Epsilon: 0.010
# Episode 542, Reward: 36, Epsilon: 0.010
# Episode 543, Reward: -34, Epsilon: 0.010
# Episode 544, Reward: -88, Epsilon: 0.010
# Episode 545, Reward: 38, Epsilon: 0.010
# Episode 546, Reward: -64, Epsilon: 0.010
# Episode 547, Reward: 54, Epsilon: 0.010
# Episode 548, Reward: 41, Epsilon: 0.010
# Episode 549, Reward: -56, Epsilon: 0.010
# Episode 550, Reward: 36, Epsilon: 0.010
# Episode 551, Reward: -47, Epsilon: 0.010
# Episode 552, Reward: -8, Epsilon: 0.010
# Episode 553, Reward: 4, Epsilon: 0.010
# Episode 554, Reward: -44, Epsilon: 0.010
# Episode 555, Reward: 40, Epsilon: 0.010
# Episode 556, Reward: 58, Epsilon: 0.010
# Episode 557, Reward: -28, Epsilon: 0.010
# Episode 558, Reward: 11, Epsilon: 0.010
# Episode 559, Reward: 45, Epsilon: 0.010
# Episode 560, Reward: -44, Epsilon: 0.010
# Episode 561, Reward: 45, Epsilon: 0.010
# Episode 562, Reward: 62, Epsilon: 0.010
# Episode 563, Reward: 62, Epsilon: 0.010
# Episode 564, Reward: 11, Epsilon: 0.010
# Episode 565, Reward: -192, Epsilon: 0.010
# Episode 566, Reward: 41, Epsilon: 0.010
# Episode 567, Reward: 61, Epsilon: 0.010
# Episode 568, Reward: 59, Epsilon: 0.010
# Episode 569, Reward: -5, Epsilon: 0.010
# Episode 570, Reward: -141, Epsilon: 0.010
# Episode 571, Reward: 5, Epsilon: 0.010
# Episode 572, Reward: 60, Epsilon: 0.010
# Episode 573, Reward: 54, Epsilon: 0.010
# Episode 574, Reward: 4, Epsilon: 0.010
# Episode 575, Reward: 50, Epsilon: 0.010
# Episode 576, Reward: 55, Epsilon: 0.010
# Episode 577, Reward: 63, Epsilon: 0.010
# Episode 578, Reward: 64, Epsilon: 0.010
# Episode 579, Reward: 54, Epsilon: 0.010
# Episode 580, Reward: 51, Epsilon: 0.010
# Episode 581, Reward: 54, Epsilon: 0.010
# Episode 582, Reward: 49, Epsilon: 0.010
# Episode 583, Reward: -4, Epsilon: 0.010
# Episode 584, Reward: -54, Epsilon: 0.010
# Episode 585, Reward: 50, Epsilon: 0.010
# Episode 586, Reward: -6, Epsilon: 0.010
# Episode 587, Reward: 50, Epsilon: 0.010
# Episode 588, Reward: -300, Epsilon: 0.010
# Episode 589, Reward: 6, Epsilon: 0.010
# Episode 590, Reward: 12, Epsilon: 0.010
# Episode 591, Reward: 55, Epsilon: 0.010
# Episode 592, Reward: 48, Epsilon: 0.010
# Episode 593, Reward: 67, Epsilon: 0.010
# Episode 594, Reward: 51, Epsilon: 0.010
# Episode 595, Reward: 53, Epsilon: 0.010
# Episode 596, Reward: -90, Epsilon: 0.010
# Episode 597, Reward: 55, Epsilon: 0.010
# Episode 598, Reward: 57, Epsilon: 0.010
# Episode 599, Reward: 51, Epsilon: 0.010
# Episode 600, Reward: 9, Epsilon: 0.010
# Episode 601, Reward: 7, Epsilon: 0.010
# Episode 602, Reward: 47, Epsilon: 0.010
# Episode 603, Reward: 51, Epsilon: 0.010
# Episode 604, Reward: 49, Epsilon: 0.010
# Episode 605, Reward: 48, Epsilon: 0.010
# Episode 606, Reward: 39, Epsilon: 0.010
# Episode 607, Reward: 24, Epsilon: 0.010
# Episode 608, Reward: 54, Epsilon: 0.010
# Episode 609, Reward: 44, Epsilon: 0.010
# Episode 610, Reward: 57, Epsilon: 0.010
# Episode 611, Reward: 5, Epsilon: 0.010
# Episode 612, Reward: 50, Epsilon: 0.010
# Episode 613, Reward: -43, Epsilon: 0.010
# Episode 614, Reward: 34, Epsilon: 0.010
# Episode 615, Reward: 4, Epsilon: 0.010
# Episode 616, Reward: 10, Epsilon: 0.010
# Episode 617, Reward: -188, Epsilon: 0.010
# Episode 618, Reward: 58, Epsilon: 0.010
# Episode 619, Reward: 5, Epsilon: 0.010
# Episode 620, Reward: -129, Epsilon: 0.010
# Episode 621, Reward: 46, Epsilon: 0.010
# Episode 622, Reward: 53, Epsilon: 0.010
# Episode 623, Reward: 56, Epsilon: 0.010
# Episode 624, Reward: 48, Epsilon: 0.010
# Episode 625, Reward: 39, Epsilon: 0.010
# Episode 626, Reward: 51, Epsilon: 0.010
# Episode 627, Reward: 48, Epsilon: 0.010
# Episode 628, Reward: -47, Epsilon: 0.010
# Episode 629, Reward: -136, Epsilon: 0.010
# Episode 630, Reward: 43, Epsilon: 0.010
# Episode 631, Reward: 46, Epsilon: 0.010
# Episode 632, Reward: -170, Epsilon: 0.010
# Episode 633, Reward: 45, Epsilon: 0.010
# Episode 634, Reward: -59, Epsilon: 0.010
# Episode 635, Reward: 58, Epsilon: 0.010
# Episode 636, Reward: 55, Epsilon: 0.010
# Episode 637, Reward: 64, Epsilon: 0.010
# Episode 638, Reward: 59, Epsilon: 0.010
# Episode 639, Reward: 50, Epsilon: 0.010
# Episode 640, Reward: -18, Epsilon: 0.010
# Episode 641, Reward: 53, Epsilon: 0.010
# Episode 642, Reward: 57, Epsilon: 0.010
# Episode 643, Reward: 36, Epsilon: 0.010
# Episode 644, Reward: -110, Epsilon: 0.010
# Episode 645, Reward: 60, Epsilon: 0.010
# Episode 646, Reward: 49, Epsilon: 0.010
# Episode 647, Reward: 21, Epsilon: 0.010
# Episode 648, Reward: 61, Epsilon: 0.010
# Episode 649, Reward: 49, Epsilon: 0.010
# Episode 650, Reward: 5, Epsilon: 0.010
# Episode 651, Reward: -8, Epsilon: 0.010
# Episode 652, Reward: 55, Epsilon: 0.010
# Episode 653, Reward: 50, Epsilon: 0.010
# Episode 654, Reward: 55, Epsilon: 0.010
# Episode 655, Reward: 0, Epsilon: 0.010
# Episode 656, Reward: -25, Epsilon: 0.010
# Episode 657, Reward: 62, Epsilon: 0.010
# Episode 658, Reward: -50, Epsilon: 0.010
# Episode 659, Reward: 49, Epsilon: 0.010
# Episode 660, Reward: 10, Epsilon: 0.010
# Episode 661, Reward: 63, Epsilon: 0.010
# Episode 662, Reward: 53, Epsilon: 0.010
# Episode 663, Reward: 52, Epsilon: 0.010
# Episode 664, Reward: 52, Epsilon: 0.010
# Episode 665, Reward: 52, Epsilon: 0.010
# Episode 666, Reward: -50, Epsilon: 0.010
# Episode 667, Reward: -3, Epsilon: 0.010
# Episode 668, Reward: 39, Epsilon: 0.010
# Episode 669, Reward: 59, Epsilon: 0.010
# Episode 670, Reward: 36, Epsilon: 0.010
# Episode 671, Reward: 7, Epsilon: 0.010
# Episode 672, Reward: 39, Epsilon: 0.010
# Episode 673, Reward: -12, Epsilon: 0.010
# Episode 674, Reward: 59, Epsilon: 0.010
# Episode 675, Reward: 63, Epsilon: 0.010
# Episode 676, Reward: 7, Epsilon: 0.010
# Episode 677, Reward: 51, Epsilon: 0.010
# Episode 678, Reward: 51, Epsilon: 0.010
# Episode 679, Reward: 43, Epsilon: 0.010
# Episode 680, Reward: -64, Epsilon: 0.010
# Episode 681, Reward: 55, Epsilon: 0.010
# Episode 682, Reward: 39, Epsilon: 0.010
# Episode 683, Reward: -6, Epsilon: 0.010
# Episode 684, Reward: 50, Epsilon: 0.010
# Episode 685, Reward: 50, Epsilon: 0.010
# Episode 686, Reward: 57, Epsilon: 0.010
# Episode 687, Reward: 45, Epsilon: 0.010
# Episode 688, Reward: -61, Epsilon: 0.010
# Episode 689, Reward: 61, Epsilon: 0.010
# Episode 690, Reward: 61, Epsilon: 0.010
# Episode 691, Reward: 51, Epsilon: 0.010
# Episode 692, Reward: -2, Epsilon: 0.010
# Episode 693, Reward: 56, Epsilon: 0.010
# Episode 694, Reward: 50, Epsilon: 0.010
# Episode 695, Reward: 43, Epsilon: 0.010
# Episode 696, Reward: 58, Epsilon: 0.010
# Episode 697, Reward: 53, Epsilon: 0.010
# Episode 698, Reward: 46, Epsilon: 0.010
# Episode 699, Reward: 59, Epsilon: 0.010
# Episode 700, Reward: 40, Epsilon: 0.010
# Episode 701, Reward: 47, Epsilon: 0.010
# Episode 702, Reward: -8, Epsilon: 0.010
# Episode 703, Reward: -19, Epsilon: 0.010
# Episode 704, Reward: 56, Epsilon: 0.010
# Episode 705, Reward: 33, Epsilon: 0.010
# Episode 706, Reward: 60, Epsilon: 0.010
# Episode 707, Reward: 59, Epsilon: 0.010
# Episode 708, Reward: 55, Epsilon: 0.010
# Episode 709, Reward: 54, Epsilon: 0.010
# Episode 710, Reward: -13, Epsilon: 0.010
# Episode 711, Reward: 54, Epsilon: 0.010
# Episode 712, Reward: 49, Epsilon: 0.010
# Episode 713, Reward: 40, Epsilon: 0.010
# Episode 714, Reward: 47, Epsilon: 0.010
# Episode 715, Reward: 59, Epsilon: 0.010
# Episode 716, Reward: -14, Epsilon: 0.010
# Episode 717, Reward: 51, Epsilon: 0.010
# Episode 718, Reward: 60, Epsilon: 0.010
# Episode 719, Reward: 55, Epsilon: 0.010
# Episode 720, Reward: 7, Epsilon: 0.010
# Episode 721, Reward: 51, Epsilon: 0.010
# Episode 722, Reward: 42, Epsilon: 0.010
# Episode 723, Reward: 16, Epsilon: 0.010
# Episode 724, Reward: 40, Epsilon: 0.010
# Episode 725, Reward: 41, Epsilon: 0.010
# Episode 726, Reward: 38, Epsilon: 0.010
# Episode 727, Reward: 49, Epsilon: 0.010
# Episode 728, Reward: 51, Epsilon: 0.010
# Episode 729, Reward: 58, Epsilon: 0.010
# Episode 730, Reward: 53, Epsilon: 0.010
# Episode 731, Reward: 58, Epsilon: 0.010
# Episode 732, Reward: 53, Epsilon: 0.010
# Episode 733, Reward: 59, Epsilon: 0.010
# Episode 734, Reward: 2, Epsilon: 0.010
# Episode 735, Reward: 47, Epsilon: 0.010
# Episode 736, Reward: 54, Epsilon: 0.010
# Episode 737, Reward: 58, Epsilon: 0.010
# Episode 738, Reward: 44, Epsilon: 0.010
# Episode 739, Reward: 50, Epsilon: 0.010
# Episode 740, Reward: 59, Epsilon: 0.010
# Episode 741, Reward: 0, Epsilon: 0.010
# Episode 742, Reward: 61, Epsilon: 0.010
# Episode 743, Reward: 42, Epsilon: 0.010
# Episode 744, Reward: 64, Epsilon: 0.010
# Episode 745, Reward: 50, Epsilon: 0.010
# Episode 746, Reward: -3, Epsilon: 0.010
# Episode 747, Reward: 57, Epsilon: 0.010
# Episode 748, Reward: 58, Epsilon: 0.010
# Episode 749, Reward: 56, Epsilon: 0.010
# Episode 750, Reward: 53, Epsilon: 0.010
# Episode 751, Reward: 59, Epsilon: 0.010
# Episode 752, Reward: 47, Epsilon: 0.010
# Episode 753, Reward: 48, Epsilon: 0.010
# Episode 754, Reward: 46, Epsilon: 0.010
# Episode 755, Reward: 59, Epsilon: 0.010
# Episode 756, Reward: 57, Epsilon: 0.010
# Episode 757, Reward: 54, Epsilon: 0.010
# Episode 758, Reward: 52, Epsilon: 0.010
# Episode 759, Reward: 43, Epsilon: 0.010
# Episode 760, Reward: 45, Epsilon: 0.010
# Episode 761, Reward: 60, Epsilon: 0.010
# Episode 762, Reward: 64, Epsilon: 0.010
# Episode 763, Reward: 60, Epsilon: 0.010
# Episode 764, Reward: 59, Epsilon: 0.010
# Episode 765, Reward: 54, Epsilon: 0.010
# Episode 766, Reward: 49, Epsilon: 0.010
# Episode 767, Reward: 66, Epsilon: 0.010
# Episode 768, Reward: 53, Epsilon: 0.010
# Episode 769, Reward: 53, Epsilon: 0.010
# Episode 770, Reward: 36, Epsilon: 0.010
# Episode 771, Reward: 63, Epsilon: 0.010
# Episode 772, Reward: 62, Epsilon: 0.010
# Episode 773, Reward: 53, Epsilon: 0.010
# Episode 774, Reward: 39, Epsilon: 0.010
# Episode 775, Reward: 47, Epsilon: 0.010
# Episode 776, Reward: 57, Epsilon: 0.010
# Episode 777, Reward: 58, Epsilon: 0.010
# Episode 778, Reward: 53, Epsilon: 0.010
# Episode 779, Reward: 46, Epsilon: 0.010
# Episode 780, Reward: 56, Epsilon: 0.010
# Episode 781, Reward: 60, Epsilon: 0.010
# Episode 782, Reward: 50, Epsilon: 0.010
# Episode 783, Reward: 56, Epsilon: 0.010
# Episode 784, Reward: 57, Epsilon: 0.010
# Episode 785, Reward: 64, Epsilon: 0.010
# Episode 786, Reward: 50, Epsilon: 0.010
# Episode 787, Reward: 54, Epsilon: 0.010
# Episode 788, Reward: 62, Epsilon: 0.010
# Episode 789, Reward: 44, Epsilon: 0.010
# Episode 790, Reward: 57, Epsilon: 0.010
# Episode 791, Reward: 53, Epsilon: 0.010
# Episode 792, Reward: 61, Epsilon: 0.010
# Episode 793, Reward: 64, Epsilon: 0.010
# Episode 794, Reward: 52, Epsilon: 0.010
# Episode 795, Reward: 60, Epsilon: 0.010
# Episode 796, Reward: 62, Epsilon: 0.010
# Episode 797, Reward: 57, Epsilon: 0.010
# Episode 798, Reward: 62, Epsilon: 0.010
# Episode 799, Reward: 58, Epsilon: 0.010
# Episode 800, Reward: 45, Epsilon: 0.010
# Episode 801, Reward: 63, Epsilon: 0.010
# Episode 802, Reward: 51, Epsilon: 0.010
# Episode 803, Reward: 43, Epsilon: 0.010
# Episode 804, Reward: 56, Epsilon: 0.010
# Episode 805, Reward: 36, Epsilon: 0.010
# Episode 806, Reward: 48, Epsilon: 0.010
# Episode 807, Reward: 35, Epsilon: 0.010
# Episode 808, Reward: 51, Epsilon: 0.010
# Episode 809, Reward: 44, Epsilon: 0.010
# Episode 810, Reward: 54, Epsilon: 0.010
# Episode 811, Reward: 50, Epsilon: 0.010
# Episode 812, Reward: 58, Epsilon: 0.010
# Episode 813, Reward: 61, Epsilon: 0.010
# Episode 814, Reward: 52, Epsilon: 0.010
# Episode 815, Reward: 54, Epsilon: 0.010
# Episode 816, Reward: 52, Epsilon: 0.010
# Episode 817, Reward: 43, Epsilon: 0.010
# Episode 818, Reward: 61, Epsilon: 0.010
# Episode 819, Reward: 50, Epsilon: 0.010
# Episode 820, Reward: -8, Epsilon: 0.010
# Episode 821, Reward: 53, Epsilon: 0.010
# Episode 822, Reward: 60, Epsilon: 0.010
# Episode 823, Reward: 45, Epsilon: 0.010
# Episode 824, Reward: 62, Epsilon: 0.010
# Episode 825, Reward: 58, Epsilon: 0.010
# Episode 826, Reward: 51, Epsilon: 0.010
# Episode 827, Reward: 42, Epsilon: 0.010
# Episode 828, Reward: 42, Epsilon: 0.010
# Episode 829, Reward: 56, Epsilon: 0.010
# Episode 830, Reward: 48, Epsilon: 0.010
# Episode 831, Reward: 58, Epsilon: 0.010
# Episode 832, Reward: 59, Epsilon: 0.010
# Episode 833, Reward: 42, Epsilon: 0.010
# Episode 834, Reward: 54, Epsilon: 0.010
# Episode 835, Reward: 48, Epsilon: 0.010
# Episode 836, Reward: 53, Epsilon: 0.010
# Episode 837, Reward: 12, Epsilon: 0.010
# Episode 838, Reward: 61, Epsilon: 0.010
# Episode 839, Reward: 54, Epsilon: 0.010
# Episode 840, Reward: 50, Epsilon: 0.010
# Episode 841, Reward: 60, Epsilon: 0.010
# Episode 842, Reward: 38, Epsilon: 0.010
# Episode 843, Reward: 54, Epsilon: 0.010
# Episode 844, Reward: 53, Epsilon: 0.010
# Episode 845, Reward: 47, Epsilon: 0.010
# Episode 846, Reward: 54, Epsilon: 0.010
# Episode 847, Reward: 62, Epsilon: 0.010
# Episode 848, Reward: -4, Epsilon: 0.010
# Episode 849, Reward: 53, Epsilon: 0.010
# Episode 850, Reward: 45, Epsilon: 0.010
# Episode 851, Reward: 55, Epsilon: 0.010
# Episode 852, Reward: 58, Epsilon: 0.010
# Episode 853, Reward: 58, Epsilon: 0.010
# Episode 854, Reward: 8, Epsilon: 0.010
# Episode 855, Reward: 52, Epsilon: 0.010
# Episode 856, Reward: 55, Epsilon: 0.010
# Episode 857, Reward: 48, Epsilon: 0.010
# Episode 858, Reward: 50, Epsilon: 0.010
# Episode 859, Reward: -14, Epsilon: 0.010
# Episode 860, Reward: 62, Epsilon: 0.010
# Episode 861, Reward: 55, Epsilon: 0.010
# Episode 862, Reward: 49, Epsilon: 0.010
# Episode 863, Reward: 57, Epsilon: 0.010
# Episode 864, Reward: 44, Epsilon: 0.010
# Episode 865, Reward: 65, Epsilon: 0.010
# Episode 866, Reward: 63, Epsilon: 0.010
# Episode 867, Reward: 63, Epsilon: 0.010
# Episode 868, Reward: 59, Epsilon: 0.010
# Episode 869, Reward: 57, Epsilon: 0.010
# Episode 870, Reward: 61, Epsilon: 0.010
# Episode 871, Reward: 50, Epsilon: 0.010
# Episode 872, Reward: 38, Epsilon: 0.010
# Episode 873, Reward: 55, Epsilon: 0.010
# Episode 874, Reward: 64, Epsilon: 0.010
# Episode 875, Reward: 54, Epsilon: 0.010
# Episode 876, Reward: 58, Epsilon: 0.010
# Episode 877, Reward: 54, Epsilon: 0.010
# Episode 878, Reward: 60, Epsilon: 0.010
# Episode 879, Reward: 60, Epsilon: 0.010
# Episode 880, Reward: -20, Epsilon: 0.010
# Episode 881, Reward: 61, Epsilon: 0.010
# Episode 882, Reward: 44, Epsilon: 0.010
# Episode 883, Reward: 59, Epsilon: 0.010
# Episode 884, Reward: 54, Epsilon: 0.010
# Episode 885, Reward: 54, Epsilon: 0.010
# Episode 886, Reward: 54, Epsilon: 0.010
# Episode 887, Reward: 46, Epsilon: 0.010
# Episode 888, Reward: 58, Epsilon: 0.010
# Episode 889, Reward: 56, Epsilon: 0.010
# Episode 890, Reward: 60, Epsilon: 0.010
# Episode 891, Reward: -3, Epsilon: 0.010
# Episode 892, Reward: 55, Epsilon: 0.010
# Episode 893, Reward: -18, Epsilon: 0.010
# Episode 894, Reward: -22, Epsilon: 0.010
# Episode 895, Reward: 46, Epsilon: 0.010
# Episode 896, Reward: 65, Epsilon: 0.010
# Episode 897, Reward: -77, Epsilon: 0.010
# Episode 898, Reward: 55, Epsilon: 0.010
# Episode 899, Reward: 61, Epsilon: 0.010
# Episode 900, Reward: 49, Epsilon: 0.010
# Episode 901, Reward: 50, Epsilon: 0.010
# Episode 902, Reward: -108, Epsilon: 0.010
# Episode 903, Reward: -16, Epsilon: 0.010
# Episode 904, Reward: 52, Epsilon: 0.010
# Episode 905, Reward: -6, Epsilon: 0.010
# Episode 906, Reward: 52, Epsilon: 0.010
# Episode 907, Reward: 66, Epsilon: 0.010
# Episode 908, Reward: -115, Epsilon: 0.010
# Episode 909, Reward: 60, Epsilon: 0.010
# Episode 910, Reward: -64, Epsilon: 0.010
# Episode 911, Reward: 60, Epsilon: 0.010
# Episode 912, Reward: 58, Epsilon: 0.010
# Episode 913, Reward: 55, Epsilon: 0.010
# Episode 914, Reward: 51, Epsilon: 0.010
# Episode 915, Reward: 7, Epsilon: 0.010
# Episode 916, Reward: 53, Epsilon: 0.010
# Episode 917, Reward: 54, Epsilon: 0.010
# Episode 918, Reward: 53, Epsilon: 0.010
# Episode 919, Reward: 64, Epsilon: 0.010
# Episode 920, Reward: 51, Epsilon: 0.010
# Episode 921, Reward: 50, Epsilon: 0.010
# Episode 922, Reward: -38, Epsilon: 0.010
# Episode 923, Reward: -2, Epsilon: 0.010
# Episode 924, Reward: 3, Epsilon: 0.010
# Episode 925, Reward: 5, Epsilon: 0.010
# Episode 926, Reward: -75, Epsilon: 0.010
# Episode 927, Reward: 57, Epsilon: 0.010
# Episode 928, Reward: 52, Epsilon: 0.010
# Episode 929, Reward: 32, Epsilon: 0.010
# Episode 930, Reward: 58, Epsilon: 0.010
# Episode 931, Reward: -5, Epsilon: 0.010
# Episode 932, Reward: 12, Epsilon: 0.010
# Episode 933, Reward: 64, Epsilon: 0.010
# Episode 934, Reward: 47, Epsilon: 0.010
# Episode 935, Reward: 54, Epsilon: 0.010
# Episode 936, Reward: 60, Epsilon: 0.010
# Episode 937, Reward: 55, Epsilon: 0.010
# Episode 938, Reward: -2, Epsilon: 0.010
# Episode 939, Reward: 59, Epsilon: 0.010
# Episode 940, Reward: 61, Epsilon: 0.010
# Episode 941, Reward: 8, Epsilon: 0.010
# Episode 942, Reward: 61, Epsilon: 0.010
# Episode 943, Reward: 41, Epsilon: 0.010
# Episode 944, Reward: -8, Epsilon: 0.010
# Episode 945, Reward: -68, Epsilon: 0.010
# Episode 946, Reward: 4, Epsilon: 0.010
# Episode 947, Reward: 47, Epsilon: 0.010
# Episode 948, Reward: 47, Epsilon: 0.010
# Episode 949, Reward: 47, Epsilon: 0.010
# Episode 950, Reward: 55, Epsilon: 0.010
# Episode 951, Reward: 61, Epsilon: 0.010
# Episode 952, Reward: 58, Epsilon: 0.010
# Episode 953, Reward: 55, Epsilon: 0.010
# Episode 954, Reward: 61, Epsilon: 0.010
# Episode 955, Reward: 59, Epsilon: 0.010
# Episode 956, Reward: 49, Epsilon: 0.010
# Episode 957, Reward: 57, Epsilon: 0.010
# Episode 958, Reward: -3, Epsilon: 0.010
# Episode 959, Reward: -2, Epsilon: 0.010
# Episode 960, Reward: 54, Epsilon: 0.010
# Episode 961, Reward: 53, Epsilon: 0.010
# Episode 962, Reward: 62, Epsilon: 0.010
# Episode 963, Reward: 47, Epsilon: 0.010
# Episode 964, Reward: 62, Epsilon: 0.010
# Episode 965, Reward: 55, Epsilon: 0.010
# Episode 966, Reward: 59, Epsilon: 0.010
# Episode 967, Reward: 44, Epsilon: 0.010
# Episode 968, Reward: -5, Epsilon: 0.010
# Episode 969, Reward: 61, Epsilon: 0.010
# Episode 970, Reward: -9, Epsilon: 0.010
# Episode 971, Reward: 56, Epsilon: 0.010
# Episode 972, Reward: 7, Epsilon: 0.010
# Episode 973, Reward: 50, Epsilon: 0.010
# Episode 974, Reward: 67, Epsilon: 0.010
# Episode 975, Reward: 51, Epsilon: 0.010
# Episode 976, Reward: 49, Epsilon: 0.010
# Episode 977, Reward: 56, Epsilon: 0.010
# Episode 978, Reward: 49, Epsilon: 0.010
# Episode 979, Reward: 61, Epsilon: 0.010
# Episode 980, Reward: 65, Epsilon: 0.010
# Episode 981, Reward: 47, Epsilon: 0.010
# Episode 982, Reward: 51, Epsilon: 0.010
# Episode 983, Reward: 55, Epsilon: 0.010
# Episode 984, Reward: 53, Epsilon: 0.010
# Episode 985, Reward: -6, Epsilon: 0.010
# Episode 986, Reward: 59, Epsilon: 0.010
# Episode 987, Reward: 2, Epsilon: 0.010
# Episode 988, Reward: 50, Epsilon: 0.010
# Episode 989, Reward: 8, Epsilon: 0.010
# Episode 990, Reward: 47, Epsilon: 0.010
# Episode 991, Reward: 44, Epsilon: 0.010
# Episode 992, Reward: 68, Epsilon: 0.010
# Episode 993, Reward: 52, Epsilon: 0.010
# Episode 994, Reward: 47, Epsilon: 0.010
# Episode 995, Reward: 48, Epsilon: 0.010
# Episode 996, Reward: 55, Epsilon: 0.010
# Episode 997, Reward: 45, Epsilon: 0.010
# Episode 998, Reward: 45, Epsilon: 0.010
# Episode 999, Reward: 64, Epsilon: 0.010
# Episode 1000, Reward: 55, Epsilon: 0.010

# %%
plt.figure(figsize=(14, 6))
plt.plot(episode_rewards_dqn)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('DQN Training on TruckBackerEnv_D')
plt.grid(True)

plt.show()

# %% [markdown]
# # QRC Testing

# %%
# --- 3. Training Script Setup and Execution ---

# Hyperparameters (user-defined and QRC-specific)
# num_episodes = 1000
# max_steps_per_episode = 500
# gamma = 0.99
# learning_rate = 1e-3
# epsilon_start = 1.0
# epsilon_decay = 0.99997
# epsilon_min = 0.01
# batch_size = 64
# target_update_freq = 5 # Target network update frequency in episodes

# QRC Specific Parameters (Defaults)
alpha = 1.0
sigma_min = 0.0
sigma_max = 1.0


# Environment Setup
env = TruckBackerEnv_D(render_mode=None)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

# Agent Initialization (using QRCAgent)
# agent = QRCAgent(
#     state_dim=state_dim,
#     action_dim=action_dim,
#     lr=learning_rate,
#     gamma=gamma,
#     epsilon=epsilon_start,
#     epsilon_decay=epsilon_decay,
#     epsilon_min=epsilon_min,
#     batch_size=batch_size,
#     target_update_freq=target_update_freq,
#     alpha=alpha,
#     sigma_min=sigma_min,
#     sigma_max=sigma_max
# )
agent = QRCAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    lr=learning_rate,
    gamma=gamma,
    epsilon=epsilon_start,
    epsilon_decay=epsilon_decay,
    min_epsilon=epsilon_min,
    batch_size=batch_size
)


# Training Loop
episode_rewards_qrc = []
recent_loss = 0.0 # Variable to track latest loss for printing

for episode in range(1, num_episodes + 1):
    # env.reset returns a tuple in modern gyms, ensure it's unpacked correctly
    state, info = env.reset() if isinstance(env.reset(), tuple) else (env.reset(), {})
    total_reward = 0

    for t in range(max_steps_per_episode):
        
        action = agent.agent_policy(state)
        
        # Check if environment step returns a tuple of (next_state, reward, terminated, truncated, info) or (next_state, reward, done, info)
        step_result = env.step(action)
        
        if len(step_result) == 5:
            next_state, reward, terminated, truncated, info = step_result
            done = terminated or truncated
        else: # assuming old gym signature (next_state, reward, done, info)
            next_state, reward, done, info = step_result

        total_reward += reward

        # Store transition in memory
        agent.remember(state, action, reward, next_state, done)

        # Train agent with memory
        current_loss = agent.train_with_mem()
        if current_loss != 0.0:
            recent_loss = current_loss

        state = next_state

        if done:
            break

    # Target Network Update (based on episode count)
    if episode % target_update_freq == 0:
        agent.update_target()

    episode_rewards_qrc.append(total_reward)
    
    # Print episode summary
    print(f"Episode {episode}/{num_episodes}, Reward: {total_reward:6.2f}, Epsilon: {agent.epsilon:.5f}, Loss: {recent_loss:.5f}")
# Out:
# Episode 1/1000, Reward: -300.00, Epsilon: 0.99292, Loss: 0.00115
# Episode 2/1000, Reward: -300.00, Epsilon: 0.98402, Loss: 0.00106
# Episode 3/1000, Reward: -300.00, Epsilon: 0.97520, Loss: 0.00034
# Episode 4/1000, Reward: -300.00, Epsilon: 0.96646, Loss: 0.00170
# Episode 5/1000, Reward: -300.00, Epsilon: 0.95781, Loss: 0.00108
# Episode 6/1000, Reward: -300.00, Epsilon: 0.94922, Loss: 0.00050
# Episode 7/1000, Reward: -300.00, Epsilon: 0.94072, Loss: 0.00109
# Episode 8/1000, Reward: -300.00, Epsilon: 0.93229, Loss: 0.00029
# Episode 9/1000, Reward: -300.00, Epsilon: 0.92394, Loss: 0.00167
# Episode 10/1000, Reward: -300.00, Epsilon: 0.91566, Loss: 0.00052
# Episode 11/1000, Reward: -300.00, Epsilon: 0.90745, Loss: 0.01096
# Episode 12/1000, Reward: -300.00, Epsilon: 0.89932, Loss: 0.00167
# Episode 13/1000, Reward: -300.00, Epsilon: 0.89127, Loss: 0.00104
# Episode 14/1000, Reward: -300.00, Epsilon: 0.88328, Loss: 0.01690
# Episode 15/1000, Reward: -300.00, Epsilon: 0.87537, Loss: 0.00052
# Episode 16/1000, Reward: -300.00, Epsilon: 0.86752, Loss: 0.00850
# Episode 17/1000, Reward: -300.00, Epsilon: 0.85975, Loss: 0.01090
# Episode 18/1000, Reward: -300.00, Epsilon: 0.85205, Loss: 0.00625
# Episode 19/1000, Reward: -300.00, Epsilon: 0.84441, Loss: 0.00199
# Episode 20/1000, Reward: -300.00, Epsilon: 0.83685, Loss: 0.00070
# Episode 21/1000, Reward: -300.00, Epsilon: 0.82935, Loss: 0.04281
# Episode 22/1000, Reward: -300.00, Epsilon: 0.82192, Loss: 0.00110
# Episode 23/1000, Reward: -300.00, Epsilon: 0.81456, Loss: 0.00373
# Episode 24/1000, Reward: -300.00, Epsilon: 0.80726, Loss: 0.00139
# Episode 25/1000, Reward: -300.00, Epsilon: 0.80002, Loss: 0.05192
# Episode 26/1000, Reward: -300.00, Epsilon: 0.79286, Loss: 0.00219
# Episode 27/1000, Reward: -300.00, Epsilon: 0.78575, Loss: 0.00428
# Episode 28/1000, Reward: -300.00, Epsilon: 0.77871, Loss: 0.02269
# Episode 29/1000, Reward: -300.00, Epsilon: 0.77174, Loss: 0.00198
# Episode 30/1000, Reward: -300.00, Epsilon: 0.76482, Loss: 0.00235
# Episode 31/1000, Reward: -300.00, Epsilon: 0.75797, Loss: 0.09476
# Episode 32/1000, Reward: -300.00, Epsilon: 0.75118, Loss: 0.00368
# Episode 33/1000, Reward: -300.00, Epsilon: 0.74445, Loss: 0.08872
# Episode 34/1000, Reward: -300.00, Epsilon: 0.73778, Loss: 0.00393
# Episode 35/1000, Reward: -300.00, Epsilon: 0.73117, Loss: 0.01161
# Episode 36/1000, Reward: -300.00, Epsilon: 0.72461, Loss: 0.09230
# Episode 37/1000, Reward: -300.00, Epsilon: 0.71812, Loss: 0.00763
# Episode 38/1000, Reward: -300.00, Epsilon: 0.71169, Loss: 0.00678
# Episode 39/1000, Reward: -300.00, Epsilon: 0.70531, Loss: 0.00288
# Episode 40/1000, Reward: -300.00, Epsilon: 0.69899, Loss: 0.00263
# Episode 41/1000, Reward: -300.00, Epsilon: 0.69273, Loss: 0.00653
# Episode 42/1000, Reward: -300.00, Epsilon: 0.68652, Loss: 0.00612
# Episode 43/1000, Reward: -300.00, Epsilon: 0.68037, Loss: 0.00391
# Episode 44/1000, Reward: -300.00, Epsilon: 0.67428, Loss: 0.00644
# Episode 45/1000, Reward: -300.00, Epsilon: 0.66823, Loss: 0.00283
# Episode 46/1000, Reward: -300.00, Epsilon: 0.66225, Loss: 0.00648
# Episode 47/1000, Reward: -300.00, Epsilon: 0.65631, Loss: 0.00674
# Episode 48/1000, Reward: -300.00, Epsilon: 0.65043, Loss: 0.00809
# Episode 49/1000, Reward: -300.00, Epsilon: 0.64461, Loss: 0.20971
# Episode 50/1000, Reward: -300.00, Epsilon: 0.63883, Loss: 0.00420
# Episode 51/1000, Reward: -300.00, Epsilon: 0.63311, Loss: 0.00845
# Episode 52/1000, Reward: -300.00, Epsilon: 0.62743, Loss: 0.01657
# Episode 53/1000, Reward: -300.00, Epsilon: 0.62181, Loss: 0.00836
# Episode 54/1000, Reward: -300.00, Epsilon: 0.61624, Loss: 0.00648
# Episode 55/1000, Reward: -300.00, Epsilon: 0.61072, Loss: 0.00614
# Episode 56/1000, Reward: -300.00, Epsilon: 0.60525, Loss: 0.00687
# Episode 57/1000, Reward: -300.00, Epsilon: 0.59982, Loss: 0.26342
# Episode 58/1000, Reward: -300.00, Epsilon: 0.59445, Loss: 0.00580
# Episode 59/1000, Reward: -300.00, Epsilon: 0.58912, Loss: 0.00822
# Episode 60/1000, Reward: -300.00, Epsilon: 0.58385, Loss: 0.00627
# Episode 61/1000, Reward: -300.00, Epsilon: 0.57861, Loss: 0.01588
# Episode 62/1000, Reward: -300.00, Epsilon: 0.57343, Loss: 0.00715
# Episode 63/1000, Reward: -300.00, Epsilon: 0.56829, Loss: 0.43670
# Episode 64/1000, Reward: -300.00, Epsilon: 0.56320, Loss: 0.00981
# Episode 65/1000, Reward: -300.00, Epsilon: 0.55815, Loss: 0.01184
# Episode 66/1000, Reward: -300.00, Epsilon: 0.55315, Loss: 0.01003
# Episode 67/1000, Reward: -300.00, Epsilon: 0.54820, Loss: 0.03264
# Episode 68/1000, Reward: -300.00, Epsilon: 0.54329, Loss: 0.35376
# Episode 69/1000, Reward: -119.00, Epsilon: 0.53971, Loss: 0.43806
# Episode 70/1000, Reward: -300.00, Epsilon: 0.53488, Loss: 0.00529
# Episode 71/1000, Reward: -300.00, Epsilon: 0.53008, Loss: 0.54248
# Episode 72/1000, Reward: -300.00, Epsilon: 0.52533, Loss: 0.54001
# Episode 73/1000, Reward: -300.00, Epsilon: 0.52063, Loss: 0.50294
# Episode 74/1000, Reward: -300.00, Epsilon: 0.51596, Loss: 0.01901
# Episode 75/1000, Reward: -300.00, Epsilon: 0.51134, Loss: 0.02181
# Episode 76/1000, Reward: -300.00, Epsilon: 0.50676, Loss: 0.02895
# Episode 77/1000, Reward: -300.00, Epsilon: 0.50222, Loss: 0.02119
# Episode 78/1000, Reward: -300.00, Epsilon: 0.49772, Loss: 0.50745
# Episode 79/1000, Reward: -300.00, Epsilon: 0.49326, Loss: 0.48289
# Episode 80/1000, Reward: -300.00, Epsilon: 0.48884, Loss: 0.01976
# Episode 81/1000, Reward: -300.00, Epsilon: 0.48446, Loss: 0.02059
# Episode 82/1000, Reward: -300.00, Epsilon: 0.48012, Loss: 0.85543
# Episode 83/1000, Reward: -300.00, Epsilon: 0.47582, Loss: 0.70642
# Episode 84/1000, Reward: -300.00, Epsilon: 0.47155, Loss: 0.02664
# Episode 85/1000, Reward: -300.00, Epsilon: 0.46733, Loss: 0.59759
# Episode 86/1000, Reward: -300.00, Epsilon: 0.46314, Loss: 0.01734
# Episode 87/1000, Reward: -300.00, Epsilon: 0.45899, Loss: 0.00844
# Episode 88/1000, Reward: -300.00, Epsilon: 0.45488, Loss: 0.02248
# Episode 89/1000, Reward: -300.00, Epsilon: 0.45080, Loss: 0.83006
# Episode 90/1000, Reward: -300.00, Epsilon: 0.44677, Loss: 0.00922
# Episode 91/1000, Reward: -300.00, Epsilon: 0.44276, Loss: 0.02401
# Episode 92/1000, Reward: -300.00, Epsilon: 0.43880, Loss: 0.01366
# Episode 93/1000, Reward: -300.00, Epsilon: 0.43486, Loss: 0.02206
# Episode 94/1000, Reward: -300.00, Epsilon: 0.43097, Loss: 0.02268
# Episode 95/1000, Reward: -300.00, Epsilon: 0.42711, Loss: 0.85244
# Episode 96/1000, Reward: -300.00, Epsilon: 0.42328, Loss: 0.03637
# Episode 97/1000, Reward: -300.00, Epsilon: 0.41949, Loss: 0.03083
# Episode 98/1000, Reward: -300.00, Epsilon: 0.41573, Loss: 0.03094
# Episode 99/1000, Reward: -300.00, Epsilon: 0.41200, Loss: 0.96107
# Episode 100/1000, Reward: -300.00, Epsilon: 0.40831, Loss: 0.01675
# Episode 101/1000, Reward: -300.00, Epsilon: 0.40465, Loss: 0.02339
# Episode 102/1000, Reward: -300.00, Epsilon: 0.40103, Loss: 1.14183
# Episode 103/1000, Reward: -300.00, Epsilon: 0.39744, Loss: 0.10277
# Episode 104/1000, Reward: -300.00, Epsilon: 0.39387, Loss: 0.02692
# Episode 105/1000, Reward: -300.00, Epsilon: 0.39035, Loss: 0.06657
# Episode 106/1000, Reward: -300.00, Epsilon: 0.38685, Loss: 0.01047
# Episode 107/1000, Reward: -300.00, Epsilon: 0.38338, Loss: 0.51366
# Episode 108/1000, Reward: -300.00, Epsilon: 0.37995, Loss: 0.02374
# Episode 109/1000, Reward: -300.00, Epsilon: 0.37654, Loss: 0.09623
# Episode 110/1000, Reward: -300.00, Epsilon: 0.37317, Loss: 1.13176
# Episode 111/1000, Reward: -300.00, Epsilon: 0.36983, Loss: 0.03353
# Episode 112/1000, Reward: -300.00, Epsilon: 0.36651, Loss: 0.05516
# Episode 113/1000, Reward: -300.00, Epsilon: 0.36323, Loss: 0.04872
# Episode 114/1000, Reward: -300.00, Epsilon: 0.35997, Loss: 1.20781
# Episode 115/1000, Reward: -300.00, Epsilon: 0.35675, Loss: 1.18229
# Episode 116/1000, Reward: -300.00, Epsilon: 0.35355, Loss: 0.03424
# Episode 117/1000, Reward: -300.00, Epsilon: 0.35038, Loss: 0.02001
# Episode 118/1000, Reward: -300.00, Epsilon: 0.34724, Loss: 1.49160
# Episode 119/1000, Reward: -300.00, Epsilon: 0.34413, Loss: 0.02741
# Episode 120/1000, Reward: -300.00, Epsilon: 0.34105, Loss: 0.01727
# Episode 121/1000, Reward: -300.00, Epsilon: 0.33799, Loss: 1.73389
# Episode 122/1000, Reward: -300.00, Epsilon: 0.33497, Loss: 0.03677
# Episode 123/1000, Reward: -300.00, Epsilon: 0.33196, Loss: 0.04934
# Episode 124/1000, Reward: -300.00, Epsilon: 0.32899, Loss: 0.02800
# Episode 125/1000, Reward: -300.00, Epsilon: 0.32604, Loss: 0.07012
# Episode 126/1000, Reward: -300.00, Epsilon: 0.32312, Loss: 0.03028
# Episode 127/1000, Reward: -300.00, Epsilon: 0.32023, Loss: 0.10464
# Episode 128/1000, Reward:  35.00, Epsilon: 0.31959, Loss: 0.05139
# Episode 129/1000, Reward: -300.00, Epsilon: 0.31673, Loss: 0.03230
# Episode 130/1000, Reward: -300.00, Epsilon: 0.31389, Loss: 2.86506
# Episode 131/1000, Reward: -300.00, Epsilon: 0.31108, Loss: 1.80623
# Episode 132/1000, Reward: -300.00, Epsilon: 0.30829, Loss: 0.06456
# Episode 133/1000, Reward: -300.00, Epsilon: 0.30553, Loss: 0.05105
# Episode 134/1000, Reward: -300.00, Epsilon: 0.30279, Loss: 0.05640
# Episode 135/1000, Reward: -300.00, Epsilon: 0.30008, Loss: 2.09540
# Episode 136/1000, Reward: -300.00, Epsilon: 0.29739, Loss: 0.03461
# Episode 137/1000, Reward: -300.00, Epsilon: 0.29473, Loss: 0.03217
# Episode 138/1000, Reward: -300.00, Epsilon: 0.29209, Loss: 0.05149
# Episode 139/1000, Reward: -300.00, Epsilon: 0.28947, Loss: 0.03421
# Episode 140/1000, Reward: -300.00, Epsilon: 0.28687, Loss: 0.06425
# Episode 141/1000, Reward: -300.00, Epsilon: 0.28430, Loss: 0.06067
# Episode 142/1000, Reward: -300.00, Epsilon: 0.28176, Loss: 0.11468
# Episode 143/1000, Reward: -300.00, Epsilon: 0.27923, Loss: 0.05576
# Episode 144/1000, Reward: -300.00, Epsilon: 0.27673, Loss: 1.11235
# Episode 145/1000, Reward: -300.00, Epsilon: 0.27425, Loss: 0.01603
# Episode 146/1000, Reward: -300.00, Epsilon: 0.27179, Loss: 0.02029
# Episode 147/1000, Reward: -300.00, Epsilon: 0.26936, Loss: 0.03549
# Episode 148/1000, Reward: -300.00, Epsilon: 0.26695, Loss: 0.04860
# Episode 149/1000, Reward: -300.00, Epsilon: 0.26455, Loss: 0.01374
# Episode 150/1000, Reward: -300.00, Epsilon: 0.26218, Loss: 0.03291
# Episode 151/1000, Reward: -300.00, Epsilon: 0.25983, Loss: 0.07144
# Episode 152/1000, Reward: -300.00, Epsilon: 0.25751, Loss: 0.03490
# Episode 153/1000, Reward: -300.00, Epsilon: 0.25520, Loss: 0.06226
# Episode 154/1000, Reward: -300.00, Epsilon: 0.25291, Loss: 0.05886
# Episode 155/1000, Reward: -300.00, Epsilon: 0.25065, Loss: 0.04279
# Episode 156/1000, Reward: -300.00, Epsilon: 0.24840, Loss: 0.05789
# Episode 157/1000, Reward: -300.00, Epsilon: 0.24618, Loss: 0.08234
# Episode 158/1000, Reward: -300.00, Epsilon: 0.24397, Loss: 0.03259
# Episode 159/1000, Reward: -300.00, Epsilon: 0.24178, Loss: 0.03122
# Episode 160/1000, Reward: -300.00, Epsilon: 0.23962, Loss: 0.01198
# Episode 161/1000, Reward: -300.00, Epsilon: 0.23747, Loss: -0.00088
# Episode 162/1000, Reward: -300.00, Epsilon: 0.23534, Loss: 0.10285
# Episode 163/1000, Reward: -300.00, Epsilon: 0.23323, Loss: 0.03006
# Episode 164/1000, Reward: -300.00, Epsilon: 0.23114, Loss: 0.05854
# Episode 165/1000, Reward: -300.00, Epsilon: 0.22907, Loss: 0.06055
# Episode 166/1000, Reward: -300.00, Epsilon: 0.22702, Loss: 0.12897
# Episode 167/1000, Reward: -300.00, Epsilon: 0.22499, Loss: 0.00755
# Episode 168/1000, Reward: -300.00, Epsilon: 0.22297, Loss: 0.03277
# Episode 169/1000, Reward: -300.00, Epsilon: 0.22097, Loss: 0.08419
# Episode 170/1000, Reward: -300.00, Epsilon: 0.21899, Loss: 0.02528
# Episode 171/1000, Reward: -300.00, Epsilon: 0.21703, Loss: 0.00263
# Episode 172/1000, Reward: -300.00, Epsilon: 0.21509, Loss: 0.02533
# Episode 173/1000, Reward: -300.00, Epsilon: 0.21316, Loss: 0.06290
# Episode 174/1000, Reward: -300.00, Epsilon: 0.21125, Loss: 0.03551
# Episode 175/1000, Reward: -300.00, Epsilon: 0.20936, Loss: 0.08021
# Episode 176/1000, Reward: -300.00, Epsilon: 0.20748, Loss: 0.09575
# Episode 177/1000, Reward: -300.00, Epsilon: 0.20562, Loss: 0.05379
# Episode 178/1000, Reward: -300.00, Epsilon: 0.20378, Loss: 0.07566
# Episode 179/1000, Reward: -300.00, Epsilon: 0.20195, Loss: 2.09482
# Episode 180/1000, Reward: -300.00, Epsilon: 0.20014, Loss: 0.05597
# Episode 181/1000, Reward: -300.00, Epsilon: 0.19835, Loss: 0.03185
# Episode 182/1000, Reward: -300.00, Epsilon: 0.19657, Loss: 0.07186
# Episode 183/1000, Reward: -300.00, Epsilon: 0.19481, Loss: 0.02217
# Episode 184/1000, Reward: -300.00, Epsilon: 0.19307, Loss: 0.03262
# Episode 185/1000, Reward: -300.00, Epsilon: 0.19134, Loss: -0.06191
# Episode 186/1000, Reward: -300.00, Epsilon: 0.18962, Loss: 0.19212
# Episode 187/1000, Reward: -300.00, Epsilon: 0.18792, Loss: 0.03219
# Episode 188/1000, Reward: -300.00, Epsilon: 0.18624, Loss: 0.54805
# Episode 189/1000, Reward: -300.00, Epsilon: 0.18457, Loss: 0.20559
# Episode 190/1000, Reward: -300.00, Epsilon: 0.18292, Loss: 3.25372
# Episode 191/1000, Reward: -300.00, Epsilon: 0.18128, Loss: 0.27089
# Episode 192/1000, Reward: -300.00, Epsilon: 0.17966, Loss: 0.03642
# Episode 193/1000, Reward: -300.00, Epsilon: 0.17805, Loss: 0.05401
# Episode 194/1000, Reward: -300.00, Epsilon: 0.17645, Loss: 0.03119
# Episode 195/1000, Reward: -300.00, Epsilon: 0.17487, Loss: 3.57637
# Episode 196/1000, Reward: -300.00, Epsilon: 0.17330, Loss: 0.21114
# Episode 197/1000, Reward: -300.00, Epsilon: 0.17175, Loss: 0.07098
# Episode 198/1000, Reward: -300.00, Epsilon: 0.17021, Loss: 0.03630
# Episode 199/1000, Reward: -300.00, Epsilon: 0.16869, Loss: 0.03634
# Episode 200/1000, Reward: -300.00, Epsilon: 0.16717, Loss: 0.04788
# Episode 201/1000, Reward: -300.00, Epsilon: 0.16568, Loss: 0.10467
# Episode 202/1000, Reward: -300.00, Epsilon: 0.16419, Loss: 0.07713
# Episode 203/1000, Reward: -300.00, Epsilon: 0.16272, Loss: 2.47811
# Episode 204/1000, Reward: -300.00, Epsilon: 0.16126, Loss: 0.11977
# Episode 205/1000, Reward: -300.00, Epsilon: 0.15982, Loss: 3.82212
# Episode 206/1000, Reward: -300.00, Epsilon: 0.15839, Loss: 0.23237
# Episode 207/1000, Reward: -300.00, Epsilon: 0.15697, Loss: 0.13476
# Episode 208/1000, Reward: -300.00, Epsilon: 0.15556, Loss: 0.11109
# Episode 209/1000, Reward: -300.00, Epsilon: 0.15417, Loss: 0.06287
# Episode 210/1000, Reward: -300.00, Epsilon: 0.15279, Loss: 3.92699
# Episode 211/1000, Reward: -300.00, Epsilon: 0.15142, Loss: 3.46049
# Episode 212/1000, Reward: -300.00, Epsilon: 0.15006, Loss: 0.15960
# Episode 213/1000, Reward: -300.00, Epsilon: 0.14872, Loss: 3.98265
# Episode 214/1000, Reward: -300.00, Epsilon: 0.14738, Loss: 3.32616
# Episode 215/1000, Reward: -300.00, Epsilon: 0.14606, Loss: 0.14112
# Episode 216/1000, Reward: -300.00, Epsilon: 0.14475, Loss: 0.08503
# Episode 217/1000, Reward: -300.00, Epsilon: 0.14346, Loss: 0.02723
# Episode 218/1000, Reward: -300.00, Epsilon: 0.14217, Loss: 0.03520
# Episode 219/1000, Reward: -300.00, Epsilon: 0.14090, Loss: 0.07682
# Episode 220/1000, Reward: -300.00, Epsilon: 0.13964, Loss: 0.05220
# Episode 221/1000, Reward: -300.00, Epsilon: 0.13838, Loss: 0.13818
# Episode 222/1000, Reward: -300.00, Epsilon: 0.13714, Loss: 0.02695
# Episode 223/1000, Reward: -300.00, Epsilon: 0.13592, Loss: 0.16612
# Episode 224/1000, Reward: -300.00, Epsilon: 0.13470, Loss: 0.12723
# Episode 225/1000, Reward: -300.00, Epsilon: 0.13349, Loss: 0.06773
# Episode 226/1000, Reward: -300.00, Epsilon: 0.13230, Loss: 3.98488
# Episode 227/1000, Reward: -300.00, Epsilon: 0.13111, Loss: 1.12605
# Episode 228/1000, Reward: -300.00, Epsilon: 0.12994, Loss: 0.04660
# Episode 229/1000, Reward: -300.00, Epsilon: 0.12877, Loss: 8.92375
# Episode 230/1000, Reward: -300.00, Epsilon: 0.12762, Loss: 0.04073
# Episode 231/1000, Reward: -300.00, Epsilon: 0.12647, Loss: 0.11649
# Episode 232/1000, Reward: -300.00, Epsilon: 0.12534, Loss: 3.79858
# Episode 233/1000, Reward: -300.00, Epsilon: 0.12422, Loss: 0.11367
# Episode 234/1000, Reward: -300.00, Epsilon: 0.12310, Loss: 0.09989
# Episode 235/1000, Reward: -300.00, Epsilon: 0.12200, Loss: 0.16036
# Episode 236/1000, Reward: -300.00, Epsilon: 0.12091, Loss: 0.12667
# Episode 237/1000, Reward: -300.00, Epsilon: 0.11983, Loss: 0.13990
# Episode 238/1000, Reward: -300.00, Epsilon: 0.11875, Loss: 0.15064
# Episode 239/1000, Reward: -300.00, Epsilon: 0.11769, Loss: 0.21895
# Episode 240/1000, Reward: -300.00, Epsilon: 0.11663, Loss: 0.13302
# Episode 241/1000, Reward: -300.00, Epsilon: 0.11559, Loss: 0.10545
# Episode 242/1000, Reward: -300.00, Epsilon: 0.11455, Loss: 0.07542
# Episode 243/1000, Reward: -300.00, Epsilon: 0.11353, Loss: 0.11361
# Episode 244/1000, Reward: -300.00, Epsilon: 0.11251, Loss: 0.16191
# Episode 245/1000, Reward: -300.00, Epsilon: 0.11150, Loss: 0.13645
# Episode 246/1000, Reward: -300.00, Epsilon: 0.11050, Loss: 5.00829
# Episode 247/1000, Reward: -300.00, Epsilon: 0.10951, Loss: 0.30571
# Episode 248/1000, Reward: -300.00, Epsilon: 0.10853, Loss: 0.13841
# Episode 249/1000, Reward: -300.00, Epsilon: 0.10756, Loss: 0.24616
# Episode 250/1000, Reward: -300.00, Epsilon: 0.10659, Loss: 0.09389
# Episode 251/1000, Reward: -300.00, Epsilon: 0.10564, Loss: 5.70208
# Episode 252/1000, Reward: -300.00, Epsilon: 0.10469, Loss: 6.83677
# Episode 253/1000, Reward: -300.00, Epsilon: 0.10375, Loss: 4.95885
# Episode 254/1000, Reward: -300.00, Epsilon: 0.10283, Loss: 1.69538
# Episode 255/1000, Reward: -300.00, Epsilon: 0.10190, Loss: 0.06864
# Episode 256/1000, Reward: -300.00, Epsilon: 0.10099, Loss: 0.40084
# Episode 257/1000, Reward: -300.00, Epsilon: 0.10009, Loss: 0.12606
# Episode 258/1000, Reward: -300.00, Epsilon: 0.09919, Loss: 94.54119
# Episode 259/1000, Reward: -300.00, Epsilon: 0.09830, Loss: 0.19169
# Episode 260/1000, Reward: -300.00, Epsilon: 0.09742, Loss: 5.17760
# Episode 261/1000, Reward: -300.00, Epsilon: 0.09655, Loss: 5.79082
# Episode 262/1000, Reward: -300.00, Epsilon: 0.09568, Loss: 0.13373
# Episode 263/1000, Reward: -300.00, Epsilon: 0.09482, Loss: 5.96289
# Episode 264/1000, Reward: -300.00, Epsilon: 0.09398, Loss: 0.11357
# Episode 265/1000, Reward: -300.00, Epsilon: 0.09313, Loss: 0.17610
# Episode 266/1000, Reward: -300.00, Epsilon: 0.09230, Loss: 5.16880
# Episode 267/1000, Reward: -300.00, Epsilon: 0.09147, Loss: 0.11574
# Episode 268/1000, Reward: -300.00, Epsilon: 0.09065, Loss: 0.31419
# Episode 269/1000, Reward: -300.00, Epsilon: 0.08984, Loss: 5.84817
# Episode 270/1000, Reward: -300.00, Epsilon: 0.08903, Loss: 5.08868
# Episode 271/1000, Reward: -300.00, Epsilon: 0.08824, Loss: 106.62346
# Episode 272/1000, Reward: -300.00, Epsilon: 0.08745, Loss: 4.98142
# Episode 273/1000, Reward: -300.00, Epsilon: 0.08666, Loss: 0.26087
# Episode 274/1000, Reward: -300.00, Epsilon: 0.08589, Loss: 0.23144
# Episode 275/1000, Reward: -300.00, Epsilon: 0.08512, Loss: 0.09385
# Episode 276/1000, Reward: -300.00, Epsilon: 0.08435, Loss: 0.13591
# Episode 277/1000, Reward: -300.00, Epsilon: 0.08360, Loss: 0.07920
# Episode 278/1000, Reward: -300.00, Epsilon: 0.08285, Loss: 0.19996
# Episode 279/1000, Reward: -300.00, Epsilon: 0.08211, Loss: 0.06653
# Episode 280/1000, Reward: -300.00, Epsilon: 0.08137, Loss: 0.70278
# Episode 281/1000, Reward: -300.00, Epsilon: 0.08064, Loss: 0.17524
# Episode 282/1000, Reward: -300.00, Epsilon: 0.07992, Loss: 0.14300
# Episode 283/1000, Reward: -300.00, Epsilon: 0.07920, Loss: 0.12197
# Episode 284/1000, Reward: -300.00, Epsilon: 0.07849, Loss: 4.54576
# Episode 285/1000, Reward: -300.00, Epsilon: 0.07779, Loss: 0.23775
# Episode 286/1000, Reward: -300.00, Epsilon: 0.07709, Loss: 0.14299
# Episode 287/1000, Reward: -300.00, Epsilon: 0.07640, Loss: 0.21574
# Episode 288/1000, Reward: -300.00, Epsilon: 0.07572, Loss: 0.15633
# Episode 289/1000, Reward: -300.00, Epsilon: 0.07504, Loss: 0.25467
# Episode 290/1000, Reward: -300.00, Epsilon: 0.07437, Loss: 6.65341
# Episode 291/1000, Reward: -300.00, Epsilon: 0.07370, Loss: 0.48314
# Episode 292/1000, Reward: -300.00, Epsilon: 0.07304, Loss: 0.17516
# Episode 293/1000, Reward: -300.00, Epsilon: 0.07239, Loss: 0.29287
# Episode 294/1000, Reward: -300.00, Epsilon: 0.07174, Loss: 0.16563
# Episode 295/1000, Reward: -300.00, Epsilon: 0.07110, Loss: 0.16146
# Episode 296/1000, Reward: -300.00, Epsilon: 0.07046, Loss: 0.22473
# Episode 297/1000, Reward: -300.00, Epsilon: 0.06983, Loss: 6.24679
# Episode 298/1000, Reward: -300.00, Epsilon: 0.06920, Loss: 0.09636
# Episode 299/1000, Reward: -300.00, Epsilon: 0.06858, Loss: 0.28111
# Episode 300/1000, Reward: -300.00, Epsilon: 0.06797, Loss: 0.17670
# Episode 301/1000, Reward: -300.00, Epsilon: 0.06736, Loss: 0.13065
# Episode 302/1000, Reward: -300.00, Epsilon: 0.06675, Loss: 0.30584
# Episode 303/1000, Reward: -300.00, Epsilon: 0.06616, Loss: 0.46400
# Episode 304/1000, Reward: -300.00, Epsilon: 0.06556, Loss: 0.17899
# Episode 305/1000, Reward: -300.00, Epsilon: 0.06498, Loss: 0.10380
# Episode 306/1000, Reward: -300.00, Epsilon: 0.06439, Loss: 0.18307
# Episode 307/1000, Reward: -300.00, Epsilon: 0.06382, Loss: 5.48786
# Episode 308/1000, Reward: -300.00, Epsilon: 0.06325, Loss: 0.25646
# Episode 309/1000, Reward: -300.00, Epsilon: 0.06268, Loss: 0.26385
# Episode 310/1000, Reward: -300.00, Epsilon: 0.06212, Loss: 0.22120
# Episode 311/1000, Reward: -300.00, Epsilon: 0.06156, Loss: 0.17191
# Episode 312/1000, Reward: -300.00, Epsilon: 0.06101, Loss: 0.24181
# Episode 313/1000, Reward: -300.00, Epsilon: 0.06046, Loss: 0.22996
# Episode 314/1000, Reward: -300.00, Epsilon: 0.05992, Loss: 0.14209
# Episode 315/1000, Reward: -300.00, Epsilon: 0.05938, Loss: 0.18664
# Episode 316/1000, Reward: -300.00, Epsilon: 0.05885, Loss: 0.19126
# Episode 317/1000, Reward: -300.00, Epsilon: 0.05832, Loss: 0.22242
# Episode 318/1000, Reward: -300.00, Epsilon: 0.05780, Loss: 0.11285
# Episode 319/1000, Reward: -300.00, Epsilon: 0.05728, Loss: 0.11461
# Episode 320/1000, Reward: -300.00, Epsilon: 0.05677, Loss: 0.10898
# Episode 321/1000, Reward: -300.00, Epsilon: 0.05626, Loss: 0.44743
# Episode 322/1000, Reward: -300.00, Epsilon: 0.05576, Loss: 0.17957
# Episode 323/1000, Reward: -300.00, Epsilon: 0.05526, Loss: 0.14995
# Episode 324/1000, Reward: -300.00, Epsilon: 0.05476, Loss: 7.86762
# Episode 325/1000, Reward: -300.00, Epsilon: 0.05427, Loss: 0.38529
# Episode 326/1000, Reward: -300.00, Epsilon: 0.05379, Loss: 0.17758
# Episode 327/1000, Reward: -300.00, Epsilon: 0.05330, Loss: 0.20661
# Episode 328/1000, Reward: -300.00, Epsilon: 0.05283, Loss: 0.33774
# Episode 329/1000, Reward: -300.00, Epsilon: 0.05235, Loss: 5.94511
# Episode 330/1000, Reward: -300.00, Epsilon: 0.05188, Loss: 0.21640
# Episode 331/1000, Reward: -300.00, Epsilon: 0.05142, Loss: 0.24658
# Episode 332/1000, Reward: -300.00, Epsilon: 0.05096, Loss: 0.45663
# Episode 333/1000, Reward: -300.00, Epsilon: 0.05050, Loss: 0.36657
# Episode 334/1000, Reward: -300.00, Epsilon: 0.05005, Loss: 6.90610
# Episode 335/1000, Reward: -300.00, Epsilon: 0.04960, Loss: 0.13281
# Episode 336/1000, Reward: -300.00, Epsilon: 0.04916, Loss: 0.31507
# Episode 337/1000, Reward: -300.00, Epsilon: 0.04872, Loss: 0.14846
# Episode 338/1000, Reward: -300.00, Epsilon: 0.04828, Loss: 0.16453
# Episode 339/1000, Reward: -300.00, Epsilon: 0.04785, Loss: 0.29992
# Episode 340/1000, Reward: -300.00, Epsilon: 0.04742, Loss: 0.17050
# Episode 341/1000, Reward: -300.00, Epsilon: 0.04699, Loss: 7.91565
# Episode 342/1000, Reward: -300.00, Epsilon: 0.04657, Loss: 17.87742
# Episode 343/1000, Reward: -300.00, Epsilon: 0.04616, Loss: 8.71222
# Episode 344/1000, Reward: -67.00, Epsilon: 0.04592, Loss: 0.21781
# Episode 345/1000, Reward: -300.00, Epsilon: 0.04551, Loss: 0.42936
# Episode 346/1000, Reward: -300.00, Epsilon: 0.04510, Loss: 8.59139
# Episode 347/1000, Reward: -300.00, Epsilon: 0.04470, Loss: 0.17358
# Episode 348/1000, Reward: -19.00, Epsilon: 0.04454, Loss: 5.79819
# Episode 349/1000, Reward: -300.00, Epsilon: 0.04414, Loss: 0.30937
# Episode 350/1000, Reward: -300.00, Epsilon: 0.04375, Loss: 8.04517
# Episode 351/1000, Reward: -152.00, Epsilon: 0.04341, Loss: 0.52889
# Episode 352/1000, Reward: -300.00, Epsilon: 0.04303, Loss: 0.38480
# Episode 353/1000, Reward:  54.00, Epsilon: 0.04296, Loss: 0.23093
# Episode 354/1000, Reward: -300.00, Epsilon: 0.04258, Loss: 1.70319
# Episode 355/1000, Reward: -300.00, Epsilon: 0.04220, Loss: 0.20110
# Episode 356/1000, Reward: -300.00, Epsilon: 0.04182, Loss: 0.28098
# Episode 357/1000, Reward: -300.00, Epsilon: 0.04145, Loss: 0.34036
# Episode 358/1000, Reward: -300.00, Epsilon: 0.04107, Loss: 0.34087
# Episode 359/1000, Reward: -300.00, Epsilon: 0.04071, Loss: 0.29944
# Episode 360/1000, Reward: -300.00, Epsilon: 0.04034, Loss: 0.15727
# Episode 361/1000, Reward: -300.00, Epsilon: 0.03998, Loss: 0.22846
# Episode 362/1000, Reward: -300.00, Epsilon: 0.03962, Loss: 0.26234
# Episode 363/1000, Reward: -300.00, Epsilon: 0.03927, Loss: 17.61378
# Episode 364/1000, Reward: -156.00, Epsilon: 0.03897, Loss: 0.20937
# Episode 365/1000, Reward: -300.00, Epsilon: 0.03862, Loss: 0.30350
# Episode 366/1000, Reward:  57.00, Epsilon: 0.03857, Loss: 0.27373
# Episode 367/1000, Reward: -300.00, Epsilon: 0.03822, Loss: 1.88402
# Episode 368/1000, Reward: -113.00, Epsilon: 0.03797, Loss: 0.14507
# Episode 369/1000, Reward: -300.00, Epsilon: 0.03763, Loss: 0.24311
# Episode 370/1000, Reward: -300.00, Epsilon: 0.03730, Loss: 0.27697
# Episode 371/1000, Reward: -300.00, Epsilon: 0.03696, Loss: 0.43396
# Episode 372/1000, Reward: -300.00, Epsilon: 0.03663, Loss: 0.22494
# Episode 373/1000, Reward:  59.00, Epsilon: 0.03659, Loss: 0.18913
# Episode 374/1000, Reward:  48.00, Epsilon: 0.03653, Loss: 0.23861
# Episode 375/1000, Reward: -300.00, Epsilon: 0.03620, Loss: 0.27535
# Episode 376/1000, Reward: -300.00, Epsilon: 0.03588, Loss: 175.15642
# Episode 377/1000, Reward: -300.00, Epsilon: 0.03555, Loss: 0.41944
# Episode 378/1000, Reward: -300.00, Epsilon: 0.03524, Loss: 0.50279
# Episode 379/1000, Reward: -300.00, Epsilon: 0.03492, Loss: 1.90529
# Episode 380/1000, Reward: -300.00, Epsilon: 0.03461, Loss: 15.06145
# Episode 381/1000, Reward: -300.00, Epsilon: 0.03430, Loss: 154.26593
# Episode 382/1000, Reward: -300.00, Epsilon: 0.03399, Loss: 0.51336
# Episode 383/1000, Reward: -300.00, Epsilon: 0.03369, Loss: 0.23232
# Episode 384/1000, Reward: -300.00, Epsilon: 0.03338, Loss: 0.42844
# Episode 385/1000, Reward: -300.00, Epsilon: 0.03308, Loss: 0.14247
# Episode 386/1000, Reward: -300.00, Epsilon: 0.03279, Loss: 0.29995
# Episode 387/1000, Reward: -300.00, Epsilon: 0.03249, Loss: 0.42675
# Episode 388/1000, Reward: -69.00, Epsilon: 0.03233, Loss: 0.24696
# Episode 389/1000, Reward: -300.00, Epsilon: 0.03204, Loss: 5.80693
# Episode 390/1000, Reward: -300.00, Epsilon: 0.03175, Loss: 0.46651
# Episode 391/1000, Reward: -300.00, Epsilon: 0.03147, Loss: 0.17060
# Episode 392/1000, Reward: -300.00, Epsilon: 0.03119, Loss: 2.07120
# Episode 393/1000, Reward: -300.00, Epsilon: 0.03091, Loss: 0.51518
# Episode 394/1000, Reward: -150.00, Epsilon: 0.03067, Loss: 0.19376
# Episode 395/1000, Reward: -300.00, Epsilon: 0.03040, Loss: 0.32421
# Episode 396/1000, Reward: -300.00, Epsilon: 0.03013, Loss: 1.40482
# Episode 397/1000, Reward: -300.00, Epsilon: 0.02986, Loss: 10.00838
# Episode 398/1000, Reward: -300.00, Epsilon: 0.02959, Loss: 0.20187
# Episode 399/1000, Reward: -300.00, Epsilon: 0.02933, Loss: 0.18880
# Episode 400/1000, Reward: -300.00, Epsilon: 0.02906, Loss: 12.07884
# Episode 401/1000, Reward: -300.00, Epsilon: 0.02880, Loss: 0.19280
# Episode 402/1000, Reward: -300.00, Epsilon: 0.02854, Loss: 0.06137
# Episode 403/1000, Reward: -300.00, Epsilon: 0.02829, Loss: 0.24461
# Episode 404/1000, Reward: -300.00, Epsilon: 0.02803, Loss: 0.18742
# Episode 405/1000, Reward: -300.00, Epsilon: 0.02778, Loss: 9.30024
# Episode 406/1000, Reward: -300.00, Epsilon: 0.02753, Loss: 8.06014
# Episode 407/1000, Reward:  33.00, Epsilon: 0.02748, Loss: 0.28863
# Episode 408/1000, Reward: -300.00, Epsilon: 0.02723, Loss: 0.34924
# Episode 409/1000, Reward: -300.00, Epsilon: 0.02699, Loss: 16.74879
# Episode 410/1000, Reward: -300.00, Epsilon: 0.02675, Loss: 0.36573
# Episode 411/1000, Reward: -300.00, Epsilon: 0.02651, Loss: 0.61034
# Episode 412/1000, Reward: -300.00, Epsilon: 0.02627, Loss: 0.34643
# Episode 413/1000, Reward: -300.00, Epsilon: 0.02603, Loss: 117.76164
# Episode 414/1000, Reward: -300.00, Epsilon: 0.02580, Loss: 0.39079
# Episode 415/1000, Reward: -300.00, Epsilon: 0.02557, Loss: 0.37726
# Episode 416/1000, Reward: -300.00, Epsilon: 0.02534, Loss: 5.45449
# Episode 417/1000, Reward: -300.00, Epsilon: 0.02511, Loss: 9.82800
# Episode 418/1000, Reward: -300.00, Epsilon: 0.02489, Loss: 0.28761
# Episode 419/1000, Reward: -300.00, Epsilon: 0.02467, Loss: 0.12228
# Episode 420/1000, Reward: -300.00, Epsilon: 0.02444, Loss: 10.63420
# Episode 421/1000, Reward: -300.00, Epsilon: 0.02423, Loss: 5.06881
# Episode 422/1000, Reward: -300.00, Epsilon: 0.02401, Loss: 3.94132
# Episode 423/1000, Reward: -300.00, Epsilon: 0.02379, Loss: 0.34999
# Episode 424/1000, Reward: -300.00, Epsilon: 0.02358, Loss: 0.52780
# Episode 425/1000, Reward: -300.00, Epsilon: 0.02337, Loss: 0.28284
# Episode 426/1000, Reward: -300.00, Epsilon: 0.02316, Loss: 0.40128
# Episode 427/1000, Reward: -300.00, Epsilon: 0.02295, Loss: 0.36754
# Episode 428/1000, Reward: -300.00, Epsilon: 0.02275, Loss: 0.22711
# Episode 429/1000, Reward: -300.00, Epsilon: 0.02254, Loss: 0.35062
# Episode 430/1000, Reward: -300.00, Epsilon: 0.02234, Loss: 0.29251
# Episode 431/1000, Reward: -300.00, Epsilon: 0.02214, Loss: 21.57033
# Episode 432/1000, Reward: -300.00, Epsilon: 0.02194, Loss: 0.93112
# Episode 433/1000, Reward: -300.00, Epsilon: 0.02175, Loss: 25.08945
# Episode 434/1000, Reward: -300.00, Epsilon: 0.02155, Loss: 0.55964
# Episode 435/1000, Reward: -300.00, Epsilon: 0.02136, Loss: 7.68179
# Episode 436/1000, Reward: -300.00, Epsilon: 0.02117, Loss: 11.51039
# Episode 437/1000, Reward: -300.00, Epsilon: 0.02098, Loss: 12.24164
# Episode 438/1000, Reward: -300.00, Epsilon: 0.02079, Loss: 6.10870
# Episode 439/1000, Reward: -300.00, Epsilon: 0.02060, Loss: 15.08246
# Episode 440/1000, Reward: -300.00, Epsilon: 0.02042, Loss: 0.22656
# Episode 441/1000, Reward: -300.00, Epsilon: 0.02023, Loss: 11.37109
# Episode 442/1000, Reward: -300.00, Epsilon: 0.02005, Loss: 13.14004
# Episode 443/1000, Reward: -300.00, Epsilon: 0.01987, Loss: 0.66345
# Episode 444/1000, Reward: -300.00, Epsilon: 0.01970, Loss: 9.33324
# Episode 445/1000, Reward: -300.00, Epsilon: 0.01952, Loss: 9.11312
# Episode 446/1000, Reward: -300.00, Epsilon: 0.01934, Loss: 0.42811
# Episode 447/1000, Reward: -300.00, Epsilon: 0.01917, Loss: 1.45414
# Episode 448/1000, Reward: -300.00, Epsilon: 0.01900, Loss: 0.34603
# Episode 449/1000, Reward: -300.00, Epsilon: 0.01883, Loss: 0.66780
# Episode 450/1000, Reward: -300.00, Epsilon: 0.01866, Loss: 0.22094
# Episode 451/1000, Reward: -300.00, Epsilon: 0.01849, Loss: 0.87820
# Episode 452/1000, Reward: -300.00, Epsilon: 0.01833, Loss: 0.38645
# Episode 453/1000, Reward: -300.00, Epsilon: 0.01816, Loss: 0.51663
# Episode 454/1000, Reward: -300.00, Epsilon: 0.01800, Loss: 0.92132
# Episode 455/1000, Reward: -300.00, Epsilon: 0.01784, Loss: 9.75720
# Episode 456/1000, Reward: -300.00, Epsilon: 0.01768, Loss: 0.99066
# Episode 457/1000, Reward: -300.00, Epsilon: 0.01752, Loss: 0.45216
# Episode 458/1000, Reward: -300.00, Epsilon: 0.01736, Loss: 11.48783
# Episode 459/1000, Reward: -300.00, Epsilon: 0.01721, Loss: 0.51619
# Episode 460/1000, Reward: -300.00, Epsilon: 0.01705, Loss: 0.32481
# Episode 461/1000, Reward: -300.00, Epsilon: 0.01690, Loss: 0.53659
# Episode 462/1000, Reward: -300.00, Epsilon: 0.01675, Loss: 0.50049
# Episode 463/1000, Reward: -300.00, Epsilon: 0.01660, Loss: 0.59384
# Episode 464/1000, Reward: -300.00, Epsilon: 0.01645, Loss: 7.40115
# Episode 465/1000, Reward: -300.00, Epsilon: 0.01630, Loss: 0.58496
# Episode 466/1000, Reward: -300.00, Epsilon: 0.01616, Loss: 12.83201
# Episode 467/1000, Reward: -300.00, Epsilon: 0.01601, Loss: 0.62223
# Episode 468/1000, Reward: -300.00, Epsilon: 0.01587, Loss: 0.43632
# Episode 469/1000, Reward: -300.00, Epsilon: 0.01573, Loss: 1.59408
# Episode 470/1000, Reward: -300.00, Epsilon: 0.01559, Loss: 0.40472
# Episode 471/1000, Reward: -300.00, Epsilon: 0.01545, Loss: 13.06495
# Episode 472/1000, Reward: -300.00, Epsilon: 0.01531, Loss: 0.68958
# Episode 473/1000, Reward: -300.00, Epsilon: 0.01517, Loss: 0.60983
# Episode 474/1000, Reward: -300.00, Epsilon: 0.01504, Loss: 0.72953
# Episode 475/1000, Reward: -157.00, Epsilon: 0.01492, Loss: 0.51137
# Episode 476/1000, Reward: -300.00, Epsilon: 0.01479, Loss: 0.45562
# Episode 477/1000, Reward: -300.00, Epsilon: 0.01465, Loss: 20.23901
# Episode 478/1000, Reward: -300.00, Epsilon: 0.01452, Loss: 0.59625
# Episode 479/1000, Reward: -300.00, Epsilon: 0.01439, Loss: 0.72749
# Episode 480/1000, Reward: -300.00, Epsilon: 0.01426, Loss: 0.52275
# Episode 481/1000, Reward:  45.00, Epsilon: 0.01424, Loss: 24.50584
# Episode 482/1000, Reward: -300.00, Epsilon: 0.01411, Loss: 0.64706
# Episode 483/1000, Reward: -300.00, Epsilon: 0.01398, Loss: 0.53251
# Episode 484/1000, Reward: -300.00, Epsilon: 0.01386, Loss: 0.57080
# Episode 485/1000, Reward: -300.00, Epsilon: 0.01374, Loss: 0.53036
# Episode 486/1000, Reward: -300.00, Epsilon: 0.01361, Loss: 0.85342
# Episode 487/1000, Reward: -300.00, Epsilon: 0.01349, Loss: 0.82820
# Episode 488/1000, Reward: -300.00, Epsilon: 0.01337, Loss: 0.72826
# Episode 489/1000, Reward: -300.00, Epsilon: 0.01325, Loss: 0.96952
# Episode 490/1000, Reward: -300.00, Epsilon: 0.01313, Loss: 2.08693
# Episode 491/1000, Reward: -300.00, Epsilon: 0.01301, Loss: 10.74724
# Episode 492/1000, Reward: -300.00, Epsilon: 0.01290, Loss: 2.00278
# Episode 493/1000, Reward: -300.00, Epsilon: 0.01278, Loss: 0.40258
# Episode 494/1000, Reward: -300.00, Epsilon: 0.01267, Loss: 0.42352
# Episode 495/1000, Reward: -300.00, Epsilon: 0.01255, Loss: 0.51026
# Episode 496/1000, Reward: -300.00, Epsilon: 0.01244, Loss: 0.34092
# Episode 497/1000, Reward: -300.00, Epsilon: 0.01233, Loss: 9.84532
# Episode 498/1000, Reward: -300.00, Epsilon: 0.01222, Loss: 1.50392
# Episode 499/1000, Reward: -300.00, Epsilon: 0.01211, Loss: 1.08983
# Episode 500/1000, Reward: -300.00, Epsilon: 0.01200, Loss: 1.43818
# Episode 501/1000, Reward: -300.00, Epsilon: 0.01189, Loss: 3.96881
# Episode 502/1000, Reward: -300.00, Epsilon: 0.01179, Loss: 13.51728
# Episode 503/1000, Reward: -300.00, Epsilon: 0.01168, Loss: 2.56094
# Episode 504/1000, Reward: -300.00, Epsilon: 0.01158, Loss: 1.65570
# Episode 505/1000, Reward: -300.00, Epsilon: 0.01147, Loss: 2.22344
# Episode 506/1000, Reward: -300.00, Epsilon: 0.01137, Loss: 86.59959
# Episode 507/1000, Reward: -300.00, Epsilon: 0.01127, Loss: 0.70075
# Episode 508/1000, Reward: -300.00, Epsilon: 0.01117, Loss: 0.54869
# Episode 509/1000, Reward: -300.00, Epsilon: 0.01107, Loss: 0.57272
# Episode 510/1000, Reward: -300.00, Epsilon: 0.01097, Loss: 1.33326
# Episode 511/1000, Reward: -300.00, Epsilon: 0.01087, Loss: 0.84503
# Episode 512/1000, Reward: -300.00, Epsilon: 0.01077, Loss: 2.38374
# Episode 513/1000, Reward: -60.00, Epsilon: 0.01072, Loss: 1.19856
# Episode 514/1000, Reward: -151.00, Epsilon: 0.01064, Loss: 11.77479
# Episode 515/1000, Reward: -300.00, Epsilon: 0.01054, Loss: 1.21198
# Episode 516/1000, Reward: -300.00, Epsilon: 0.01045, Loss: 9.23195
# Episode 517/1000, Reward: -300.00, Epsilon: 0.01036, Loss: 5.94670
# Episode 518/1000, Reward: -300.00, Epsilon: 0.01026, Loss: 1.67969
# Episode 519/1000, Reward: -300.00, Epsilon: 0.01017, Loss: 2.07200
# Episode 520/1000, Reward: -300.00, Epsilon: 0.01008, Loss: 14.17257
# Episode 521/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 2.63778
# Episode 522/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.22560
# Episode 523/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 2.34751
# Episode 524/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 3.76808
# Episode 525/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.85247
# Episode 526/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.00353
# Episode 527/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.97711
# Episode 528/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 0.34106
# Episode 529/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 2.75104
# Episode 530/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 72.22256
# Episode 531/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 15.59349
# Episode 532/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 19.62613
# Episode 533/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.51187
# Episode 534/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 8.52716
# Episode 535/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 18.56092
# Episode 536/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 1.40769
# Episode 537/1000, Reward: -167.00, Epsilon: 0.01000, Loss: 4.80532
# Episode 538/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.09839
# Episode 539/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.10447
# Episode 540/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.69504
# Episode 541/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 0.95789
# Episode 542/1000, Reward:  -5.00, Epsilon: 0.01000, Loss: 0.58799
# Episode 543/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.75071
# Episode 544/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.57756
# Episode 545/1000, Reward:  28.00, Epsilon: 0.01000, Loss: 1.62622
# Episode 546/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.74730
# Episode 547/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 18.70933
# Episode 548/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.24357
# Episode 549/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.05848
# Episode 550/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.43556
# Episode 551/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 2.52808
# Episode 552/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 0.75955
# Episode 553/1000, Reward: -137.00, Epsilon: 0.01000, Loss: 0.93694
# Episode 554/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 2.00547
# Episode 555/1000, Reward: -68.00, Epsilon: 0.01000, Loss: 1.10729
# Episode 556/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.08700
# Episode 557/1000, Reward: -190.00, Epsilon: 0.01000, Loss: 1.31628
# Episode 558/1000, Reward: -20.00, Epsilon: 0.01000, Loss: 1.35813
# Episode 559/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 11.76817
# Episode 560/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.01979
# Episode 561/1000, Reward: -41.00, Epsilon: 0.01000, Loss: 1.27630
# Episode 562/1000, Reward: -46.00, Epsilon: 0.01000, Loss: 1.18486
# Episode 563/1000, Reward: -31.00, Epsilon: 0.01000, Loss: 5.75214
# Episode 564/1000, Reward:  -4.00, Epsilon: 0.01000, Loss: 124.44758
# Episode 565/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 2.80599
# Episode 566/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.45199
# Episode 567/1000, Reward: -170.00, Epsilon: 0.01000, Loss: 14.22962
# Episode 568/1000, Reward: -179.00, Epsilon: 0.01000, Loss: 21.32208
# Episode 569/1000, Reward: -48.00, Epsilon: 0.01000, Loss: 0.92306
# Episode 570/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.40572
# Episode 571/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.82509
# Episode 572/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.77888
# Episode 573/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.70776
# Episode 574/1000, Reward: -93.00, Epsilon: 0.01000, Loss: 1.50623
# Episode 575/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 0.86775
# Episode 576/1000, Reward: -24.00, Epsilon: 0.01000, Loss: 0.90699
# Episode 577/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.71578
# Episode 578/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.74262
# Episode 579/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.85609
# Episode 580/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 3.41519
# Episode 581/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.53539
# Episode 582/1000, Reward:  40.00, Epsilon: 0.01000, Loss: 1.04160
# Episode 583/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.20109
# Episode 584/1000, Reward: -97.00, Epsilon: 0.01000, Loss: 1.51494
# Episode 585/1000, Reward: -47.00, Epsilon: 0.01000, Loss: 3.93388
# Episode 586/1000, Reward: -187.00, Epsilon: 0.01000, Loss: 1.29245
# Episode 587/1000, Reward:  40.00, Epsilon: 0.01000, Loss: 0.94912
# Episode 588/1000, Reward:  31.00, Epsilon: 0.01000, Loss: 2.08375
# Episode 589/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 0.64341
# Episode 590/1000, Reward:  -3.00, Epsilon: 0.01000, Loss: 1.14800
# Episode 591/1000, Reward:  38.00, Epsilon: 0.01000, Loss: 1.32808
# Episode 592/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 1.34341
# Episode 593/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 5.32599
# Episode 594/1000, Reward: -23.00, Epsilon: 0.01000, Loss: 1.34136
# Episode 595/1000, Reward:  12.00, Epsilon: 0.01000, Loss: 0.69382
# Episode 596/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 0.84910
# Episode 597/1000, Reward: -124.00, Epsilon: 0.01000, Loss: 4.14627
# Episode 598/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.96338
# Episode 599/1000, Reward: -129.00, Epsilon: 0.01000, Loss: 14.04022
# Episode 600/1000, Reward: -49.00, Epsilon: 0.01000, Loss: 0.84633
# Episode 601/1000, Reward: -14.00, Epsilon: 0.01000, Loss: 8.82418
# Episode 602/1000, Reward: -51.00, Epsilon: 0.01000, Loss: 0.69337
# Episode 603/1000, Reward: -24.00, Epsilon: 0.01000, Loss: 5.49398
# Episode 604/1000, Reward: -82.00, Epsilon: 0.01000, Loss: 1.16523
# Episode 605/1000, Reward:  37.00, Epsilon: 0.01000, Loss: 1.11681
# Episode 606/1000, Reward:  48.00, Epsilon: 0.01000, Loss: 1.84857
# Episode 607/1000, Reward:  -9.00, Epsilon: 0.01000, Loss: 0.92334
# Episode 608/1000, Reward:  60.00, Epsilon: 0.01000, Loss: 21.27471
# Episode 609/1000, Reward: -95.00, Epsilon: 0.01000, Loss: 2.83158
# Episode 610/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 0.91502
# Episode 611/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 0.71760
# Episode 612/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 1.30829
# Episode 613/1000, Reward:  59.00, Epsilon: 0.01000, Loss: 1.91555
# Episode 614/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 0.78870
# Episode 615/1000, Reward: -10.00, Epsilon: 0.01000, Loss: 7.98727
# Episode 616/1000, Reward: -85.00, Epsilon: 0.01000, Loss: 2.30393
# Episode 617/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 1.88710
# Episode 618/1000, Reward: -83.00, Epsilon: 0.01000, Loss: 1.32783
# Episode 619/1000, Reward:   1.00, Epsilon: 0.01000, Loss: 9.40168
# Episode 620/1000, Reward: -163.00, Epsilon: 0.01000, Loss: 1.28302
# Episode 621/1000, Reward: -178.00, Epsilon: 0.01000, Loss: 2.01171
# Episode 622/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 3.15539
# Episode 623/1000, Reward: -145.00, Epsilon: 0.01000, Loss: 158.35656
# Episode 624/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 154.82228
# Episode 625/1000, Reward: -114.00, Epsilon: 0.01000, Loss: 15.21357
# Episode 626/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 1.23483
# Episode 627/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 6.54885
# Episode 628/1000, Reward:  62.00, Epsilon: 0.01000, Loss: 1.11524
# Episode 629/1000, Reward: -39.00, Epsilon: 0.01000, Loss: 164.94904
# Episode 630/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 3.86542
# Episode 631/1000, Reward: -75.00, Epsilon: 0.01000, Loss: 13.84825
# Episode 632/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 17.44825
# Episode 633/1000, Reward:  -6.00, Epsilon: 0.01000, Loss: 2.66408
# Episode 634/1000, Reward:  14.00, Epsilon: 0.01000, Loss: 2.01662
# Episode 635/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 2.25297
# Episode 636/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 1.66167
# Episode 637/1000, Reward: -139.00, Epsilon: 0.01000, Loss: 165.35716
# Episode 638/1000, Reward: -300.00, Epsilon: 0.01000, Loss: 2.45467
# Episode 639/1000, Reward:  48.00, Epsilon: 0.01000, Loss: 2.55604
# Episode 640/1000, Reward: -85.00, Epsilon: 0.01000, Loss: 1.47542
# Episode 641/1000, Reward: -73.00, Epsilon: 0.01000, Loss: 10.60489
# Episode 642/1000, Reward:  23.00, Epsilon: 0.01000, Loss: 2.12974
# Episode 643/1000, Reward:  32.00, Epsilon: 0.01000, Loss: 35.75641
# Episode 644/1000, Reward:  37.00, Epsilon: 0.01000, Loss: 3.04717
# Episode 645/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 2.71958
# Episode 646/1000, Reward: -196.00, Epsilon: 0.01000, Loss: 74.41299
# Episode 647/1000, Reward:  40.00, Epsilon: 0.01000, Loss: 7.10826
# Episode 648/1000, Reward: -133.00, Epsilon: 0.01000, Loss: 2.00871
# Episode 649/1000, Reward: -134.00, Epsilon: 0.01000, Loss: 5.39080
# Episode 650/1000, Reward: -179.00, Epsilon: 0.01000, Loss: 4.17456
# Episode 651/1000, Reward: -52.00, Epsilon: 0.01000, Loss: 1.31363
# Episode 652/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 1.21206
# Episode 653/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 2.86741
# Episode 654/1000, Reward:  40.00, Epsilon: 0.01000, Loss: 0.53685
# Episode 655/1000, Reward:  35.00, Epsilon: 0.01000, Loss: 8.73112
# Episode 656/1000, Reward:  60.00, Epsilon: 0.01000, Loss: 1.08624
# Episode 657/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 2.68508
# Episode 658/1000, Reward:  11.00, Epsilon: 0.01000, Loss: 1.48895
# Episode 659/1000, Reward:  39.00, Epsilon: 0.01000, Loss: 7.01725
# Episode 660/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 7.84884
# Episode 661/1000, Reward:  59.00, Epsilon: 0.01000, Loss: 1.84789
# Episode 662/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 2.88779
# Episode 663/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 26.39115
# Episode 664/1000, Reward:  26.00, Epsilon: 0.01000, Loss: 3.86010
# Episode 665/1000, Reward:   7.00, Epsilon: 0.01000, Loss: 21.44863
# Episode 666/1000, Reward:   7.00, Epsilon: 0.01000, Loss: 11.82863
# Episode 667/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 2.12011
# Episode 668/1000, Reward:  36.00, Epsilon: 0.01000, Loss: 1.32386
# Episode 669/1000, Reward:  59.00, Epsilon: 0.01000, Loss: 68.30729
# Episode 670/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 2.06250
# Episode 671/1000, Reward: -151.00, Epsilon: 0.01000, Loss: 8.44736
# Episode 672/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 1.07102
# Episode 673/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 2.63145
# Episode 674/1000, Reward:  17.00, Epsilon: 0.01000, Loss: 1.06457
# Episode 675/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 54.81719
# Episode 676/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 6.75249
# Episode 677/1000, Reward: -58.00, Epsilon: 0.01000, Loss: 93.11583
# Episode 678/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 2.49532
# Episode 679/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 4.29968
# Episode 680/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 2.71182
# Episode 681/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 1.47311
# Episode 682/1000, Reward: -44.00, Epsilon: 0.01000, Loss: 14.72398
# Episode 683/1000, Reward: -118.00, Epsilon: 0.01000, Loss: 19.92141
# Episode 684/1000, Reward:  25.00, Epsilon: 0.01000, Loss: 4.40480
# Episode 685/1000, Reward:  41.00, Epsilon: 0.01000, Loss: 3.22333
# Episode 686/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 5.16265
# Episode 687/1000, Reward: -78.00, Epsilon: 0.01000, Loss: 3.99521
# Episode 688/1000, Reward: -52.00, Epsilon: 0.01000, Loss: 14.09864
# Episode 689/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 1.30045
# Episode 690/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 0.95909
# Episode 691/1000, Reward: -38.00, Epsilon: 0.01000, Loss: 19.36517
# Episode 692/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 2.29044
# Episode 693/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 1.95682
# Episode 694/1000, Reward:  59.00, Epsilon: 0.01000, Loss: 3.51731
# Episode 695/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 6.33709
# Episode 696/1000, Reward:  61.00, Epsilon: 0.01000, Loss: 1.37678
# Episode 697/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 69.26684
# Episode 698/1000, Reward:  61.00, Epsilon: 0.01000, Loss: 2.43138
# Episode 699/1000, Reward:  37.00, Epsilon: 0.01000, Loss: 2.91598
# Episode 700/1000, Reward:  63.00, Epsilon: 0.01000, Loss: 77.89361
# Episode 701/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 3.44600
# Episode 702/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 4.74931
# Episode 703/1000, Reward:   4.00, Epsilon: 0.01000, Loss: 1.54781
# Episode 704/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 2.70515
# Episode 705/1000, Reward: -14.00, Epsilon: 0.01000, Loss: 5.19905
# Episode 706/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 6.43665
# Episode 707/1000, Reward: -106.00, Epsilon: 0.01000, Loss: 1.59277
# Episode 708/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 6.29668
# Episode 709/1000, Reward:  -7.00, Epsilon: 0.01000, Loss: 4.56412
# Episode 710/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 0.68458
# Episode 711/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 1.15150
# Episode 712/1000, Reward:  35.00, Epsilon: 0.01000, Loss: 1.48380
# Episode 713/1000, Reward:  40.00, Epsilon: 0.01000, Loss: 82.97415
# Episode 714/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 3.10597
# Episode 715/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 7.21351
# Episode 716/1000, Reward:  38.00, Epsilon: 0.01000, Loss: 2.07625
# Episode 717/1000, Reward: -73.00, Epsilon: 0.01000, Loss: 16.84567
# Episode 718/1000, Reward:  60.00, Epsilon: 0.01000, Loss: 70.49758
# Episode 719/1000, Reward:  60.00, Epsilon: 0.01000, Loss: 17.46002
# ...
# Episode 761/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 4.41295
# Episode 762/1000, Reward:  41.00, Epsilon: 0.01000, Loss: 2.15049
# Episode 763/1000, Reward:  -4.00, Epsilon: 0.01000, Loss: 42.44496
# Episode 764/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 26.57963
# Episode 765/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 2.94067
# Episode 766/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 1.77599
# Episode 767/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 6.26957
# Episode 768/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 3.55923
# Episode 769/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 1.91906
# Episode 770/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 4.84283
# Episode 771/1000, Reward:  39.00, Epsilon: 0.01000, Loss: 3.05342
# Episode 772/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 1.49609
# Episode 773/1000, Reward:  37.00, Epsilon: 0.01000, Loss: 105.21118
# Episode 774/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 1.75047
# Episode 775/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 2.08558
# Episode 776/1000, Reward:  32.00, Epsilon: 0.01000, Loss: 160.09590
# Episode 777/1000, Reward:  39.00, Epsilon: 0.01000, Loss: 2.92951
# Episode 778/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 79.18314
# Episode 779/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 2.21374
# Episode 780/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 36.08102
# Episode 781/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 30.64792
# Episode 782/1000, Reward: -14.00, Epsilon: 0.01000, Loss: 2.37327
# Episode 783/1000, Reward: -68.00, Epsilon: 0.01000, Loss: 10.93510
# Episode 784/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 13.96009
# Episode 785/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 18.51876
# Episode 786/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 23.32566
# Episode 787/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 4.26706
# Episode 788/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 13.76944
# Episode 789/1000, Reward:  61.00, Epsilon: 0.01000, Loss: 47.69867
# Episode 790/1000, Reward:  -2.00, Epsilon: 0.01000, Loss: 21.36658
# Episode 791/1000, Reward: -15.00, Epsilon: 0.01000, Loss: 12.49448
# Episode 792/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 4.14647
# Episode 793/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 8.25790
# Episode 794/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 3.06711
# Episode 795/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 94.77809
# Episode 796/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 10.80314
# Episode 797/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 2.47338
# Episode 798/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 1.79566
# Episode 799/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 7.31713
# Episode 800/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 5.18393
# Episode 801/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 4.97222
# Episode 802/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 7.34060
# Episode 803/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 5.54669
# Episode 804/1000, Reward:   9.00, Epsilon: 0.01000, Loss: 15.50157
# Episode 805/1000, Reward:   0.00, Epsilon: 0.01000, Loss: 7.93830
# Episode 806/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 18.62501
# Episode 807/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 19.45522
# Episode 808/1000, Reward:  59.00, Epsilon: 0.01000, Loss: 5.65030
# Episode 809/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 5.55549
# Episode 810/1000, Reward:  61.00, Epsilon: 0.01000, Loss: 27.87209
# Episode 811/1000, Reward:  62.00, Epsilon: 0.01000, Loss: 12.38970
# Episode 812/1000, Reward: -15.00, Epsilon: 0.01000, Loss: 5.28153
# Episode 813/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 10.35412
# Episode 814/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 32.66802
# Episode 815/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 24.88714
# Episode 816/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 15.80903
# Episode 817/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 3.85986
# Episode 818/1000, Reward:  60.00, Epsilon: 0.01000, Loss: 6.75878
# Episode 819/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 6.16718
# Episode 820/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 33.73293
# Episode 821/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 16.46985
# Episode 822/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 26.39998
# Episode 823/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 74.96165
# Episode 824/1000, Reward:  40.00, Epsilon: 0.01000, Loss: 8.75167
# Episode 825/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 16.59271
# Episode 826/1000, Reward:  38.00, Epsilon: 0.01000, Loss: 6.85345
# Episode 827/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 59.38353
# Episode 828/1000, Reward:  39.00, Epsilon: 0.01000, Loss: 6.18926
# Episode 829/1000, Reward:  37.00, Epsilon: 0.01000, Loss: 16.94910
# Episode 830/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 38.93623
# Episode 831/1000, Reward:  26.00, Epsilon: 0.01000, Loss: 19.38120
# Episode 832/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 5.41135
# Episode 833/1000, Reward:  48.00, Epsilon: 0.01000, Loss: 5.28903
# Episode 834/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 3.30415
# Episode 835/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 8.52738
# Episode 836/1000, Reward:  34.00, Epsilon: 0.01000, Loss: 85.23635
# Episode 837/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 6.81941
# Episode 838/1000, Reward: -16.00, Epsilon: 0.01000, Loss: 4.15094
# Episode 839/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 109.08891
# Episode 840/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 2.83587
# Episode 841/1000, Reward: -15.00, Epsilon: 0.01000, Loss: 3.71881
# Episode 842/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 12.60868
# Episode 843/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 3.82907
# Episode 844/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 3.28309
# Episode 845/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 2.68924
# Episode 846/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 4.43012
# Episode 847/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 60.19873
# Episode 848/1000, Reward:  48.00, Epsilon: 0.01000, Loss: 4.13448
# Episode 849/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 8.29428
# Episode 850/1000, Reward:  41.00, Epsilon: 0.01000, Loss: 7.42395
# Episode 851/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 7.53779
# Episode 852/1000, Reward:  38.00, Epsilon: 0.01000, Loss: 59.76162
# Episode 853/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 22.48457
# Episode 854/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 6.97398
# Episode 855/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 4.82080
# Episode 856/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 13.38649
# Episode 857/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 14.45186
# Episode 858/1000, Reward:  -5.00, Epsilon: 0.01000, Loss: 22.68729
# Episode 859/1000, Reward:  -9.00, Epsilon: 0.01000, Loss: 6.89436
# Episode 860/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 3.61988
# Episode 861/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 50.56587
# Episode 862/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 2.26394
# Episode 863/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 17.48357
# Episode 864/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 63.80471
# Episode 865/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 4.58325
# Episode 866/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 52.99735
# Episode 867/1000, Reward:  33.00, Epsilon: 0.01000, Loss: 5.33984
# Episode 868/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 5.41751
# Episode 869/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 107.41773
# Episode 870/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 21.04965
# Episode 871/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 12.18674
# Episode 872/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 32.52124
# Episode 873/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 23.29116
# Episode 874/1000, Reward: -28.00, Epsilon: 0.01000, Loss: 15.31795
# Episode 875/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 16.22406
# Episode 876/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 13.13403
# Episode 877/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 2.33168
# Episode 878/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 4.17169
# Episode 879/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 6.98965
# Episode 880/1000, Reward:  29.00, Epsilon: 0.01000, Loss: 2.69458
# Episode 881/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 9.55119
# Episode 882/1000, Reward:  48.00, Epsilon: 0.01000, Loss: 13.26473
# Episode 883/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 7.91844
# Episode 884/1000, Reward:  41.00, Epsilon: 0.01000, Loss: 9.09720
# Episode 885/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 15.50301
# Episode 886/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 80.37933
# Episode 887/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 13.54490
# Episode 888/1000, Reward:  35.00, Epsilon: 0.01000, Loss: 14.29707
# Episode 889/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 12.98419
# Episode 890/1000, Reward: -17.00, Epsilon: 0.01000, Loss: 5.51728
# Episode 891/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 28.95082
# Episode 892/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 16.06785
# Episode 893/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 13.75198
# Episode 894/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 2.42139
# Episode 895/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 2.86236
# Episode 896/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 1.16174
# Episode 897/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 11.64997
# Episode 898/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 10.27712
# Episode 899/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 13.41380
# Episode 900/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 17.60318
# Episode 901/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 21.38353
# Episode 902/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 10.35017
# Episode 903/1000, Reward:  28.00, Epsilon: 0.01000, Loss: 16.76646
# Episode 904/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 4.69198
# Episode 905/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 40.42578
# Episode 906/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 7.32036
# Episode 907/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 4.16611
# Episode 908/1000, Reward:  38.00, Epsilon: 0.01000, Loss: 6.43157
# Episode 909/1000, Reward: -19.00, Epsilon: 0.01000, Loss: 62.07265
# Episode 910/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 2.59274
# Episode 911/1000, Reward:  32.00, Epsilon: 0.01000, Loss: 3.86775
# Episode 912/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 11.25272
# Episode 913/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 95.15967
# Episode 914/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 3.04228
# Episode 915/1000, Reward:  37.00, Epsilon: 0.01000, Loss: 11.58159
# Episode 916/1000, Reward:  60.00, Epsilon: 0.01000, Loss: 2.02183
# Episode 917/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 8.12761
# Episode 918/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 31.63806
# Episode 919/1000, Reward:  44.00, Epsilon: 0.01000, Loss: 14.99001
# Episode 920/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 9.58808
# Episode 921/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 7.46530
# Episode 922/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 10.74476
# Episode 923/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 13.76915
# Episode 924/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 5.70937
# Episode 925/1000, Reward:  61.00, Epsilon: 0.01000, Loss: 7.05229
# Episode 926/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 3.65627
# Episode 927/1000, Reward:  21.00, Epsilon: 0.01000, Loss: 7.52173
# Episode 928/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 4.83552
# Episode 929/1000, Reward:  23.00, Epsilon: 0.01000, Loss: 6.70600
# Episode 930/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 14.26522
# Episode 931/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 22.60627
# Episode 932/1000, Reward: -13.00, Epsilon: 0.01000, Loss: 4.24201
# Episode 933/1000, Reward:  48.00, Epsilon: 0.01000, Loss: 4.11038
# Episode 934/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 2.99362
# Episode 935/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 24.28009
# Episode 936/1000, Reward: -16.00, Epsilon: 0.01000, Loss: 9.33505
# Episode 937/1000, Reward: -179.00, Epsilon: 0.01000, Loss: 3.21343
# Episode 938/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 4.46684
# Episode 939/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 2.92480
# Episode 940/1000, Reward: -76.00, Epsilon: 0.01000, Loss: 6.20732
# Episode 941/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 12.20966
# Episode 942/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 41.43838
# Episode 943/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 4.04383
# Episode 944/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 3.39779
# Episode 945/1000, Reward:  35.00, Epsilon: 0.01000, Loss: 9.39143
# Episode 946/1000, Reward:  41.00, Epsilon: 0.01000, Loss: 9.91045
# Episode 947/1000, Reward:  62.00, Epsilon: 0.01000, Loss: 21.58727
# Episode 948/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 10.53486
# Episode 949/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 39.49879
# Episode 950/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 3.90544
# Episode 951/1000, Reward:  59.00, Epsilon: 0.01000, Loss: 21.33673
# Episode 952/1000, Reward:  57.00, Epsilon: 0.01000, Loss: 3.69965
# Episode 953/1000, Reward:  -5.00, Epsilon: 0.01000, Loss: 9.03300
# Episode 954/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 13.52222
# Episode 955/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 12.99975
# Episode 956/1000, Reward:  40.00, Epsilon: 0.01000, Loss: 3.36560
# Episode 957/1000, Reward:  49.00, Epsilon: 0.01000, Loss: 5.15820
# Episode 958/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 28.21690
# Episode 959/1000, Reward:  45.00, Epsilon: 0.01000, Loss: 2.34227
# Episode 960/1000, Reward:  41.00, Epsilon: 0.01000, Loss: 17.05878
# Episode 961/1000, Reward:  61.00, Epsilon: 0.01000, Loss: 38.87600
# Episode 962/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 5.43107
# Episode 963/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 2.13455
# Episode 964/1000, Reward:  -9.00, Epsilon: 0.01000, Loss: 14.61555
# Episode 965/1000, Reward: -66.00, Epsilon: 0.01000, Loss: 2.63963
# Episode 966/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 3.51117
# Episode 967/1000, Reward:  41.00, Epsilon: 0.01000, Loss: 2.59908
# Episode 968/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 6.29252
# Episode 969/1000, Reward:  62.00, Epsilon: 0.01000, Loss: 11.80465
# Episode 970/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 39.12283
# Episode 971/1000, Reward: -51.00, Epsilon: 0.01000, Loss: 6.42589
# Episode 972/1000, Reward: -11.00, Epsilon: 0.01000, Loss: 26.55129
# Episode 973/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 1.51139
# Episode 974/1000, Reward:  56.00, Epsilon: 0.01000, Loss: 11.76279
# Episode 975/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 63.65638
# Episode 976/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 12.56311
# Episode 977/1000, Reward:  46.00, Epsilon: 0.01000, Loss: 29.71563
# Episode 978/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 3.25101
# Episode 979/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 6.01008
# Episode 980/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 3.09277
# Episode 981/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 49.93414
# Episode 982/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 2.87471
# Episode 983/1000, Reward:  47.00, Epsilon: 0.01000, Loss: 5.12634
# Episode 984/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 8.76842
# Episode 985/1000, Reward:  53.00, Epsilon: 0.01000, Loss: 7.85620
# Episode 986/1000, Reward:  33.00, Epsilon: 0.01000, Loss: 7.25025
# Episode 987/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 17.68079
# Episode 988/1000, Reward:  48.00, Epsilon: 0.01000, Loss: 4.61754
# Episode 989/1000, Reward:  42.00, Epsilon: 0.01000, Loss: 5.31670
# Episode 990/1000, Reward:  52.00, Epsilon: 0.01000, Loss: 11.24344
# Episode 991/1000, Reward:  54.00, Epsilon: 0.01000, Loss: 22.54154
# Episode 992/1000, Reward:  60.00, Epsilon: 0.01000, Loss: 29.03178
# Episode 993/1000, Reward:  50.00, Epsilon: 0.01000, Loss: 6.43259
# Episode 994/1000, Reward:  58.00, Epsilon: 0.01000, Loss: 7.53145
# Episode 995/1000, Reward:  51.00, Epsilon: 0.01000, Loss: 35.96445
# Episode 996/1000, Reward:  55.00, Epsilon: 0.01000, Loss: 101.48764
# Episode 997/1000, Reward:  63.00, Epsilon: 0.01000, Loss: 23.63239
# Episode 998/1000, Reward: -18.00, Epsilon: 0.01000, Loss: 1.72776
# Episode 999/1000, Reward:   4.00, Epsilon: 0.01000, Loss: 3.18890
# Episode 1000/1000, Reward:  43.00, Epsilon: 0.01000, Loss: 60.84516

# %%
# Plotting Results
plt.figure(figsize=(14, 6))
plt.plot(episode_rewards_qrc)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('QRC Training on TruckBackerEnv_D')
plt.grid(True)
plt.show()

# %% [markdown]
# # Compare QRC and DQN

# %%
# Side-by-side plot of DQN vs QRC rewards
plt.figure(figsize=(14, 6))

# DQN rewards (assuming stored in `dqn_rewards` list)
plt.plot(episode_rewards_dqn, label='DQN', color='blue')

# QRC rewards (assuming stored in `episode_rewards_qrc` list)
plt.plot(episode_rewards_qrc, label='QRC', color='red')

plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('DQN vs QRC Training on TruckBackerEnv_D')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Side-by-side plot of DQN vs QRC rewards
plt.figure(figsize=(14, 6))

# DQN rewards (assuming stored in `dqn_rewards` list)
plt.plot(episode_rewards_dqn, label='DQN', color='blue')

plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('DQN on TruckBackerEnv_D')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Side-by-side plot of DQN vs QRC rewards
plt.figure(figsize=(14, 6))

# QRC rewards (assuming stored in `dqn_rewards` list)
plt.plot(episode_rewards_qrc, label='QRC', color='red')

plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('QRC on TruckBackerEnv_D')
plt.legend()
plt.grid(True)
plt.show()

# %%
window = 50
smoothed_dqn = np.convolve(episode_rewards_dqn, np.ones(window)/window, mode='valid')
smoothed_qrc = np.convolve(episode_rewards_qrc, np.ones(window)/window, mode='valid')

plt.figure(figsize=(20, 6))
plt.plot(smoothed_dqn, label='DQN', color='blue')
plt.plot(smoothed_qrc, label='QRC', color='red')


plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('DQN vs QRC Training on TruckBackerEnv_D')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import torch
import random
import matplotlib.pyplot as plt

all_rewards = []

for run in range(num_runs):
    # set random seeds for reproducibility
    seed = run
    np.random.seed(seed)
    torch.manual_seed(seed)
    random.seed(seed)

    # reinitialize environment and agent each run
    env = TruckBackerEnv_D(render_mode=None)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    agent = DQNAgent(
        state_dim=state_dim,
        action_dim=action_dim,
        lr=learning_rate,
        gamma=gamma,
        epsilon=epsilon_start,
        epsilon_decay=epsilon_decay,
        epsilon_min=epsilon_min,
        batch_size=batch_size
    )

    episode_rewards = []

    for episode in range(1, num_episodes + 1):
        state = env.reset()
        total_reward = 0

        for t in range(max_steps_per_episode):
            action = agent.agent_policy(state)
            next_state, reward, done, info = env.step(action)
            total_reward += reward
            agent.remember(state, action, reward, next_state, done)
            agent.train_with_mem()
            state = next_state
            if done:
                break

        if episode % target_update_freq == 0:
            agent.update_target()

        episode_rewards.append(total_reward)

    all_rewards.append(episode_rewards)
    print(f"Run {run+1}/{num_runs} finished.")

# --- Compute mean and std over runs ---
mean_rewards_dqp = np.mean(all_rewards, axis=0)
std_rewards_dqp = np.std(all_rewards, axis=0)

# --- Plot learning curve with error bands ---
plt.plot(mean_rewards_dqp, label="Mean Reward")
plt.fill_between(range(num_episodes),
                 mean_rewards_dqp - std_rewards_dqp,
                 mean_rewards_dqp + std_rewards_dqp,
                 alpha=0.2)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.title(f"DQN ({num_runs} runs)")
plt.show()
# Out:
# Run 1/20 finished.
# Run 2/20 finished.
# Run 3/20 finished.
# Run 4/20 finished.
# Run 5/20 finished.
# Run 6/20 finished.
# Run 7/20 finished.
# Run 8/20 finished.
# Run 9/20 finished.
# Run 10/20 finished.
# Run 11/20 finished.
# Run 12/20 finished.
# Run 13/20 finished.
# Run 14/20 finished.
# Run 15/20 finished.
# Run 16/20 finished.
# Run 17/20 finished.
# Run 18/20 finished.
# Run 19/20 finished.
# Run 20/20 finished.

# %%
# QRC-specific parameters
alpha = 1.0
sigma_min = 0.0
sigma_max = 1.0

# ========================================
# --- 2. Multi-Run Setup ---
# ========================================
all_rewards_qrc = []

for run in range(num_runs):
    # print(f"\n=== Starting Run {run + 1}/{num_runs} ===")

    # --- Random Seed for Reproducibility ---
    seed = run
    np.random.seed(seed)
    torch.manual_seed(seed)
    random.seed(seed)

    # --- Environment Setup ---
    env = TruckBackerEnv_D(render_mode=None)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    # --- Agent Initialization ---
    agent = QRCAgent(
        state_dim=state_dim,
        action_dim=action_dim,
        lr=learning_rate,
        gamma=gamma,
        epsilon=epsilon_start,
        epsilon_decay=epsilon_decay,
        min_epsilon=epsilon_min,
        batch_size=batch_size
    )

    episode_rewards = []
    recent_loss = 0.0

    # ========================================
    # --- 3. Training Loop ---
    # ========================================
    for episode in range(1, num_episodes + 1):
        # handle Gym reset signature
        reset_output = env.reset()
        state, info = reset_output if isinstance(reset_output, tuple) else (reset_output, {})
        total_reward = 0

        for t in range(max_steps_per_episode):
            action = agent.agent_policy(state)

            step_result = env.step(action)
            if len(step_result) == 5:
                next_state, reward, terminated, truncated, info = step_result
                done = terminated or truncated
            else:
                next_state, reward, done, info = step_result

            total_reward += reward

            # memory + training
            agent.remember(state, action, reward, next_state, done)
            current_loss = agent.train_with_mem()
            if current_loss != 0.0:
                recent_loss = current_loss

            state = next_state
            if done:
                break

        # target update
        if episode % target_update_freq == 0:
            agent.update_target()

        episode_rewards.append(total_reward)

        # print(f"[Run {run+1}] Ep {episode}/{num_episodes} | "
        #       f"Reward: {total_reward:6.2f} | Eps: {agent.epsilon:.5f} | Loss: {recent_loss:.5f}")

    all_rewards_qrc.append(episode_rewards)
    # print(f"=== Run {run + 1} complete! ===")
    print(f"Run {run+1}/{num_runs} finished.")

# ========================================
# --- 4. Aggregate Results ---
# ========================================
mean_rewards_qrc = np.mean(all_rewards_qrc, axis=0)
std_rewards_qrc = np.std(all_rewards_qrc, axis=0)

# ========================================
# --- 5. Plotting ---
# ========================================
plt.figure(figsize=(10, 6))
plt.plot(mean_rewards_qrc, label="QRC Mean Reward")
plt.fill_between(
    range(num_episodes),
    mean_rewards_qrc - std_rewards_qrc,
    mean_rewards_qrc + std_rewards_qrc,
    alpha=0.2
)
plt.title(f"QRC Training Performance ({num_runs} runs)")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.grid(True)
plt.show()

# ========================================
# --- 6. Optional: Save Results ---
# ========================================
np.save("qrc_all_rewards.npy", all_rewards_qrc)
print("Saved rewards to qrc_all_rewards.npy")
# Out:
# Run 1/20 finished.
# Run 2/20 finished.
# Run 3/20 finished.
# Run 4/20 finished.
# Run 5/20 finished.
# Run 6/20 finished.
# Run 7/20 finished.
# Run 8/20 finished.
# Run 9/20 finished.
# Run 10/20 finished.
# Run 11/20 finished.
# Run 12/20 finished.
# Run 13/20 finished.
# Run 14/20 finished.
# Run 15/20 finished.
# Run 16/20 finished.
# Run 17/20 finished.
# Run 18/20 finished.
# Run 19/20 finished.
# Run 20/20 finished.
# Saved rewards to qrc_all_rewards.npy

# %%
window = 50
smoothed_dqn = np.convolve(mean_rewards_dqp, np.ones(window)/window, mode='valid')
smoothed_qrc = np.convolve(mean_rewards_qrc, np.ones(window)/window, mode='valid')

plt.figure(figsize=(20, 6))
plt.plot(smoothed_dqn, label='DQN', color='blue')
plt.plot(smoothed_qrc, label='QRC', color='red')


plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('DQN vs QRC Training on TruckBackerEnv_D')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(mean_rewards_qrc, label="QRC Mean Reward")
# plt.plot(mean_rewards_dqn, label="DQN Mean Reward")
# plt.fill_between(
#     range(num_episodes),
#     mean_rewards_qrc - std_rewards_qrc,
#     mean_rewards_qrc + std_rewards_qrc,
#     alpha=0.2
# )
plt.title(f"QRC Training Performance ({num_runs} runs)")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(mean_rewards_dqp, label="Mean Reward")
# plt.fill_between(range(num_episodes),
#                  mean_rewards_dqp - std_rewards_dqp,
#                  mean_rewards_dqp + std_rewards_dqp,
#                  alpha=0.2)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.title(f"DQN ({num_runs} runs)")
plt.show()
