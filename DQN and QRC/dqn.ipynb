# %%
import numpy as np
import matplotlib.pyplot as plt
import os, shutil
from tqdm import tqdm
from rl_glue import RLGlue
import seaborn as sns
import random, numpy as np, torch


def set_global_seed(seed):
    # Python RNG
    random.seed(seed)

    # NumPy RNG
    np.random.seed(seed)

    # PyTorch CPU RNG
    torch.manual_seed(seed)

    # PyTorch GPU RNG
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)

    # cuDNN deterministic behavior
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Ensures deterministic algorithms wherever possible
    torch.use_deterministic_algorithms(True)

# %%
class DQNAgent:
    def __init__(self, state_dim, action_dim, lr=1e-5, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01, buffer_size=50000, batch_size=64):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size
        self.memory = deque(maxlen=buffer_size)
        # device, not needed, but needed if going on canada compute to specify gpu
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.q_nn = self.build_nn().to(self.device) # build q network
        self.target_net = self.build_nn().to(self.device) # build target network
        self.target_net.load_state_dict(self.q_nn.state_dict()) # make target net same as q net. initialization is random so need this
        self.optimizer = optim.Adam(self.q_nn.parameters(), lr=lr) 
        
    def build_nn(self): # to build the q network, 2 hidden layer with relu and 128 neurons in each
        return nn.Sequential(
            nn.Linear(self.state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, self.action_dim)
        )
    
    def agent_policy(self, state): # act e greedy
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.action_dim) # rand action
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device) # convert state to tensor, then add batch dimension, then move to device
        with torch.no_grad(): # dont calculate gradients, no need
            q_values = self.q_nn(state)
        return q_values.argmax().item()
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done)) # store transition sars, done is if terminal state
    
    def train_with_mem(self): # train with experience from memory using batch size set in agent
        if len(self.memory) < self.batch_size: # if not enough mem, could be changed to use what we have instead of skip
            return
        batch = random.sample(self.memory, self.batch_size) # get batch
        states, actions, rewards, next_states, dones = zip(*batch) # get batch features

        # convert data to tensors which can be used by pytorch
        states = torch.tensor(np.stack(states), dtype=torch.float32).to(self.device) 
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)

        # get current q values from q network
        q_values = self.q_nn(states).gather(1, actions)

        # use the samples from experience batch to calc target network q values
        with torch.no_grad(): # no need to calc gradients for target
            next_q_values = self.target_net(next_states).max(1, keepdim=True)[0]  
        # target = r + gamma * max_a' Q(s', a') * (1 - done)
        target = rewards + self.gamma * next_q_values * (1 - dones)

        # mean squared error 
        errors = target - q_values
        squared_errors = errors ** 2
        mean_squared_error = torch.mean(squared_errors)

        self.optimizer.zero_grad()
        mean_squared_error.backward()
        self.optimizer.step()
 
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay 

    
    def update_target(self): # update target network replacing it with the current q network
        self.target_net.load_state_dict(self.q_nn.state_dict())

# %%
from tbu_gym.tbu_discrete import TruckBackerEnv_D
num_episodes = 1000
max_steps_per_episode = 500
learning_rate = 1e-3
epsilon_start = 0.5
epsilon_decay = 0.99997
epsilon_min = 0.01
batch_size = 64
target_update_freq = 5


seeds = [i for i in range(200)]

import seaborn as sns
import matplotlib.pyplot as plt

all_rewards = []
for seed in seeds:
    print(f"\n========== RUN SEED = {seed} ==========\n")
    
    # Global RNGs
    set_global_seed(seed)

    # Environment
    env = TruckBackerEnv_D(render_mode=None)
    env.seed(seed)
    env.action_space.seed(seed)
    state = env.reset()

    # Agent
    agent = DQNAgent(
        state_dim=env.observation_space.shape[0],
        action_dim=env.action_space.n,
        lr=learning_rate,
        epsilon=epsilon_start,
        epsilon_decay=epsilon_decay,
        epsilon_min=epsilon_min,
        batch_size=batch_size
    )

    episode_rewards = []

    for episode in range(1, num_episodes + 1):
        env.seed(seed + episode)
        state = env.reset()
        total_reward = 0

        for t in range(max_steps_per_episode):
            action = agent.agent_policy(state)
            next_state, reward, done, info = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            agent.train_with_mem()
            state = next_state
            total_reward += reward
            if done:
                break

        if episode % target_update_freq == 0:
            agent.update_target()

        episode_rewards.append(total_reward)
        print(f"Seed {seed} | Episode {episode} | Reward {total_reward:.2f}")

    # Store rewards for this seed
    all_rewards.append(episode_rewards)
    torch.save(
    {
        "rewards": torch.tensor(all_rewards, dtype=torch.float32),
    },
    r"C:\Users\otten\Desktop\CMPUT655-Project\data\dqn_reward_seeds.pt"
    )

# Convert to NumPy array for easier aggregation
all_rewards = np.array(all_rewards)  # shape = (num_seeds, num_episodes)
num_seeds = all_rewards.shape[0]

# Compute mean and standard deviation across seeds
mean_rewards = np.mean(all_rewards, axis=0)
std_rewards = np.std(all_rewards, axis=0)

# Compute 90% confidence interval
ci_multiplier = 1.645  # for 90% confidence
ci = ci_multiplier * (std_rewards / np.sqrt(num_seeds))

# Plot mean reward with 90% confidence interval
plt.figure(figsize=(12,6))
sns.lineplot(x=np.arange(1, num_episodes+1), y=mean_rewards, label="Mean Reward")
plt.fill_between(np.arange(1, num_episodes+1), mean_rewards - ci, mean_rewards + ci, alpha=0.3, color="blue", label="90% CI")
plt.title("DQN Training Rewards (Aggregated Across Seeds)")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ========== RUN SEED = 0 ==========
#
# Seed 0 | Episode 1 | Reward -300.00
# Seed 0 | Episode 2 | Reward -300.00
# Seed 0 | Episode 3 | Reward -300.00
# Seed 0 | Episode 4 | Reward -300.00
# Seed 0 | Episode 5 | Reward -300.00
# Seed 0 | Episode 6 | Reward -300.00
# Seed 0 | Episode 7 | Reward -300.00
# Seed 0 | Episode 8 | Reward -300.00
# Seed 0 | Episode 9 | Reward -300.00
# Seed 0 | Episode 10 | Reward -300.00
# Seed 0 | Episode 11 | Reward -300.00
# Seed 0 | Episode 12 | Reward -300.00
# Seed 0 | Episode 13 | Reward -300.00
# Seed 0 | Episode 14 | Reward -300.00
# Seed 0 | Episode 15 | Reward -300.00
# Seed 0 | Episode 16 | Reward -300.00
# Seed 0 | Episode 17 | Reward -300.00
# Seed 0 | Episode 18 | Reward -300.00
# Seed 0 | Episode 19 | Reward -300.00
# Seed 0 | Episode 20 | Reward -300.00
# Seed 0 | Episode 21 | Reward -300.00
# Seed 0 | Episode 22 | Reward -175.00
# Seed 0 | Episode 23 | Reward -300.00
# Seed 0 | Episode 24 | Reward -300.00
# Seed 0 | Episode 25 | Reward -300.00
# Seed 0 | Episode 26 | Reward -300.00
# Seed 0 | Episode 27 | Reward -300.00
# Seed 0 | Episode 28 | Reward -300.00
# Seed 0 | Episode 29 | Reward -300.00
# Seed 0 | Episode 30 | Reward -300.00
# Seed 0 | Episode 31 | Reward -300.00
# Seed 0 | Episode 32 | Reward -300.00
# Seed 0 | Episode 33 | Reward -300.00
# Seed 0 | Episode 34 | Reward -300.00
# Seed 0 | Episode 35 | Reward -300.00
# Seed 0 | Episode 36 | Reward -300.00
# Seed 0 | Episode 37 | Reward -300.00
# Seed 0 | Episode 38 | Reward -300.00
# Seed 0 | Episode 39 | Reward -300.00
# Seed 0 | Episode 40 | Reward -300.00
# Seed 0 | Episode 41 | Reward -300.00
# Seed 0 | Episode 42 | Reward -300.00
# Seed 0 | Episode 43 | Reward -300.00
# Seed 0 | Episode 44 | Reward -300.00
# Seed 0 | Episode 45 | Reward -300.00
# Seed 0 | Episode 46 | Reward -300.00
# Seed 0 | Episode 47 | Reward -300.00
# Seed 0 | Episode 48 | Reward -300.00
# Seed 0 | Episode 49 | Reward -300.00
# Seed 0 | Episode 50 | Reward -300.00
# Seed 0 | Episode 51 | Reward -300.00
# Seed 0 | Episode 52 | Reward -300.00
# Seed 0 | Episode 53 | Reward -300.00
# Seed 0 | Episode 54 | Reward -300.00
# Seed 0 | Episode 55 | Reward -300.00
# Seed 0 | Episode 56 | Reward -300.00
# Seed 0 | Episode 57 | Reward -300.00
# Seed 0 | Episode 58 | Reward -300.00
# Seed 0 | Episode 59 | Reward -300.00
# Seed 0 | Episode 60 | Reward -300.00
# Seed 0 | Episode 61 | Reward 50.00
# Seed 0 | Episode 62 | Reward -300.00
# Seed 0 | Episode 63 | Reward -300.00
# Seed 0 | Episode 64 | Reward -300.00
# Seed 0 | Episode 65 | Reward -300.00
# Seed 0 | Episode 66 | Reward -300.00
# Seed 0 | Episode 67 | Reward -300.00
# Seed 0 | Episode 68 | Reward -300.00
# Seed 0 | Episode 69 | Reward -300.00
# Seed 0 | Episode 70 | Reward -300.00
# Seed 0 | Episode 71 | Reward -300.00
# Seed 0 | Episode 72 | Reward -300.00
# Seed 0 | Episode 73 | Reward -300.00
# Seed 0 | Episode 74 | Reward -300.00
# Seed 0 | Episode 75 | Reward -300.00
# Seed 0 | Episode 76 | Reward -300.00
# Seed 0 | Episode 77 | Reward -300.00
# Seed 0 | Episode 78 | Reward -300.00
# Seed 0 | Episode 79 | Reward -300.00
# Seed 0 | Episode 80 | Reward -300.00
# Seed 0 | Episode 81 | Reward -300.00
# Seed 0 | Episode 82 | Reward -300.00
# Seed 0 | Episode 83 | Reward -300.00
# Seed 0 | Episode 84 | Reward -140.00
# Seed 0 | Episode 85 | Reward -300.00
# Seed 0 | Episode 86 | Reward -300.00
# Seed 0 | Episode 87 | Reward -300.00
# Seed 0 | Episode 88 | Reward -300.00
# Seed 0 | Episode 89 | Reward -94.00
# Seed 0 | Episode 90 | Reward -124.00
# Seed 0 | Episode 91 | Reward -300.00
# Seed 0 | Episode 92 | Reward 46.00
# Seed 0 | Episode 93 | Reward -198.00
# Seed 0 | Episode 94 | Reward -300.00
# Seed 0 | Episode 95 | Reward -91.00
# Seed 0 | Episode 96 | Reward -300.00
# Seed 0 | Episode 97 | Reward -300.00
# Seed 0 | Episode 98 | Reward -91.00
# Seed 0 | Episode 99 | Reward -300.00
# Seed 0 | Episode 100 | Reward -300.00
# Seed 0 | Episode 101 | Reward -300.00
# Seed 0 | Episode 102 | Reward -300.00
# Seed 0 | Episode 103 | Reward -184.00
# Seed 0 | Episode 104 | Reward -300.00
# Seed 0 | Episode 105 | Reward -300.00
# Seed 0 | Episode 106 | Reward -300.00
# Seed 0 | Episode 107 | Reward -300.00
# Seed 0 | Episode 108 | Reward -300.00
# Seed 0 | Episode 109 | Reward -190.00
# Seed 0 | Episode 110 | Reward -300.00
# Seed 0 | Episode 111 | Reward 55.00
# Seed 0 | Episode 112 | Reward -300.00
# Seed 0 | Episode 113 | Reward -300.00
# Seed 0 | Episode 114 | Reward -300.00
# Seed 0 | Episode 115 | Reward -91.00
# Seed 0 | Episode 116 | Reward 53.00
# Seed 0 | Episode 117 | Reward 31.00
# Seed 0 | Episode 118 | Reward -300.00
# Seed 0 | Episode 119 | Reward -300.00
# Seed 0 | Episode 120 | Reward -54.00
# Seed 0 | Episode 121 | Reward -300.00
# Seed 0 | Episode 122 | Reward 41.00
# Seed 0 | Episode 123 | Reward 46.00
# Seed 0 | Episode 124 | Reward -300.00
# Seed 0 | Episode 125 | Reward 39.00
# Seed 0 | Episode 126 | Reward -20.00
# Seed 0 | Episode 127 | Reward -300.00
# Seed 0 | Episode 128 | Reward -22.00
# Seed 0 | Episode 129 | Reward -39.00
# Seed 0 | Episode 130 | Reward 48.00
# Seed 0 | Episode 131 | Reward -49.00
# Seed 0 | Episode 132 | Reward 56.00
# Seed 0 | Episode 133 | Reward -300.00
# Seed 0 | Episode 134 | Reward -12.00
# Seed 0 | Episode 135 | Reward 46.00
# Seed 0 | Episode 136 | Reward 56.00
# Seed 0 | Episode 137 | Reward 37.00
# Seed 0 | Episode 138 | Reward -33.00
# Seed 0 | Episode 139 | Reward -300.00
# Seed 0 | Episode 140 | Reward -96.00
# Seed 0 | Episode 141 | Reward -31.00
# Seed 0 | Episode 142 | Reward 56.00
# Seed 0 | Episode 143 | Reward 51.00
# Seed 0 | Episode 144 | Reward -108.00
# Seed 0 | Episode 145 | Reward -37.00
# Seed 0 | Episode 146 | Reward 47.00
# Seed 0 | Episode 147 | Reward -171.00
# Seed 0 | Episode 148 | Reward -300.00
# Seed 0 | Episode 149 | Reward 57.00
# Seed 0 | Episode 150 | Reward 59.00
# Seed 0 | Episode 151 | Reward -132.00
# Seed 0 | Episode 152 | Reward 54.00
# Seed 0 | Episode 153 | Reward -300.00
# Seed 0 | Episode 154 | Reward -169.00
# Seed 0 | Episode 155 | Reward 52.00
# Seed 0 | Episode 156 | Reward -19.00
# Seed 0 | Episode 157 | Reward 55.00
# Seed 0 | Episode 158 | Reward -41.00
# Seed 0 | Episode 159 | Reward 21.00
# Seed 0 | Episode 160 | Reward -16.00
# Seed 0 | Episode 161 | Reward -64.00
# Seed 0 | Episode 162 | Reward 57.00
# Seed 0 | Episode 163 | Reward 4.00
# Seed 0 | Episode 164 | Reward 62.00
# Seed 0 | Episode 165 | Reward -300.00
# Seed 0 | Episode 166 | Reward -300.00
# Seed 0 | Episode 167 | Reward -156.00
# Seed 0 | Episode 168 | Reward -8.00
# Seed 0 | Episode 169 | Reward 55.00
# Seed 0 | Episode 170 | Reward -152.00
# Seed 0 | Episode 171 | Reward 62.00
# Seed 0 | Episode 172 | Reward 60.00
# Seed 0 | Episode 173 | Reward 61.00
# Seed 0 | Episode 174 | Reward -178.00
# Seed 0 | Episode 175 | Reward -300.00
# Seed 0 | Episode 176 | Reward -153.00
# Seed 0 | Episode 177 | Reward 52.00
# Seed 0 | Episode 178 | Reward -64.00
# Seed 0 | Episode 179 | Reward -105.00
# Seed 0 | Episode 180 | Reward 37.00
# Seed 0 | Episode 181 | Reward 47.00
# Seed 0 | Episode 182 | Reward -300.00
# Seed 0 | Episode 183 | Reward -300.00
# Seed 0 | Episode 184 | Reward 0.00
# Seed 0 | Episode 185 | Reward 61.00
# Seed 0 | Episode 186 | Reward -5.00
# Seed 0 | Episode 187 | Reward -300.00
# Seed 0 | Episode 188 | Reward -33.00
# Seed 0 | Episode 189 | Reward 0.00
# Seed 0 | Episode 190 | Reward -300.00
# Seed 0 | Episode 191 | Reward -71.00
# Seed 0 | Episode 192 | Reward 48.00
# Seed 0 | Episode 193 | Reward -27.00
# Seed 0 | Episode 194 | Reward -300.00
# Seed 0 | Episode 195 | Reward -14.00
# Seed 0 | Episode 196 | Reward 43.00
# Seed 0 | Episode 197 | Reward -43.00
# Seed 0 | Episode 198 | Reward -37.00
# Seed 0 | Episode 199 | Reward 46.00
# Seed 0 | Episode 200 | Reward 43.00
# Seed 0 | Episode 201 | Reward -300.00
# Seed 0 | Episode 202 | Reward -199.00
# Seed 0 | Episode 203 | Reward 45.00
# Seed 0 | Episode 204 | Reward -300.00
# Seed 0 | Episode 205 | Reward -94.00
# Seed 0 | Episode 206 | Reward -133.00
# Seed 0 | Episode 207 | Reward 50.00
# Seed 0 | Episode 208 | Reward -34.00
# Seed 0 | Episode 209 | Reward 12.00
# Seed 0 | Episode 210 | Reward 47.00
# Seed 0 | Episode 211 | Reward -46.00
# Seed 0 | Episode 212 | Reward 50.00
# Seed 0 | Episode 213 | Reward -118.00
# Seed 0 | Episode 214 | Reward 55.00
# Seed 0 | Episode 215 | Reward -34.00
# Seed 0 | Episode 216 | Reward -113.00
# Seed 0 | Episode 217 | Reward 47.00
# Seed 0 | Episode 218 | Reward 41.00
# Seed 0 | Episode 219 | Reward -1.00
# Seed 0 | Episode 220 | Reward 37.00
# Seed 0 | Episode 221 | Reward -48.00
# Seed 0 | Episode 222 | Reward -1.00
# Seed 0 | Episode 223 | Reward 41.00
# Seed 0 | Episode 224 | Reward 50.00
# Seed 0 | Episode 225 | Reward 31.00
# Seed 0 | Episode 226 | Reward 42.00
# Seed 0 | Episode 227 | Reward 50.00
# Seed 0 | Episode 228 | Reward 46.00
# Seed 0 | Episode 229 | Reward -77.00
# Seed 0 | Episode 230 | Reward 7.00
# Seed 0 | Episode 231 | Reward 49.00
# Seed 0 | Episode 232 | Reward 54.00
# Seed 0 | Episode 233 | Reward 59.00
# Seed 0 | Episode 234 | Reward 47.00
# Seed 0 | Episode 235 | Reward -15.00
# Seed 0 | Episode 236 | Reward 40.00
# Seed 0 | Episode 237 | Reward 51.00
# Seed 0 | Episode 238 | Reward 50.00
# Seed 0 | Episode 239 | Reward 60.00
# Seed 0 | Episode 240 | Reward 48.00
# Seed 0 | Episode 241 | Reward 53.00
# Seed 0 | Episode 242 | Reward 61.00
# Seed 0 | Episode 243 | Reward 53.00
# Seed 0 | Episode 244 | Reward 60.00
# Seed 0 | Episode 245 | Reward 54.00
# Seed 0 | Episode 246 | Reward 54.00
# Seed 0 | Episode 247 | Reward 51.00
# Seed 0 | Episode 248 | Reward 44.00
# Seed 0 | Episode 249 | Reward 35.00
# Seed 0 | Episode 250 | Reward 55.00
# Seed 0 | Episode 251 | Reward 47.00
# Seed 0 | Episode 252 | Reward 46.00
# Seed 0 | Episode 253 | Reward 51.00
# Seed 0 | Episode 254 | Reward 50.00
# Seed 0 | Episode 255 | Reward 48.00
# Seed 0 | Episode 256 | Reward 46.00
# Seed 0 | Episode 257 | Reward 46.00
# Seed 0 | Episode 258 | Reward 56.00
# Seed 0 | Episode 259 | Reward 52.00
# Seed 0 | Episode 260 | Reward 41.00
# Seed 0 | Episode 261 | Reward 49.00
# Seed 0 | Episode 262 | Reward 48.00
# Seed 0 | Episode 263 | Reward 48.00
# Seed 0 | Episode 264 | Reward 57.00
# Seed 0 | Episode 265 | Reward 52.00
# Seed 0 | Episode 266 | Reward 52.00
# Seed 0 | Episode 267 | Reward 46.00
# Seed 0 | Episode 268 | Reward 41.00
# Seed 0 | Episode 269 | Reward 55.00
# Seed 0 | Episode 270 | Reward 54.00
# Seed 0 | Episode 271 | Reward 50.00
# Seed 0 | Episode 272 | Reward 55.00
# Seed 0 | Episode 273 | Reward 59.00
# Seed 0 | Episode 274 | Reward 40.00
# Seed 0 | Episode 275 | Reward 38.00
# Seed 0 | Episode 276 | Reward 42.00
# Seed 0 | Episode 277 | Reward 53.00
# Seed 0 | Episode 278 | Reward 49.00
# Seed 0 | Episode 279 | Reward 56.00
# Seed 0 | Episode 280 | Reward 45.00
# Seed 0 | Episode 281 | Reward 47.00
# Seed 0 | Episode 282 | Reward 48.00
# Seed 0 | Episode 283 | Reward 50.00
# Seed 0 | Episode 284 | Reward 49.00
# Seed 0 | Episode 285 | Reward 51.00
# Seed 0 | Episode 286 | Reward 49.00
# Seed 0 | Episode 287 | Reward 36.00
# Seed 0 | Episode 288 | Reward 45.00
# Seed 0 | Episode 289 | Reward 44.00
# Seed 0 | Episode 290 | Reward 55.00
# Seed 0 | Episode 291 | Reward 56.00
# Seed 0 | Episode 292 | Reward 52.00
# Seed 0 | Episode 293 | Reward 49.00
# Seed 0 | Episode 294 | Reward 47.00
# Seed 0 | Episode 295 | Reward 53.00
# Seed 0 | Episode 296 | Reward 51.00
# Seed 0 | Episode 297 | Reward 63.00
# Seed 0 | Episode 298 | Reward 46.00
# Seed 0 | Episode 299 | Reward 38.00
# Seed 0 | Episode 300 | Reward 49.00
# Seed 0 | Episode 301 | Reward 54.00
# Seed 0 | Episode 302 | Reward 48.00
# Seed 0 | Episode 303 | Reward 58.00
# Seed 0 | Episode 304 | Reward 49.00
# Seed 0 | Episode 305 | Reward 47.00
# Seed 0 | Episode 306 | Reward 58.00
# Seed 0 | Episode 307 | Reward 51.00
# Seed 0 | Episode 308 | Reward 49.00
# Seed 0 | Episode 309 | Reward 50.00
# Seed 0 | Episode 310 | Reward 50.00
# Seed 0 | Episode 311 | Reward 59.00
# Seed 0 | Episode 312 | Reward 49.00
# Seed 0 | Episode 313 | Reward 50.00
# Seed 0 | Episode 314 | Reward 43.00
# Seed 0 | Episode 315 | Reward 43.00
# Seed 0 | Episode 316 | Reward 32.00
# Seed 0 | Episode 317 | Reward 41.00
# Seed 0 | Episode 318 | Reward 37.00
# Seed 0 | Episode 319 | Reward 52.00
# Seed 0 | Episode 320 | Reward 44.00
# Seed 0 | Episode 321 | Reward 50.00
# Seed 0 | Episode 322 | Reward 57.00
# Seed 0 | Episode 323 | Reward 55.00
# Seed 0 | Episode 324 | Reward 58.00
# Seed 0 | Episode 325 | Reward 55.00
# Seed 0 | Episode 326 | Reward 61.00
# Seed 0 | Episode 327 | Reward 51.00
# Seed 0 | Episode 328 | Reward 47.00
# Seed 0 | Episode 329 | Reward 53.00
# Seed 0 | Episode 330 | Reward 40.00
# Seed 0 | Episode 331 | Reward 55.00
# Seed 0 | Episode 332 | Reward 54.00
# Seed 0 | Episode 333 | Reward 40.00
# Seed 0 | Episode 334 | Reward 53.00
# Seed 0 | Episode 335 | Reward 55.00
# Seed 0 | Episode 336 | Reward 37.00
# Seed 0 | Episode 337 | Reward 61.00
# Seed 0 | Episode 338 | Reward 42.00
# Seed 0 | Episode 339 | Reward 53.00
# Seed 0 | Episode 340 | Reward 45.00
# Seed 0 | Episode 341 | Reward 44.00
# Seed 0 | Episode 342 | Reward 45.00
# Seed 0 | Episode 343 | Reward 48.00
# Seed 0 | Episode 344 | Reward 40.00
# Seed 0 | Episode 345 | Reward 43.00
# Seed 0 | Episode 346 | Reward 52.00
# Seed 0 | Episode 347 | Reward 59.00
# Seed 0 | Episode 348 | Reward 55.00
# Seed 0 | Episode 349 | Reward 55.00
# Seed 0 | Episode 350 | Reward 44.00
# Seed 0 | Episode 351 | Reward 43.00
# Seed 0 | Episode 352 | Reward 59.00
# Seed 0 | Episode 353 | Reward 47.00
# Seed 0 | Episode 354 | Reward 47.00
# Seed 0 | Episode 355 | Reward 59.00
# Seed 0 | Episode 356 | Reward 57.00
# Seed 0 | Episode 357 | Reward 52.00
# Seed 0 | Episode 358 | Reward 50.00
# Seed 0 | Episode 359 | Reward 50.00
# Seed 0 | Episode 360 | Reward 45.00
# Seed 0 | Episode 361 | Reward 54.00
# Seed 0 | Episode 362 | Reward 58.00
# Seed 0 | Episode 363 | Reward 36.00
# Seed 0 | Episode 364 | Reward 52.00
# Seed 0 | Episode 365 | Reward 49.00
# Seed 0 | Episode 366 | Reward 54.00
# Seed 0 | Episode 367 | Reward 55.00
# Seed 0 | Episode 368 | Reward 54.00
# Seed 0 | Episode 369 | Reward 50.00
# Seed 0 | Episode 370 | Reward 33.00
# Seed 0 | Episode 371 | Reward 50.00
# Seed 0 | Episode 372 | Reward 50.00
# Seed 0 | Episode 373 | Reward 41.00
# Seed 0 | Episode 374 | Reward 56.00
# Seed 0 | Episode 375 | Reward 43.00
# Seed 0 | Episode 376 | Reward 48.00
# Seed 0 | Episode 377 | Reward 57.00
# Seed 0 | Episode 378 | Reward 52.00
# Seed 0 | Episode 379 | Reward 46.00
# Seed 0 | Episode 380 | Reward 58.00
# Seed 0 | Episode 381 | Reward 37.00
# Seed 0 | Episode 382 | Reward 54.00
# Seed 0 | Episode 383 | Reward 56.00
# Seed 0 | Episode 384 | Reward 53.00
# Seed 0 | Episode 385 | Reward 46.00
# Seed 0 | Episode 386 | Reward 59.00
# Seed 0 | Episode 387 | Reward 58.00
# Seed 0 | Episode 388 | Reward 56.00
# Seed 0 | Episode 389 | Reward 64.00
# Seed 0 | Episode 390 | Reward 50.00
# Seed 0 | Episode 391 | Reward 59.00
# Seed 0 | Episode 392 | Reward 53.00
# Seed 0 | Episode 393 | Reward 48.00
# Seed 0 | Episode 394 | Reward 49.00
# Seed 0 | Episode 395 | Reward 53.00
# Seed 0 | Episode 396 | Reward 50.00
# Seed 0 | Episode 397 | Reward 58.00
# Seed 0 | Episode 398 | Reward 47.00
# Seed 0 | Episode 399 | Reward 50.00
# Seed 0 | Episode 400 | Reward 51.00
# Seed 0 | Episode 401 | Reward 39.00
# Seed 0 | Episode 402 | Reward 53.00
# Seed 0 | Episode 403 | Reward 51.00
# Seed 0 | Episode 404 | Reward 57.00
# Seed 0 | Episode 405 | Reward 46.00
# Seed 0 | Episode 406 | Reward 52.00
# Seed 0 | Episode 407 | Reward 51.00
# Seed 0 | Episode 408 | Reward 53.00
# Seed 0 | Episode 409 | Reward 43.00
# Seed 0 | Episode 410 | Reward 49.00
# Seed 0 | Episode 411 | Reward 55.00
# Seed 0 | Episode 412 | Reward 47.00
# Seed 0 | Episode 413 | Reward 59.00
# Seed 0 | Episode 414 | Reward 57.00
# Seed 0 | Episode 415 | Reward 47.00
# Seed 0 | Episode 416 | Reward 63.00
# Seed 0 | Episode 417 | Reward 43.00
# Seed 0 | Episode 418 | Reward 52.00
# Seed 0 | Episode 419 | Reward 38.00
# Seed 0 | Episode 420 | Reward 42.00
# Seed 0 | Episode 421 | Reward 56.00
# Seed 0 | Episode 422 | Reward 54.00
# Seed 0 | Episode 423 | Reward 49.00
# Seed 0 | Episode 424 | Reward 48.00
# Seed 0 | Episode 425 | Reward 57.00
# Seed 0 | Episode 426 | Reward 52.00
# Seed 0 | Episode 427 | Reward 53.00
# Seed 0 | Episode 428 | Reward 49.00
# Seed 0 | Episode 429 | Reward 52.00
# Seed 0 | Episode 430 | Reward 48.00
# Seed 0 | Episode 431 | Reward 60.00
# Seed 0 | Episode 432 | Reward 44.00
# Seed 0 | Episode 433 | Reward 53.00
# Seed 0 | Episode 434 | Reward 53.00
# Seed 0 | Episode 435 | Reward 46.00
# Seed 0 | Episode 436 | Reward 53.00
# Seed 0 | Episode 437 | Reward 55.00
# Seed 0 | Episode 438 | Reward 43.00
# Seed 0 | Episode 439 | Reward 40.00
# Seed 0 | Episode 440 | Reward 39.00
# Seed 0 | Episode 441 | Reward 60.00
# Seed 0 | Episode 442 | Reward 49.00
# Seed 0 | Episode 443 | Reward 60.00
# Seed 0 | Episode 444 | Reward 45.00
# Seed 0 | Episode 445 | Reward 49.00
# Seed 0 | Episode 446 | Reward 51.00
# Seed 0 | Episode 447 | Reward 51.00
# Seed 0 | Episode 448 | Reward 63.00
# Seed 0 | Episode 449 | Reward 30.00
# Seed 0 | Episode 450 | Reward 46.00
# Seed 0 | Episode 451 | Reward 47.00
# Seed 0 | Episode 452 | Reward 40.00
# Seed 0 | Episode 453 | Reward 58.00
# Seed 0 | Episode 454 | Reward 62.00
# Seed 0 | Episode 455 | Reward 35.00
# Seed 0 | Episode 456 | Reward 46.00
# Seed 0 | Episode 457 | Reward 49.00
# Seed 0 | Episode 458 | Reward 53.00
# Seed 0 | Episode 459 | Reward 44.00
# Seed 0 | Episode 460 | Reward 64.00
# Seed 0 | Episode 461 | Reward 38.00
# Seed 0 | Episode 462 | Reward 42.00
# Seed 0 | Episode 463 | Reward 42.00
# Seed 0 | Episode 464 | Reward 44.00
# Seed 0 | Episode 465 | Reward 41.00
# Seed 0 | Episode 466 | Reward 60.00
# Seed 0 | Episode 467 | Reward 50.00
# Seed 0 | Episode 468 | Reward 47.00
# Seed 0 | Episode 469 | Reward 52.00
# Seed 0 | Episode 470 | Reward 53.00
# Seed 0 | Episode 471 | Reward 51.00
# Seed 0 | Episode 472 | Reward 45.00
# Seed 0 | Episode 473 | Reward 49.00
# Seed 0 | Episode 474 | Reward 43.00
# Seed 0 | Episode 475 | Reward 48.00
# Seed 0 | Episode 476 | Reward 53.00
# Seed 0 | Episode 477 | Reward 43.00
# Seed 0 | Episode 478 | Reward 57.00
# Seed 0 | Episode 479 | Reward 55.00
# Seed 0 | Episode 480 | Reward 49.00
# Seed 0 | Episode 481 | Reward 38.00
# Seed 0 | Episode 482 | Reward 43.00
# Seed 0 | Episode 483 | Reward 61.00
# Seed 0 | Episode 484 | Reward 56.00
# Seed 0 | Episode 485 | Reward 50.00
# Seed 0 | Episode 486 | Reward 37.00
# Seed 0 | Episode 487 | Reward 46.00
# Seed 0 | Episode 488 | Reward 54.00
# Seed 0 | Episode 489 | Reward 48.00
# Seed 0 | Episode 490 | Reward 50.00
# Seed 0 | Episode 491 | Reward 50.00
# Seed 0 | Episode 492 | Reward 52.00
# Seed 0 | Episode 493 | Reward 37.00
# Seed 0 | Episode 494 | Reward 42.00
# Seed 0 | Episode 495 | Reward 50.00
# Seed 0 | Episode 496 | Reward 45.00
# Seed 0 | Episode 497 | Reward 54.00
# Seed 0 | Episode 498 | Reward 39.00
# Seed 0 | Episode 499 | Reward 40.00
# Seed 0 | Episode 500 | Reward 48.00
# Seed 0 | Episode 501 | Reward 43.00
# Seed 0 | Episode 502 | Reward 58.00
# Seed 0 | Episode 503 | Reward 53.00
# Seed 0 | Episode 504 | Reward 62.00
# Seed 0 | Episode 505 | Reward 32.00
# Seed 0 | Episode 506 | Reward 58.00
# Seed 0 | Episode 507 | Reward 55.00
# Seed 0 | Episode 508 | Reward 34.00
# Seed 0 | Episode 509 | Reward 56.00
# Seed 0 | Episode 510 | Reward 45.00
# Seed 0 | Episode 511 | Reward 42.00
# Seed 0 | Episode 512 | Reward 51.00
# Seed 0 | Episode 513 | Reward 55.00
# Seed 0 | Episode 514 | Reward 48.00
# Seed 0 | Episode 515 | Reward 42.00
# Seed 0 | Episode 516 | Reward 51.00
# Seed 0 | Episode 517 | Reward 44.00
# Seed 0 | Episode 518 | Reward 56.00
# Seed 0 | Episode 519 | Reward 56.00
# Seed 0 | Episode 520 | Reward 59.00
# Seed 0 | Episode 521 | Reward 50.00
# Seed 0 | Episode 522 | Reward 56.00
# Seed 0 | Episode 523 | Reward 58.00
# Seed 0 | Episode 524 | Reward 61.00
# Seed 0 | Episode 525 | Reward 48.00
# Seed 0 | Episode 526 | Reward 55.00
# Seed 0 | Episode 527 | Reward 52.00
# Seed 0 | Episode 528 | Reward 45.00
# Seed 0 | Episode 529 | Reward 52.00
# Seed 0 | Episode 530 | Reward 42.00
# Seed 0 | Episode 531 | Reward 45.00
# Seed 0 | Episode 532 | Reward 55.00
# Seed 0 | Episode 533 | Reward 48.00
# Seed 0 | Episode 534 | Reward 38.00
# Seed 0 | Episode 535 | Reward 45.00
# Seed 0 | Episode 536 | Reward 54.00
# Seed 0 | Episode 537 | Reward 54.00
# Seed 0 | Episode 538 | Reward 49.00
# Seed 0 | Episode 539 | Reward 61.00
# Seed 0 | Episode 540 | Reward 45.00
# Seed 0 | Episode 541 | Reward 47.00
# Seed 0 | Episode 542 | Reward 39.00
# Seed 0 | Episode 543 | Reward 56.00
# Seed 0 | Episode 544 | Reward 55.00
# Seed 0 | Episode 545 | Reward 60.00
# Seed 0 | Episode 546 | Reward 49.00
# Seed 0 | Episode 547 | Reward 56.00
# Seed 0 | Episode 548 | Reward 60.00
# Seed 0 | Episode 549 | Reward 57.00
# Seed 0 | Episode 550 | Reward 53.00
# Seed 0 | Episode 551 | Reward 41.00
# Seed 0 | Episode 552 | Reward 63.00
# Seed 0 | Episode 553 | Reward 39.00
# Seed 0 | Episode 554 | Reward 39.00
# Seed 0 | Episode 555 | Reward 55.00
# Seed 0 | Episode 556 | Reward 48.00
# Seed 0 | Episode 557 | Reward 42.00
# Seed 0 | Episode 558 | Reward 51.00
# Seed 0 | Episode 559 | Reward 46.00
# Seed 0 | Episode 560 | Reward 48.00
# Seed 0 | Episode 561 | Reward 41.00
# Seed 0 | Episode 562 | Reward 44.00
# Seed 0 | Episode 563 | Reward 59.00
# Seed 0 | Episode 564 | Reward 50.00
# Seed 0 | Episode 565 | Reward 51.00
# Seed 0 | Episode 566 | Reward 35.00
# Seed 0 | Episode 567 | Reward 49.00
# Seed 0 | Episode 568 | Reward 46.00
# Seed 0 | Episode 569 | Reward 46.00
# Seed 0 | Episode 570 | Reward 53.00
# Seed 0 | Episode 571 | Reward 48.00
# Seed 0 | Episode 572 | Reward 49.00
# Seed 0 | Episode 573 | Reward 55.00
# Seed 0 | Episode 574 | Reward 47.00
# Seed 0 | Episode 575 | Reward 64.00
# Seed 0 | Episode 576 | Reward 41.00
# Seed 0 | Episode 577 | Reward 44.00
# Seed 0 | Episode 578 | Reward 56.00
# Seed 0 | Episode 579 | Reward 48.00
# Seed 0 | Episode 580 | Reward 59.00
# Seed 0 | Episode 581 | Reward 55.00
# Seed 0 | Episode 582 | Reward 61.00
# Seed 0 | Episode 583 | Reward 62.00
# Seed 0 | Episode 584 | Reward 47.00
# Seed 0 | Episode 585 | Reward 55.00
# Seed 0 | Episode 586 | Reward 50.00
# Seed 0 | Episode 587 | Reward 51.00
# Seed 0 | Episode 588 | Reward 42.00
# Seed 0 | Episode 589 | Reward 47.00
# Seed 0 | Episode 590 | Reward 50.00
# Seed 0 | Episode 591 | Reward 54.00
# Seed 0 | Episode 592 | Reward 56.00
# Seed 0 | Episode 593 | Reward 45.00
# Seed 0 | Episode 594 | Reward 59.00
# Seed 0 | Episode 595 | Reward 50.00
# Seed 0 | Episode 596 | Reward 51.00
# Seed 0 | Episode 597 | Reward 43.00
# Seed 0 | Episode 598 | Reward 42.00
# Seed 0 | Episode 599 | Reward 47.00
# Seed 0 | Episode 600 | Reward 57.00
# Seed 0 | Episode 601 | Reward 48.00
# Seed 0 | Episode 602 | Reward 59.00
# Seed 0 | Episode 603 | Reward 59.00
# Seed 0 | Episode 604 | Reward 57.00
# Seed 0 | Episode 605 | Reward 65.00
# Seed 0 | Episode 606 | Reward 43.00
# Seed 0 | Episode 607 | Reward 43.00
# Seed 0 | Episode 608 | Reward 52.00
# Seed 0 | Episode 609 | Reward 50.00
# Seed 0 | Episode 610 | Reward 52.00
# Seed 0 | Episode 611 | Reward 47.00
# Seed 0 | Episode 612 | Reward 59.00
# Seed 0 | Episode 613 | Reward 49.00
# Seed 0 | Episode 614 | Reward 63.00
# Seed 0 | Episode 615 | Reward 43.00
# Seed 0 | Episode 616 | Reward 57.00
# Seed 0 | Episode 617 | Reward 60.00
# Seed 0 | Episode 618 | Reward 53.00
# Seed 0 | Episode 619 | Reward 54.00
# Seed 0 | Episode 620 | Reward 45.00
# Seed 0 | Episode 621 | Reward 48.00
# Seed 0 | Episode 622 | Reward 58.00
# Seed 0 | Episode 623 | Reward 62.00
# Seed 0 | Episode 624 | Reward 60.00
# Seed 0 | Episode 625 | Reward 50.00
# Seed 0 | Episode 626 | Reward 43.00
# Seed 0 | Episode 627 | Reward 62.00
# Seed 0 | Episode 628 | Reward 44.00
# Seed 0 | Episode 629 | Reward 47.00
# Seed 0 | Episode 630 | Reward 47.00
# Seed 0 | Episode 631 | Reward 45.00
# Seed 0 | Episode 632 | Reward 65.00
# Seed 0 | Episode 633 | Reward 56.00
# Seed 0 | Episode 634 | Reward 45.00
# Seed 0 | Episode 635 | Reward 48.00
# Seed 0 | Episode 636 | Reward 56.00
# Seed 0 | Episode 637 | Reward 31.00
# Seed 0 | Episode 638 | Reward 59.00
# Seed 0 | Episode 639 | Reward 43.00
# Seed 0 | Episode 640 | Reward 47.00
# Seed 0 | Episode 641 | Reward 59.00
# Seed 0 | Episode 642 | Reward 50.00
# Seed 0 | Episode 643 | Reward 61.00
# Seed 0 | Episode 644 | Reward 51.00
# Seed 0 | Episode 645 | Reward 51.00
# Seed 0 | Episode 646 | Reward 55.00
# Seed 0 | Episode 647 | Reward 47.00
# Seed 0 | Episode 648 | Reward 51.00
# Seed 0 | Episode 649 | Reward 45.00
# Seed 0 | Episode 650 | Reward 55.00
# Seed 0 | Episode 651 | Reward 63.00
# Seed 0 | Episode 652 | Reward 51.00
# Seed 0 | Episode 653 | Reward 54.00
# Seed 0 | Episode 654 | Reward 58.00
# Seed 0 | Episode 655 | Reward 55.00
# Seed 0 | Episode 656 | Reward 62.00
# Seed 0 | Episode 657 | Reward 43.00
# Seed 0 | Episode 658 | Reward 58.00
# Seed 0 | Episode 659 | Reward 62.00
# Seed 0 | Episode 660 | Reward 53.00
# Seed 0 | Episode 661 | Reward 62.00
# Seed 0 | Episode 662 | Reward 65.00
# Seed 0 | Episode 663 | Reward 56.00
# Seed 0 | Episode 664 | Reward 50.00
# Seed 0 | Episode 665 | Reward 55.00
# Seed 0 | Episode 666 | Reward 51.00
# Seed 0 | Episode 667 | Reward 63.00
# Seed 0 | Episode 668 | Reward 52.00
# Seed 0 | Episode 669 | Reward 45.00
# Seed 0 | Episode 670 | Reward 54.00
# Seed 0 | Episode 671 | Reward 54.00
# Seed 0 | Episode 672 | Reward 42.00
# Seed 0 | Episode 673 | Reward 39.00
# Seed 0 | Episode 674 | Reward 56.00
# Seed 0 | Episode 675 | Reward 59.00
# Seed 0 | Episode 676 | Reward 51.00
# Seed 0 | Episode 677 | Reward 63.00
# Seed 0 | Episode 678 | Reward 43.00
# Seed 0 | Episode 679 | Reward 56.00
# Seed 0 | Episode 680 | Reward 63.00
# Seed 0 | Episode 681 | Reward 55.00
# Seed 0 | Episode 682 | Reward 43.00
# Seed 0 | Episode 683 | Reward 45.00
# Seed 0 | Episode 684 | Reward 51.00
# Seed 0 | Episode 685 | Reward 50.00
# Seed 0 | Episode 686 | Reward 54.00
# Seed 0 | Episode 687 | Reward 57.00
# Seed 0 | Episode 688 | Reward 66.00
# Seed 0 | Episode 689 | Reward 58.00
# Seed 0 | Episode 690 | Reward 44.00
# Seed 0 | Episode 691 | Reward 41.00
# Seed 0 | Episode 692 | Reward 63.00
# Seed 0 | Episode 693 | Reward 41.00
# Seed 0 | Episode 694 | Reward 52.00
# Seed 0 | Episode 695 | Reward 59.00
# Seed 0 | Episode 696 | Reward 49.00
# Seed 0 | Episode 697 | Reward 58.00
# Seed 0 | Episode 698 | Reward 46.00
# Seed 0 | Episode 699 | Reward 48.00
# Seed 0 | Episode 700 | Reward 52.00
# Seed 0 | Episode 701 | Reward 47.00
# Seed 0 | Episode 702 | Reward 58.00
# Seed 0 | Episode 703 | Reward 58.00
# Seed 0 | Episode 704 | Reward 55.00
# Seed 0 | Episode 705 | Reward 52.00
# Seed 0 | Episode 706 | Reward 61.00
# Seed 0 | Episode 707 | Reward 48.00
# Seed 0 | Episode 708 | Reward 47.00
# Seed 0 | Episode 709 | Reward 48.00
# Seed 0 | Episode 710 | Reward 55.00
# Seed 0 | Episode 711 | Reward 48.00
# Seed 0 | Episode 712 | Reward 57.00
# Seed 0 | Episode 713 | Reward 52.00
# Seed 0 | Episode 714 | Reward 51.00
# Seed 0 | Episode 715 | Reward 52.00
# Seed 0 | Episode 716 | Reward 49.00
# Seed 0 | Episode 717 | Reward 51.00
# Seed 0 | Episode 718 | Reward 48.00
# Seed 0 | Episode 719 | Reward 49.00
# Seed 0 | Episode 720 | Reward 61.00
# Seed 0 | Episode 721 | Reward 48.00
# Seed 0 | Episode 722 | Reward 53.00
# Seed 0 | Episode 723 | Reward 53.00
# Seed 0 | Episode 724 | Reward 61.00
# Seed 0 | Episode 725 | Reward 44.00
# Seed 0 | Episode 726 | Reward 48.00
# Seed 0 | Episode 727 | Reward 52.00
# Seed 0 | Episode 728 | Reward 48.00
# Seed 0 | Episode 729 | Reward 42.00
# Seed 0 | Episode 730 | Reward 52.00
# Seed 0 | Episode 731 | Reward 50.00
# Seed 0 | Episode 732 | Reward 42.00
# Seed 0 | Episode 733 | Reward 65.00
# Seed 0 | Episode 734 | Reward 53.00
# Seed 0 | Episode 735 | Reward 52.00
# Seed 0 | Episode 736 | Reward 54.00
# Seed 0 | Episode 737 | Reward 56.00
# Seed 0 | Episode 738 | Reward 52.00
# Seed 0 | Episode 739 | Reward 44.00
# Seed 0 | Episode 740 | Reward 48.00
# Seed 0 | Episode 741 | Reward 60.00
# Seed 0 | Episode 742 | Reward 48.00
# Seed 0 | Episode 743 | Reward 61.00
# Seed 0 | Episode 744 | Reward 52.00
# Seed 0 | Episode 745 | Reward 54.00
# Seed 0 | Episode 746 | Reward 49.00
# Seed 0 | Episode 747 | Reward 47.00
# Seed 0 | Episode 748 | Reward 49.00
# Seed 0 | Episode 749 | Reward 40.00
# Seed 0 | Episode 750 | Reward 54.00
# Seed 0 | Episode 751 | Reward 60.00
# Seed 0 | Episode 752 | Reward 50.00
# Seed 0 | Episode 753 | Reward 60.00
# Seed 0 | Episode 754 | Reward 43.00
# Seed 0 | Episode 755 | Reward 53.00
# Seed 0 | Episode 756 | Reward 59.00
# Seed 0 | Episode 757 | Reward 48.00
# Seed 0 | Episode 758 | Reward 40.00
# Seed 0 | Episode 759 | Reward 63.00
# Seed 0 | Episode 760 | Reward 40.00
# Seed 0 | Episode 761 | Reward 52.00
# Seed 0 | Episode 762 | Reward 59.00
# Seed 0 | Episode 763 | Reward 45.00
# Seed 0 | Episode 764 | Reward 45.00
# Seed 0 | Episode 765 | Reward 55.00
# Seed 0 | Episode 766 | Reward 58.00
# Seed 0 | Episode 767 | Reward 51.00
# Seed 0 | Episode 768 | Reward 44.00
# Seed 0 | Episode 769 | Reward 48.00
# Seed 0 | Episode 770 | Reward 46.00
# Seed 0 | Episode 771 | Reward 53.00
# Seed 0 | Episode 772 | Reward 59.00
# Seed 0 | Episode 773 | Reward 61.00
# Seed 0 | Episode 774 | Reward 60.00
# Seed 0 | Episode 775 | Reward 58.00
# Seed 0 | Episode 776 | Reward 61.00
# Seed 0 | Episode 777 | Reward 54.00
# Seed 0 | Episode 778 | Reward 61.00
# Seed 0 | Episode 779 | Reward 57.00
# Seed 0 | Episode 780 | Reward 49.00
# Seed 0 | Episode 781 | Reward 54.00
# Seed 0 | Episode 782 | Reward 60.00
# Seed 0 | Episode 783 | Reward 57.00
# Seed 0 | Episode 784 | Reward 53.00
# Seed 0 | Episode 785 | Reward 56.00
# Seed 0 | Episode 786 | Reward 44.00
# Seed 0 | Episode 787 | Reward 64.00
# Seed 0 | Episode 788 | Reward 53.00
# Seed 0 | Episode 789 | Reward 59.00
# Seed 0 | Episode 790 | Reward 49.00
# Seed 0 | Episode 791 | Reward 45.00
# Seed 0 | Episode 792 | Reward 45.00
# Seed 0 | Episode 793 | Reward 44.00
# Seed 0 | Episode 794 | Reward 56.00
# Seed 0 | Episode 795 | Reward 55.00
# Seed 0 | Episode 796 | Reward 49.00
# Seed 0 | Episode 797 | Reward 55.00
# Seed 0 | Episode 798 | Reward 54.00
# Seed 0 | Episode 799 | Reward 52.00
# Seed 0 | Episode 800 | Reward 60.00
# Seed 0 | Episode 801 | Reward 64.00
# Seed 0 | Episode 802 | Reward 39.00
# Seed 0 | Episode 803 | Reward 54.00
# Seed 0 | Episode 804 | Reward 33.00
# Seed 0 | Episode 805 | Reward 64.00
# Seed 0 | Episode 806 | Reward 57.00
# Seed 0 | Episode 807 | Reward 45.00
# Seed 0 | Episode 808 | Reward 58.00
# Seed 0 | Episode 809 | Reward 51.00
# Seed 0 | Episode 810 | Reward 53.00
# Seed 0 | Episode 811 | Reward 25.00
# Seed 0 | Episode 812 | Reward 54.00
# Seed 0 | Episode 813 | Reward 49.00
# Seed 0 | Episode 814 | Reward 55.00
# Seed 0 | Episode 815 | Reward 49.00
# Seed 0 | Episode 816 | Reward 26.00
# Seed 0 | Episode 817 | Reward 64.00
# Seed 0 | Episode 818 | Reward 63.00
# Seed 0 | Episode 819 | Reward 56.00
# Seed 0 | Episode 820 | Reward 44.00
# Seed 0 | Episode 821 | Reward 48.00
# Seed 0 | Episode 822 | Reward 52.00
# Seed 0 | Episode 823 | Reward 56.00
# Seed 0 | Episode 824 | Reward 52.00
# Seed 0 | Episode 825 | Reward 63.00
# Seed 0 | Episode 826 | Reward 37.00
# Seed 0 | Episode 827 | Reward 49.00
# Seed 0 | Episode 828 | Reward 34.00
# Seed 0 | Episode 829 | Reward 55.00
# Seed 0 | Episode 830 | Reward 51.00
# Seed 0 | Episode 831 | Reward 42.00
# Seed 0 | Episode 832 | Reward 38.00
# Seed 0 | Episode 833 | Reward 54.00
# Seed 0 | Episode 834 | Reward 56.00
# Seed 0 | Episode 835 | Reward 43.00
# Seed 0 | Episode 836 | Reward 63.00
# Seed 0 | Episode 837 | Reward 47.00
# Seed 0 | Episode 838 | Reward 39.00
# Seed 0 | Episode 839 | Reward 59.00
# Seed 0 | Episode 840 | Reward 45.00
# Seed 0 | Episode 841 | Reward 57.00
# Seed 0 | Episode 842 | Reward 49.00
# Seed 0 | Episode 843 | Reward 42.00
# Seed 0 | Episode 844 | Reward 52.00
# Seed 0 | Episode 845 | Reward 42.00
# Seed 0 | Episode 846 | Reward 46.00
# Seed 0 | Episode 847 | Reward 47.00
# Seed 0 | Episode 848 | Reward 52.00
# Seed 0 | Episode 849 | Reward 51.00
# Seed 0 | Episode 850 | Reward 62.00
# Seed 0 | Episode 851 | Reward -13.00
# Seed 0 | Episode 852 | Reward 44.00
# Seed 0 | Episode 853 | Reward 48.00
# Seed 0 | Episode 854 | Reward 35.00
# Seed 0 | Episode 855 | Reward 41.00
# Seed 0 | Episode 856 | Reward 61.00
# Seed 0 | Episode 857 | Reward 60.00
# Seed 0 | Episode 858 | Reward 36.00
# Seed 0 | Episode 859 | Reward 64.00
# Seed 0 | Episode 860 | Reward -19.00
# Seed 0 | Episode 861 | Reward 40.00
# Seed 0 | Episode 862 | Reward 49.00
# Seed 0 | Episode 863 | Reward 45.00
# Seed 0 | Episode 864 | Reward 59.00
# Seed 0 | Episode 865 | Reward 46.00
# Seed 0 | Episode 866 | Reward 57.00
# Seed 0 | Episode 867 | Reward 53.00
# Seed 0 | Episode 868 | Reward 57.00
# Seed 0 | Episode 869 | Reward 53.00
# Seed 0 | Episode 870 | Reward 59.00
# Seed 0 | Episode 871 | Reward 63.00
# Seed 0 | Episode 872 | Reward 36.00
# Seed 0 | Episode 873 | Reward 48.00
# Seed 0 | Episode 874 | Reward 55.00
# Seed 0 | Episode 875 | Reward 48.00
# Seed 0 | Episode 876 | Reward 56.00
# Seed 0 | Episode 877 | Reward 40.00
# Seed 0 | Episode 878 | Reward 40.00
# Seed 0 | Episode 879 | Reward 44.00
# Seed 0 | Episode 880 | Reward 58.00
# Seed 0 | Episode 881 | Reward 59.00
# Seed 0 | Episode 882 | Reward 54.00
# Seed 0 | Episode 883 | Reward 39.00
# Seed 0 | Episode 884 | Reward 53.00
# Seed 0 | Episode 885 | Reward 45.00
# Seed 0 | Episode 886 | Reward 56.00
# Seed 0 | Episode 887 | Reward 47.00
# Seed 0 | Episode 888 | Reward 57.00
# Seed 0 | Episode 889 | Reward 62.00
# Seed 0 | Episode 890 | Reward 57.00
# Seed 0 | Episode 891 | Reward 41.00
# Seed 0 | Episode 892 | Reward 55.00
# Seed 0 | Episode 893 | Reward 51.00
# Seed 0 | Episode 894 | Reward 62.00
# Seed 0 | Episode 895 | Reward 52.00
# Seed 0 | Episode 896 | Reward 44.00
# Seed 0 | Episode 897 | Reward 50.00
# Seed 0 | Episode 898 | Reward 41.00
# Seed 0 | Episode 899 | Reward 43.00
# Seed 0 | Episode 900 | Reward 49.00
# Seed 0 | Episode 901 | Reward -17.00
# Seed 0 | Episode 902 | Reward 58.00
# Seed 0 | Episode 903 | Reward 59.00
# Seed 0 | Episode 904 | Reward 58.00
# Seed 0 | Episode 905 | Reward 43.00
# Seed 0 | Episode 906 | Reward 48.00
# Seed 0 | Episode 907 | Reward 51.00
# Seed 0 | Episode 908 | Reward 51.00
# Seed 0 | Episode 909 | Reward 50.00
# Seed 0 | Episode 910 | Reward 56.00
# Seed 0 | Episode 911 | Reward 57.00
# Seed 0 | Episode 912 | Reward 41.00
# Seed 0 | Episode 913 | Reward 56.00
# Seed 0 | Episode 914 | Reward 51.00
# Seed 0 | Episode 915 | Reward 61.00
# Seed 0 | Episode 916 | Reward 61.00
# Seed 0 | Episode 917 | Reward 60.00
# Seed 0 | Episode 918 | Reward 55.00
# Seed 0 | Episode 919 | Reward 45.00
# Seed 0 | Episode 920 | Reward 58.00
# Seed 0 | Episode 921 | Reward 59.00
# Seed 0 | Episode 922 | Reward 56.00
# Seed 0 | Episode 923 | Reward 44.00
# Seed 0 | Episode 924 | Reward -11.00
# Seed 0 | Episode 925 | Reward 40.00
# Seed 0 | Episode 926 | Reward 53.00
# Seed 0 | Episode 927 | Reward 50.00
# Seed 0 | Episode 928 | Reward 49.00
# Seed 0 | Episode 929 | Reward 57.00
# Seed 0 | Episode 930 | Reward 16.00
# Seed 0 | Episode 931 | Reward 52.00
# Seed 0 | Episode 932 | Reward 43.00
# Seed 0 | Episode 933 | Reward 62.00
# Seed 0 | Episode 934 | Reward 56.00
# Seed 0 | Episode 935 | Reward 61.00
# Seed 0 | Episode 936 | Reward 57.00
# Seed 0 | Episode 937 | Reward 57.00
# Seed 0 | Episode 938 | Reward 45.00
# Seed 0 | Episode 939 | Reward 42.00
# Seed 0 | Episode 940 | Reward 57.00
# Seed 0 | Episode 941 | Reward 54.00
# Seed 0 | Episode 942 | Reward 59.00
# Seed 0 | Episode 943 | Reward 45.00
# Seed 0 | Episode 944 | Reward 57.00
# Seed 0 | Episode 945 | Reward 53.00
# Seed 0 | Episode 946 | Reward 54.00
# Seed 0 | Episode 947 | Reward 60.00
# Seed 0 | Episode 948 | Reward 49.00
# Seed 0 | Episode 949 | Reward 56.00
# Seed 0 | Episode 950 | Reward 60.00
# Seed 0 | Episode 951 | Reward 46.00
# Seed 0 | Episode 952 | Reward 60.00
# Seed 0 | Episode 953 | Reward 62.00
# Seed 0 | Episode 954 | Reward 54.00
# Seed 0 | Episode 955 | Reward 61.00
# Seed 0 | Episode 956 | Reward 52.00
# Seed 0 | Episode 957 | Reward 52.00
# Seed 0 | Episode 958 | Reward 53.00
# Seed 0 | Episode 959 | Reward 54.00
# Seed 0 | Episode 960 | Reward 57.00
# Seed 0 | Episode 961 | Reward 57.00
# Seed 0 | Episode 962 | Reward 59.00
# Seed 0 | Episode 963 | Reward 51.00
# Seed 0 | Episode 964 | Reward 54.00
# Seed 0 | Episode 965 | Reward 65.00
# Seed 0 | Episode 966 | Reward 57.00
# Seed 0 | Episode 967 | Reward 54.00
# Seed 0 | Episode 968 | Reward 51.00
# Seed 0 | Episode 969 | Reward 46.00
# Seed 0 | Episode 970 | Reward 41.00
# Seed 0 | Episode 971 | Reward 63.00
# Seed 0 | Episode 972 | Reward 49.00
# Seed 0 | Episode 973 | Reward 56.00
# Seed 0 | Episode 974 | Reward 49.00
# Seed 0 | Episode 975 | Reward 60.00
# Seed 0 | Episode 976 | Reward 48.00
# Seed 0 | Episode 977 | Reward 54.00
# Seed 0 | Episode 978 | Reward 55.00
# Seed 0 | Episode 979 | Reward 58.00
# Seed 0 | Episode 980 | Reward 46.00
# Seed 0 | Episode 981 | Reward 58.00
# Seed 0 | Episode 982 | Reward 51.00
# Seed 0 | Episode 983 | Reward 55.00
# Seed 0 | Episode 984 | Reward 62.00
# Seed 0 | Episode 985 | Reward 61.00
# Seed 0 | Episode 986 | Reward 61.00
# Seed 0 | Episode 987 | Reward 51.00
# Seed 0 | Episode 988 | Reward 54.00
# Seed 0 | Episode 989 | Reward 49.00
# Seed 0 | Episode 990 | Reward 58.00
# Seed 0 | Episode 991 | Reward 51.00
# Seed 0 | Episode 992 | Reward 49.00
# Seed 0 | Episode 993 | Reward 57.00
# Seed 0 | Episode 994 | Reward 52.00
# Seed 0 | Episode 995 | Reward 63.00
# Seed 0 | Episode 996 | Reward 61.00
# Seed 0 | Episode 997 | Reward 51.00
# Seed 0 | Episode 998 | Reward 51.00
# Seed 0 | Episode 999 | Reward 49.00
# Seed 0 | Episode 1000 | Reward 56.00
#
# ========== RUN SEED = 1 ==========
#
# Seed 1 | Episode 1 | Reward -300.00
# Seed 1 | Episode 2 | Reward -300.00
# Seed 1 | Episode 3 | Reward -300.00
# Seed 1 | Episode 4 | Reward -300.00
# Seed 1 | Episode 5 | Reward -300.00
# Seed 1 | Episode 6 | Reward -300.00
# Seed 1 | Episode 7 | Reward -300.00
# Seed 1 | Episode 8 | Reward -300.00
# Seed 1 | Episode 9 | Reward -300.00
# Seed 1 | Episode 10 | Reward -300.00
# Seed 1 | Episode 11 | Reward -300.00
# Seed 1 | Episode 12 | Reward -300.00
# Seed 1 | Episode 13 | Reward -300.00
# Seed 1 | Episode 14 | Reward -300.00
# Seed 1 | Episode 15 | Reward -300.00
# Seed 1 | Episode 16 | Reward -300.00
# Seed 1 | Episode 17 | Reward -300.00
# Seed 1 | Episode 18 | Reward -300.00
# Seed 1 | Episode 19 | Reward -300.00
# Seed 1 | Episode 20 | Reward -300.00
# Seed 1 | Episode 21 | Reward -300.00
# Seed 1 | Episode 22 | Reward -300.00
# Seed 1 | Episode 23 | Reward -300.00
# Seed 1 | Episode 24 | Reward -300.00
# Seed 1 | Episode 25 | Reward -300.00
# Seed 1 | Episode 26 | Reward -300.00
# Seed 1 | Episode 27 | Reward -300.00
# Seed 1 | Episode 28 | Reward -300.00
# Seed 1 | Episode 29 | Reward -300.00
# Seed 1 | Episode 30 | Reward -300.00
# Seed 1 | Episode 31 | Reward -300.00
# Seed 1 | Episode 32 | Reward -300.00
# Seed 1 | Episode 33 | Reward -300.00
# Seed 1 | Episode 34 | Reward -300.00
# Seed 1 | Episode 35 | Reward -300.00
# Seed 1 | Episode 36 | Reward -300.00
# Seed 1 | Episode 37 | Reward -300.00
# Seed 1 | Episode 38 | Reward -300.00
# Seed 1 | Episode 39 | Reward -300.00
# Seed 1 | Episode 40 | Reward -300.00
# Seed 1 | Episode 41 | Reward -300.00
# Seed 1 | Episode 42 | Reward -300.00
# Seed 1 | Episode 43 | Reward -300.00
# Seed 1 | Episode 44 | Reward -300.00
# Seed 1 | Episode 45 | Reward -300.00
# Seed 1 | Episode 46 | Reward -300.00
# Seed 1 | Episode 47 | Reward -300.00
# Seed 1 | Episode 48 | Reward -300.00
# Seed 1 | Episode 49 | Reward -300.00
# Seed 1 | Episode 50 | Reward -300.00
# Seed 1 | Episode 51 | Reward -300.00
# Seed 1 | Episode 52 | Reward -300.00
# Seed 1 | Episode 53 | Reward -300.00
# Seed 1 | Episode 54 | Reward -300.00
# Seed 1 | Episode 55 | Reward -300.00
# Seed 1 | Episode 56 | Reward -300.00
# Seed 1 | Episode 57 | Reward -300.00
# Seed 1 | Episode 58 | Reward -300.00
# Seed 1 | Episode 59 | Reward -300.00
# Seed 1 | Episode 60 | Reward -300.00
# Seed 1 | Episode 61 | Reward -300.00
# Seed 1 | Episode 62 | Reward -300.00
# Seed 1 | Episode 63 | Reward -300.00
# Seed 1 | Episode 64 | Reward -300.00
# Seed 1 | Episode 65 | Reward -300.00
# Seed 1 | Episode 66 | Reward -300.00
# Seed 1 | Episode 67 | Reward -300.00
# Seed 1 | Episode 68 | Reward -300.00
# Seed 1 | Episode 69 | Reward -300.00
# Seed 1 | Episode 70 | Reward -300.00
# Seed 1 | Episode 71 | Reward -300.00
# Seed 1 | Episode 72 | Reward -300.00
# Seed 1 | Episode 73 | Reward -300.00
# Seed 1 | Episode 74 | Reward -300.00
# Seed 1 | Episode 75 | Reward -300.00
# Seed 1 | Episode 76 | Reward -300.00
# Seed 1 | Episode 77 | Reward -300.00
# Seed 1 | Episode 78 | Reward -300.00
# Seed 1 | Episode 79 | Reward -300.00
# Seed 1 | Episode 80 | Reward -300.00
# Seed 1 | Episode 81 | Reward -300.00
# Seed 1 | Episode 82 | Reward -300.00
# Seed 1 | Episode 83 | Reward -300.00
# Seed 1 | Episode 84 | Reward -300.00
# Seed 1 | Episode 85 | Reward -300.00
# Seed 1 | Episode 86 | Reward -300.00
# Seed 1 | Episode 87 | Reward -300.00
# Seed 1 | Episode 88 | Reward -300.00
# Seed 1 | Episode 89 | Reward -300.00
# Seed 1 | Episode 90 | Reward -300.00
# Seed 1 | Episode 91 | Reward -300.00
# Seed 1 | Episode 92 | Reward -300.00
# Seed 1 | Episode 93 | Reward -300.00
# Seed 1 | Episode 94 | Reward -300.00
# Seed 1 | Episode 95 | Reward -300.00
# Seed 1 | Episode 96 | Reward -300.00
# Seed 1 | Episode 97 | Reward -300.00
# Seed 1 | Episode 98 | Reward -300.00
# Seed 1 | Episode 99 | Reward -300.00
# Seed 1 | Episode 100 | Reward -300.00
# Seed 1 | Episode 101 | Reward -300.00
# Seed 1 | Episode 102 | Reward -300.00
# Seed 1 | Episode 103 | Reward -300.00
# Seed 1 | Episode 104 | Reward -300.00
# Seed 1 | Episode 105 | Reward -300.00
# Seed 1 | Episode 106 | Reward -300.00
# Seed 1 | Episode 107 | Reward -300.00
# Seed 1 | Episode 108 | Reward -300.00
# Seed 1 | Episode 109 | Reward -300.00
# Seed 1 | Episode 110 | Reward -300.00
# Seed 1 | Episode 111 | Reward -300.00
# Seed 1 | Episode 112 | Reward -300.00
# Seed 1 | Episode 113 | Reward -300.00
# Seed 1 | Episode 114 | Reward -300.00
# Seed 1 | Episode 115 | Reward -300.00
# Seed 1 | Episode 116 | Reward -300.00
# Seed 1 | Episode 117 | Reward -300.00
# Seed 1 | Episode 118 | Reward -300.00
# Seed 1 | Episode 119 | Reward -300.00
# Seed 1 | Episode 120 | Reward -300.00
# Seed 1 | Episode 121 | Reward -300.00
# Seed 1 | Episode 122 | Reward -300.00
# Seed 1 | Episode 123 | Reward -300.00
# Seed 1 | Episode 124 | Reward -300.00
# Seed 1 | Episode 125 | Reward -300.00
# Seed 1 | Episode 126 | Reward -300.00
# Seed 1 | Episode 127 | Reward -300.00
# Seed 1 | Episode 128 | Reward -300.00
# Seed 1 | Episode 129 | Reward -300.00
# Seed 1 | Episode 130 | Reward -300.00
# Seed 1 | Episode 131 | Reward -300.00
# Seed 1 | Episode 132 | Reward -300.00
# Seed 1 | Episode 133 | Reward -300.00
# Seed 1 | Episode 134 | Reward -300.00
# Seed 1 | Episode 135 | Reward -300.00
# Seed 1 | Episode 136 | Reward -300.00
# Seed 1 | Episode 137 | Reward -300.00
# Seed 1 | Episode 138 | Reward -300.00
# Seed 1 | Episode 139 | Reward -300.00
# Seed 1 | Episode 140 | Reward -300.00
# Seed 1 | Episode 141 | Reward -300.00
# Seed 1 | Episode 142 | Reward -300.00
# Seed 1 | Episode 143 | Reward -300.00
# Seed 1 | Episode 144 | Reward -300.00
# Seed 1 | Episode 145 | Reward -300.00
# Seed 1 | Episode 146 | Reward -300.00
# Seed 1 | Episode 147 | Reward -300.00
# Seed 1 | Episode 148 | Reward -300.00
# Seed 1 | Episode 149 | Reward -300.00
# Seed 1 | Episode 150 | Reward -300.00
# Seed 1 | Episode 151 | Reward -300.00
# Seed 1 | Episode 152 | Reward -300.00
# Seed 1 | Episode 153 | Reward -300.00
# Seed 1 | Episode 154 | Reward -300.00
# Seed 1 | Episode 155 | Reward -300.00
# Seed 1 | Episode 156 | Reward -300.00
# Seed 1 | Episode 157 | Reward -300.00
# Seed 1 | Episode 158 | Reward -300.00
# Seed 1 | Episode 159 | Reward -161.00
# Seed 1 | Episode 160 | Reward -300.00
# Seed 1 | Episode 161 | Reward -300.00
# Seed 1 | Episode 162 | Reward -300.00
# Seed 1 | Episode 163 | Reward -300.00
# Seed 1 | Episode 164 | Reward -300.00
# Seed 1 | Episode 165 | Reward -300.00
# Seed 1 | Episode 166 | Reward -300.00
# Seed 1 | Episode 167 | Reward -300.00
# Seed 1 | Episode 168 | Reward -300.00
# Seed 1 | Episode 169 | Reward -300.00
# Seed 1 | Episode 170 | Reward -300.00
# Seed 1 | Episode 171 | Reward -300.00
# Seed 1 | Episode 172 | Reward -300.00
# Seed 1 | Episode 173 | Reward -300.00
# Seed 1 | Episode 174 | Reward -300.00
# Seed 1 | Episode 175 | Reward -300.00
# Seed 1 | Episode 176 | Reward -300.00
# Seed 1 | Episode 177 | Reward -300.00
# Seed 1 | Episode 178 | Reward -300.00
# Seed 1 | Episode 179 | Reward -300.00
# Seed 1 | Episode 180 | Reward -300.00
# Seed 1 | Episode 181 | Reward -300.00
# Seed 1 | Episode 182 | Reward -300.00
# Seed 1 | Episode 183 | Reward -300.00
# Seed 1 | Episode 184 | Reward -300.00
# Seed 1 | Episode 185 | Reward -300.00
# Seed 1 | Episode 186 | Reward -300.00
# Seed 1 | Episode 187 | Reward -300.00
# Seed 1 | Episode 188 | Reward -300.00
# Seed 1 | Episode 189 | Reward -300.00
# Seed 1 | Episode 190 | Reward -300.00
# Seed 1 | Episode 191 | Reward -300.00
# Seed 1 | Episode 192 | Reward -300.00
# Seed 1 | Episode 193 | Reward -300.00
# Seed 1 | Episode 194 | Reward -300.00
# Seed 1 | Episode 195 | Reward -300.00
# Seed 1 | Episode 196 | Reward -300.00
# Seed 1 | Episode 197 | Reward -300.00
# Seed 1 | Episode 198 | Reward -300.00
# Seed 1 | Episode 199 | Reward -300.00
# Seed 1 | Episode 200 | Reward -300.00
# Seed 1 | Episode 201 | Reward -300.00
# Seed 1 | Episode 202 | Reward -300.00
# Seed 1 | Episode 203 | Reward -300.00
# Seed 1 | Episode 204 | Reward -300.00
# Seed 1 | Episode 205 | Reward -300.00
# Seed 1 | Episode 206 | Reward -300.00
# Seed 1 | Episode 207 | Reward -300.00
# Seed 1 | Episode 208 | Reward -300.00
# Seed 1 | Episode 209 | Reward -300.00
# Seed 1 | Episode 210 | Reward -300.00
# Seed 1 | Episode 211 | Reward -300.00
# Seed 1 | Episode 212 | Reward -300.00
# Seed 1 | Episode 213 | Reward -300.00
# Seed 1 | Episode 214 | Reward -300.00
# Seed 1 | Episode 215 | Reward -300.00
# Seed 1 | Episode 216 | Reward -300.00
# Seed 1 | Episode 217 | Reward -300.00
# Seed 1 | Episode 218 | Reward -300.00
# Seed 1 | Episode 219 | Reward -300.00
# Seed 1 | Episode 220 | Reward -300.00
# Seed 1 | Episode 221 | Reward -300.00
# Seed 1 | Episode 222 | Reward -300.00
# Seed 1 | Episode 223 | Reward -300.00
# Seed 1 | Episode 224 | Reward -300.00
# Seed 1 | Episode 225 | Reward -300.00
# Seed 1 | Episode 226 | Reward -300.00
# Seed 1 | Episode 227 | Reward -300.00
# Seed 1 | Episode 228 | Reward -300.00
# Seed 1 | Episode 229 | Reward -300.00
# Seed 1 | Episode 230 | Reward -300.00
# Seed 1 | Episode 231 | Reward -300.00
# Seed 1 | Episode 232 | Reward -300.00
# Seed 1 | Episode 233 | Reward -300.00
# Seed 1 | Episode 234 | Reward -300.00
# Seed 1 | Episode 235 | Reward -300.00
# Seed 1 | Episode 236 | Reward -300.00
# Seed 1 | Episode 237 | Reward -300.00
# Seed 1 | Episode 238 | Reward -300.00
# Seed 1 | Episode 239 | Reward -300.00
# Seed 1 | Episode 240 | Reward -300.00
# Seed 1 | Episode 241 | Reward -300.00
# Seed 1 | Episode 242 | Reward -300.00
# Seed 1 | Episode 243 | Reward -300.00
# Seed 1 | Episode 244 | Reward -300.00
# Seed 1 | Episode 245 | Reward -300.00
# Seed 1 | Episode 246 | Reward -300.00
# Seed 1 | Episode 247 | Reward -300.00
# Seed 1 | Episode 248 | Reward -300.00
# Seed 1 | Episode 249 | Reward -300.00
# Seed 1 | Episode 250 | Reward -300.00
# Seed 1 | Episode 251 | Reward -300.00
# Seed 1 | Episode 252 | Reward -300.00
# Seed 1 | Episode 253 | Reward -300.00
# Seed 1 | Episode 254 | Reward -300.00
# Seed 1 | Episode 255 | Reward -300.00
# Seed 1 | Episode 256 | Reward -300.00
# Seed 1 | Episode 257 | Reward -300.00
# Seed 1 | Episode 258 | Reward -300.00
# Seed 1 | Episode 259 | Reward -300.00
# Seed 1 | Episode 260 | Reward -300.00
# Seed 1 | Episode 261 | Reward -300.00
# Seed 1 | Episode 262 | Reward -300.00
# Seed 1 | Episode 263 | Reward -300.00
# Seed 1 | Episode 264 | Reward -300.00
# Seed 1 | Episode 265 | Reward -300.00
# Seed 1 | Episode 266 | Reward -300.00
# Seed 1 | Episode 267 | Reward -300.00
# Seed 1 | Episode 268 | Reward -300.00
# Seed 1 | Episode 269 | Reward -300.00
# Seed 1 | Episode 270 | Reward -300.00
# Seed 1 | Episode 271 | Reward -300.00
# Seed 1 | Episode 272 | Reward -300.00
# Seed 1 | Episode 273 | Reward -300.00
# Seed 1 | Episode 274 | Reward -300.00
# Seed 1 | Episode 275 | Reward -300.00
# Seed 1 | Episode 276 | Reward -300.00
# Seed 1 | Episode 277 | Reward -300.00
# Seed 1 | Episode 278 | Reward -300.00
# Seed 1 | Episode 279 | Reward -300.00
# Seed 1 | Episode 280 | Reward -300.00
# Seed 1 | Episode 281 | Reward -300.00
# Seed 1 | Episode 282 | Reward -300.00
# Seed 1 | Episode 283 | Reward -300.00
# Seed 1 | Episode 284 | Reward -300.00
# Seed 1 | Episode 285 | Reward -300.00
# Seed 1 | Episode 286 | Reward -300.00
# Seed 1 | Episode 287 | Reward -300.00
# Seed 1 | Episode 288 | Reward -300.00
# Seed 1 | Episode 289 | Reward -300.00
# Seed 1 | Episode 290 | Reward -300.00
# Seed 1 | Episode 291 | Reward -300.00
# Seed 1 | Episode 292 | Reward -300.00
# Seed 1 | Episode 293 | Reward -300.00
# Seed 1 | Episode 294 | Reward -300.00
# Seed 1 | Episode 295 | Reward -300.00
# Seed 1 | Episode 296 | Reward -300.00
# Seed 1 | Episode 297 | Reward -300.00
# Seed 1 | Episode 298 | Reward -300.00
# Seed 1 | Episode 299 | Reward -300.00
# Seed 1 | Episode 300 | Reward -300.00
# Seed 1 | Episode 301 | Reward -300.00
# Seed 1 | Episode 302 | Reward -300.00
# Seed 1 | Episode 303 | Reward -300.00
# Seed 1 | Episode 304 | Reward -300.00
# Seed 1 | Episode 305 | Reward -300.00
# Seed 1 | Episode 306 | Reward -300.00
# Seed 1 | Episode 307 | Reward -300.00
# Seed 1 | Episode 308 | Reward -300.00
# Seed 1 | Episode 309 | Reward -300.00
# Seed 1 | Episode 310 | Reward -300.00
# Seed 1 | Episode 311 | Reward -300.00
# ...
# Seed 4 | Episode 502 | Reward 59.00
# Seed 4 | Episode 503 | Reward 59.00
# Seed 4 | Episode 504 | Reward 32.00
# Seed 4 | Episode 505 | Reward 56.00
# Seed 4 | Episode 506 | Reward 52.00
# Seed 4 | Episode 507 | Reward 34.00
# Seed 4 | Episode 508 | Reward 51.00
# Seed 4 | Episode 509 | Reward 57.00
# Seed 4 | Episode 510 | Reward 46.00
# Seed 4 | Episode 511 | Reward 43.00
# Seed 4 | Episode 512 | Reward 56.00
# Seed 4 | Episode 513 | Reward 44.00
# Seed 4 | Episode 514 | Reward 53.00
# Seed 4 | Episode 515 | Reward 61.00
# Seed 4 | Episode 516 | Reward 58.00
# Seed 4 | Episode 517 | Reward 50.00
# Seed 4 | Episode 518 | Reward 55.00
# Seed 4 | Episode 519 | Reward 56.00
# Seed 4 | Episode 520 | Reward 64.00
# Seed 4 | Episode 521 | Reward 45.00
# Seed 4 | Episode 522 | Reward 54.00
# Seed 4 | Episode 523 | Reward 55.00
# Seed 4 | Episode 524 | Reward 46.00
# Seed 4 | Episode 525 | Reward 54.00
# Seed 4 | Episode 526 | Reward 44.00
# Seed 4 | Episode 527 | Reward 48.00
# Seed 4 | Episode 528 | Reward 55.00
# Seed 4 | Episode 529 | Reward 49.00
# Seed 4 | Episode 530 | Reward 4.00
# Seed 4 | Episode 531 | Reward 41.00
# Seed 4 | Episode 532 | Reward 55.00
# Seed 4 | Episode 533 | Reward 52.00
# Seed 4 | Episode 534 | Reward 48.00
# Seed 4 | Episode 535 | Reward 56.00
# Seed 4 | Episode 536 | Reward 52.00
# Seed 4 | Episode 537 | Reward 49.00
# Seed 4 | Episode 538 | Reward 44.00
# Seed 4 | Episode 539 | Reward 57.00
# Seed 4 | Episode 540 | Reward 55.00
# Seed 4 | Episode 541 | Reward 60.00
# Seed 4 | Episode 542 | Reward 49.00
# Seed 4 | Episode 543 | Reward 58.00
# Seed 4 | Episode 544 | Reward 60.00
# Seed 4 | Episode 545 | Reward 60.00
# Seed 4 | Episode 546 | Reward 54.00
# Seed 4 | Episode 547 | Reward 44.00
# Seed 4 | Episode 548 | Reward 63.00
# Seed 4 | Episode 549 | Reward 49.00
# Seed 4 | Episode 550 | Reward 37.00
# Seed 4 | Episode 551 | Reward 54.00
# Seed 4 | Episode 552 | Reward 50.00
# Seed 4 | Episode 553 | Reward 42.00
# Seed 4 | Episode 554 | Reward 45.00
# Seed 4 | Episode 555 | Reward 47.00
# Seed 4 | Episode 556 | Reward 49.00
# Seed 4 | Episode 557 | Reward 45.00
# Seed 4 | Episode 558 | Reward 42.00
# Seed 4 | Episode 559 | Reward 60.00
# Seed 4 | Episode 560 | Reward 48.00
# Seed 4 | Episode 561 | Reward 48.00
# Seed 4 | Episode 562 | Reward 44.00
# Seed 4 | Episode 563 | Reward 50.00
# Seed 4 | Episode 564 | Reward 45.00
# Seed 4 | Episode 565 | Reward 48.00
# Seed 4 | Episode 566 | Reward 47.00
# Seed 4 | Episode 567 | Reward 49.00
# Seed 4 | Episode 568 | Reward 51.00
# Seed 4 | Episode 569 | Reward 56.00
# Seed 4 | Episode 570 | Reward 51.00
# Seed 4 | Episode 571 | Reward 63.00
# Seed 4 | Episode 572 | Reward 42.00
# Seed 4 | Episode 573 | Reward 46.00
# Seed 4 | Episode 574 | Reward 55.00
# Seed 4 | Episode 575 | Reward 52.00
# Seed 4 | Episode 576 | Reward 59.00
# Seed 4 | Episode 577 | Reward 53.00
# Seed 4 | Episode 578 | Reward 56.00
# Seed 4 | Episode 579 | Reward 62.00
# Seed 4 | Episode 580 | Reward 38.00
# Seed 4 | Episode 581 | Reward 56.00
# Seed 4 | Episode 582 | Reward 55.00
# Seed 4 | Episode 583 | Reward 43.00
# Seed 4 | Episode 584 | Reward 40.00
# Seed 4 | Episode 585 | Reward 50.00
# Seed 4 | Episode 586 | Reward 51.00
# Seed 4 | Episode 587 | Reward 54.00
# Seed 4 | Episode 588 | Reward 63.00
# Seed 4 | Episode 589 | Reward 46.00
# Seed 4 | Episode 590 | Reward 59.00
# Seed 4 | Episode 591 | Reward 52.00
# Seed 4 | Episode 592 | Reward 46.00
# Seed 4 | Episode 593 | Reward 47.00
# Seed 4 | Episode 594 | Reward 46.00
# Seed 4 | Episode 595 | Reward 46.00
# Seed 4 | Episode 596 | Reward 48.00
# Seed 4 | Episode 597 | Reward 47.00
# Seed 4 | Episode 598 | Reward 57.00
# Seed 4 | Episode 599 | Reward 60.00
# Seed 4 | Episode 600 | Reward 58.00
# Seed 4 | Episode 601 | Reward 58.00
# Seed 4 | Episode 602 | Reward 41.00
# Seed 4 | Episode 603 | Reward 42.00
# Seed 4 | Episode 604 | Reward 53.00
# Seed 4 | Episode 605 | Reward 45.00
# Seed 4 | Episode 606 | Reward 50.00
# Seed 4 | Episode 607 | Reward -9.00
# Seed 4 | Episode 608 | Reward 56.00
# Seed 4 | Episode 609 | Reward 30.00
# Seed 4 | Episode 610 | Reward 57.00
# Seed 4 | Episode 611 | Reward 32.00
# Seed 4 | Episode 612 | Reward 49.00
# Seed 4 | Episode 613 | Reward 61.00
# Seed 4 | Episode 614 | Reward 50.00
# Seed 4 | Episode 615 | Reward 48.00
# Seed 4 | Episode 616 | Reward 33.00
# Seed 4 | Episode 617 | Reward 46.00
# Seed 4 | Episode 618 | Reward 57.00
# Seed 4 | Episode 619 | Reward 58.00
# Seed 4 | Episode 620 | Reward 59.00
# Seed 4 | Episode 621 | Reward 48.00
# Seed 4 | Episode 622 | Reward 47.00
# Seed 4 | Episode 623 | Reward 60.00
# Seed 4 | Episode 624 | Reward 44.00
# Seed 4 | Episode 625 | Reward 43.00
# Seed 4 | Episode 626 | Reward 39.00
# Seed 4 | Episode 627 | Reward 40.00
# Seed 4 | Episode 628 | Reward 61.00
# Seed 4 | Episode 629 | Reward 54.00
# Seed 4 | Episode 630 | Reward 42.00
# Seed 4 | Episode 631 | Reward 42.00
# Seed 4 | Episode 632 | Reward 49.00
# Seed 4 | Episode 633 | Reward 44.00
# Seed 4 | Episode 634 | Reward 47.00
# Seed 4 | Episode 635 | Reward 42.00
# Seed 4 | Episode 636 | Reward 43.00
# Seed 4 | Episode 637 | Reward 63.00
# Seed 4 | Episode 638 | Reward 52.00
# Seed 4 | Episode 639 | Reward 58.00
# Seed 4 | Episode 640 | Reward 43.00
# Seed 4 | Episode 641 | Reward 42.00
# Seed 4 | Episode 642 | Reward 53.00
# Seed 4 | Episode 643 | Reward 45.00
# Seed 4 | Episode 644 | Reward 47.00
# Seed 4 | Episode 645 | Reward 45.00
# Seed 4 | Episode 646 | Reward 44.00
# Seed 4 | Episode 647 | Reward 64.00
# Seed 4 | Episode 648 | Reward 50.00
# Seed 4 | Episode 649 | Reward 48.00
# Seed 4 | Episode 650 | Reward 56.00
# Seed 4 | Episode 651 | Reward 53.00
# Seed 4 | Episode 652 | Reward 58.00
# Seed 4 | Episode 653 | Reward 36.00
# Seed 4 | Episode 654 | Reward 56.00
# Seed 4 | Episode 655 | Reward 57.00
# Seed 4 | Episode 656 | Reward 53.00
# Seed 4 | Episode 657 | Reward 56.00
# Seed 4 | Episode 658 | Reward 61.00
# Seed 4 | Episode 659 | Reward 58.00
# Seed 4 | Episode 660 | Reward 40.00
# Seed 4 | Episode 661 | Reward 55.00
# Seed 4 | Episode 662 | Reward 45.00
# Seed 4 | Episode 663 | Reward 63.00
# Seed 4 | Episode 664 | Reward 47.00
# Seed 4 | Episode 665 | Reward 53.00
# Seed 4 | Episode 666 | Reward 53.00
# Seed 4 | Episode 667 | Reward 50.00
# Seed 4 | Episode 668 | Reward 41.00
# Seed 4 | Episode 669 | Reward 37.00
# Seed 4 | Episode 670 | Reward 50.00
# Seed 4 | Episode 671 | Reward 62.00
# Seed 4 | Episode 672 | Reward 51.00
# Seed 4 | Episode 673 | Reward 64.00
# Seed 4 | Episode 674 | Reward 39.00
# Seed 4 | Episode 675 | Reward 54.00
# Seed 4 | Episode 676 | Reward 64.00
# Seed 4 | Episode 677 | Reward 54.00
# Seed 4 | Episode 678 | Reward 45.00
# Seed 4 | Episode 679 | Reward 45.00
# Seed 4 | Episode 680 | Reward 45.00
# Seed 4 | Episode 681 | Reward 46.00
# Seed 4 | Episode 682 | Reward 48.00
# Seed 4 | Episode 683 | Reward 58.00
# Seed 4 | Episode 684 | Reward 65.00
# Seed 4 | Episode 685 | Reward 58.00
# Seed 4 | Episode 686 | Reward 45.00
# Seed 4 | Episode 687 | Reward 36.00
# Seed 4 | Episode 688 | Reward 60.00
# Seed 4 | Episode 689 | Reward 45.00
# Seed 4 | Episode 690 | Reward 51.00
# Seed 4 | Episode 691 | Reward 53.00
# Seed 4 | Episode 692 | Reward 52.00
# Seed 4 | Episode 693 | Reward 59.00
# Seed 4 | Episode 694 | Reward 51.00
# Seed 4 | Episode 695 | Reward 51.00
# Seed 4 | Episode 696 | Reward 55.00
# Seed 4 | Episode 697 | Reward 44.00
# Seed 4 | Episode 698 | Reward 62.00
# Seed 4 | Episode 699 | Reward 58.00
# Seed 4 | Episode 700 | Reward 55.00
# Seed 4 | Episode 701 | Reward 50.00
# Seed 4 | Episode 702 | Reward 65.00
# Seed 4 | Episode 703 | Reward 48.00
# Seed 4 | Episode 704 | Reward 47.00
# Seed 4 | Episode 705 | Reward 48.00
# Seed 4 | Episode 706 | Reward 53.00
# Seed 4 | Episode 707 | Reward 48.00
# Seed 4 | Episode 708 | Reward 51.00
# Seed 4 | Episode 709 | Reward 46.00
# Seed 4 | Episode 710 | Reward 37.00
# Seed 4 | Episode 711 | Reward 53.00
# Seed 4 | Episode 712 | Reward 41.00
# Seed 4 | Episode 713 | Reward -128.00
# Seed 4 | Episode 714 | Reward -33.00
# Seed 4 | Episode 715 | Reward 47.00
# Seed 4 | Episode 716 | Reward 59.00
# Seed 4 | Episode 717 | Reward 57.00
# Seed 4 | Episode 718 | Reward 55.00
# Seed 4 | Episode 719 | Reward 54.00
# Seed 4 | Episode 720 | Reward 65.00
# Seed 4 | Episode 721 | Reward -19.00
# Seed 4 | Episode 722 | Reward 50.00
# Seed 4 | Episode 723 | Reward 51.00
# Seed 4 | Episode 724 | Reward 32.00
# Seed 4 | Episode 725 | Reward 44.00
# Seed 4 | Episode 726 | Reward 55.00
# Seed 4 | Episode 727 | Reward 48.00
# Seed 4 | Episode 728 | Reward 32.00
# Seed 4 | Episode 729 | Reward 62.00
# Seed 4 | Episode 730 | Reward 45.00
# Seed 4 | Episode 731 | Reward 45.00
# Seed 4 | Episode 732 | Reward 48.00
# Seed 4 | Episode 733 | Reward 56.00
# Seed 4 | Episode 734 | Reward 47.00
# Seed 4 | Episode 735 | Reward -31.00
# Seed 4 | Episode 736 | Reward 46.00
# Seed 4 | Episode 737 | Reward 62.00
# Seed 4 | Episode 738 | Reward 38.00
# Seed 4 | Episode 739 | Reward 62.00
# Seed 4 | Episode 740 | Reward 51.00
# Seed 4 | Episode 741 | Reward 51.00
# Seed 4 | Episode 742 | Reward 50.00
# Seed 4 | Episode 743 | Reward 48.00
# Seed 4 | Episode 744 | Reward 47.00
# Seed 4 | Episode 745 | Reward 44.00
# Seed 4 | Episode 746 | Reward 51.00
# Seed 4 | Episode 747 | Reward 60.00
# Seed 4 | Episode 748 | Reward 41.00
# Seed 4 | Episode 749 | Reward 59.00
# Seed 4 | Episode 750 | Reward 44.00
# Seed 4 | Episode 751 | Reward 47.00
# Seed 4 | Episode 752 | Reward 58.00
# Seed 4 | Episode 753 | Reward 48.00
# Seed 4 | Episode 754 | Reward 47.00
# Seed 4 | Episode 755 | Reward 61.00
# Seed 4 | Episode 756 | Reward 45.00
# Seed 4 | Episode 757 | Reward 51.00
# Seed 4 | Episode 758 | Reward 58.00
# Seed 4 | Episode 759 | Reward 41.00
# Seed 4 | Episode 760 | Reward 44.00
# Seed 4 | Episode 761 | Reward 51.00
# Seed 4 | Episode 762 | Reward 61.00
# Seed 4 | Episode 763 | Reward 50.00
# Seed 4 | Episode 764 | Reward 46.00
# Seed 4 | Episode 765 | Reward 43.00
# Seed 4 | Episode 766 | Reward 43.00
# Seed 4 | Episode 767 | Reward 55.00
# Seed 4 | Episode 768 | Reward 60.00
# Seed 4 | Episode 769 | Reward 62.00
# Seed 4 | Episode 770 | Reward 60.00
# Seed 4 | Episode 771 | Reward 59.00
# Seed 4 | Episode 772 | Reward 60.00
# Seed 4 | Episode 773 | Reward 50.00
# Seed 4 | Episode 774 | Reward 61.00
# Seed 4 | Episode 775 | Reward 57.00
# Seed 4 | Episode 776 | Reward 52.00
# Seed 4 | Episode 777 | Reward 56.00
# Seed 4 | Episode 778 | Reward 60.00
# Seed 4 | Episode 779 | Reward 57.00
# Seed 4 | Episode 780 | Reward 52.00
# Seed 4 | Episode 781 | Reward 54.00
# Seed 4 | Episode 782 | Reward 45.00
# Seed 4 | Episode 783 | Reward 63.00
# Seed 4 | Episode 784 | Reward 53.00
# Seed 4 | Episode 785 | Reward 59.00
# Seed 4 | Episode 786 | Reward 49.00
# Seed 4 | Episode 787 | Reward 47.00
# Seed 4 | Episode 788 | Reward 51.00
# Seed 4 | Episode 789 | Reward 46.00
# Seed 4 | Episode 790 | Reward 54.00
# Seed 4 | Episode 791 | Reward 54.00
# Seed 4 | Episode 792 | Reward 54.00
# Seed 4 | Episode 793 | Reward 58.00
# Seed 4 | Episode 794 | Reward 57.00
# Seed 4 | Episode 795 | Reward 51.00
# Seed 4 | Episode 796 | Reward 58.00
# Seed 4 | Episode 797 | Reward 63.00
# Seed 4 | Episode 798 | Reward 42.00
# Seed 4 | Episode 799 | Reward 52.00
# Seed 4 | Episode 800 | Reward 39.00
# Seed 4 | Episode 801 | Reward 62.00
# Seed 4 | Episode 802 | Reward 55.00
# Seed 4 | Episode 803 | Reward 51.00
# Seed 4 | Episode 804 | Reward 56.00
# Seed 4 | Episode 805 | Reward 48.00
# Seed 4 | Episode 806 | Reward 57.00
# Seed 4 | Episode 807 | Reward 43.00
# Seed 4 | Episode 808 | Reward 54.00
# Seed 4 | Episode 809 | Reward 55.00
# Seed 4 | Episode 810 | Reward 54.00
# Seed 4 | Episode 811 | Reward 50.00
# Seed 4 | Episode 812 | Reward 51.00
# Seed 4 | Episode 813 | Reward 63.00
# Seed 4 | Episode 814 | Reward 63.00
# Seed 4 | Episode 815 | Reward 59.00
# Seed 4 | Episode 816 | Reward 44.00
# Seed 4 | Episode 817 | Reward 47.00
# Seed 4 | Episode 818 | Reward 54.00
# Seed 4 | Episode 819 | Reward 54.00
# Seed 4 | Episode 820 | Reward 50.00
# Seed 4 | Episode 821 | Reward 60.00
# Seed 4 | Episode 822 | Reward 51.00
# Seed 4 | Episode 823 | Reward 45.00
# Seed 4 | Episode 824 | Reward 55.00
# Seed 4 | Episode 825 | Reward 52.00
# Seed 4 | Episode 826 | Reward 54.00
# Seed 4 | Episode 827 | Reward 45.00
# Seed 4 | Episode 828 | Reward -300.00
# Seed 4 | Episode 829 | Reward 56.00
# Seed 4 | Episode 830 | Reward 58.00
# Seed 4 | Episode 831 | Reward 48.00
# Seed 4 | Episode 832 | Reward 63.00
# Seed 4 | Episode 833 | Reward 48.00
# Seed 4 | Episode 834 | Reward 11.00
# Seed 4 | Episode 835 | Reward 55.00
# Seed 4 | Episode 836 | Reward 48.00
# Seed 4 | Episode 837 | Reward 54.00
# Seed 4 | Episode 838 | Reward 51.00
# Seed 4 | Episode 839 | Reward 43.00
# Seed 4 | Episode 840 | Reward 52.00
# Seed 4 | Episode 841 | Reward 45.00
# Seed 4 | Episode 842 | Reward 49.00
# Seed 4 | Episode 843 | Reward 53.00
# Seed 4 | Episode 844 | Reward 50.00
# Seed 4 | Episode 845 | Reward 53.00
# Seed 4 | Episode 846 | Reward 64.00
# Seed 4 | Episode 847 | Reward 45.00
# Seed 4 | Episode 848 | Reward 52.00
# Seed 4 | Episode 849 | Reward 50.00
# Seed 4 | Episode 850 | Reward 43.00
# Seed 4 | Episode 851 | Reward 39.00
# Seed 4 | Episode 852 | Reward 61.00
# Seed 4 | Episode 853 | Reward 57.00
# Seed 4 | Episode 854 | Reward 41.00
# Seed 4 | Episode 855 | Reward 64.00
# Seed 4 | Episode 856 | Reward 48.00
# Seed 4 | Episode 857 | Reward 42.00
# Seed 4 | Episode 858 | Reward 51.00
# Seed 4 | Episode 859 | Reward 48.00
# Seed 4 | Episode 860 | Reward 59.00
# Seed 4 | Episode 861 | Reward 40.00
# Seed 4 | Episode 862 | Reward 61.00
# Seed 4 | Episode 863 | Reward 54.00
# Seed 4 | Episode 864 | Reward 54.00
# Seed 4 | Episode 865 | Reward 55.00
# Seed 4 | Episode 866 | Reward 56.00
# Seed 4 | Episode 867 | Reward 64.00
# Seed 4 | Episode 868 | Reward 13.00
# Seed 4 | Episode 869 | Reward 50.00
# Seed 4 | Episode 870 | Reward 51.00
# Seed 4 | Episode 871 | Reward 56.00
# Seed 4 | Episode 872 | Reward 59.00
# Seed 4 | Episode 873 | Reward 55.00
# Seed 4 | Episode 874 | Reward 52.00
# Seed 4 | Episode 875 | Reward 49.00
# Seed 4 | Episode 876 | Reward 58.00
# Seed 4 | Episode 877 | Reward 62.00
# Seed 4 | Episode 878 | Reward 53.00
# Seed 4 | Episode 879 | Reward 47.00
# Seed 4 | Episode 880 | Reward 50.00
# Seed 4 | Episode 881 | Reward 46.00
# Seed 4 | Episode 882 | Reward 56.00
# Seed 4 | Episode 883 | Reward 45.00
# Seed 4 | Episode 884 | Reward 55.00
# Seed 4 | Episode 885 | Reward 62.00
# Seed 4 | Episode 886 | Reward 57.00
# Seed 4 | Episode 887 | Reward 37.00
# Seed 4 | Episode 888 | Reward 59.00
# Seed 4 | Episode 889 | Reward 51.00
# Seed 4 | Episode 890 | Reward 58.00
# Seed 4 | Episode 891 | Reward 53.00
# Seed 4 | Episode 892 | Reward 46.00
# Seed 4 | Episode 893 | Reward 53.00
# Seed 4 | Episode 894 | Reward 43.00
# Seed 4 | Episode 895 | Reward 42.00
# Seed 4 | Episode 896 | Reward 52.00
# Seed 4 | Episode 897 | Reward 46.00
# Seed 4 | Episode 898 | Reward 62.00
# Seed 4 | Episode 899 | Reward 64.00
# Seed 4 | Episode 900 | Reward 60.00
# Seed 4 | Episode 901 | Reward 47.00
# Seed 4 | Episode 902 | Reward 49.00
# Seed 4 | Episode 903 | Reward 52.00
# Seed 4 | Episode 904 | Reward 53.00
# Seed 4 | Episode 905 | Reward 50.00
# Seed 4 | Episode 906 | Reward 56.00
# Seed 4 | Episode 907 | Reward 54.00
# Seed 4 | Episode 908 | Reward 41.00
# Seed 4 | Episode 909 | Reward 56.00
# Seed 4 | Episode 910 | Reward 52.00
# Seed 4 | Episode 911 | Reward 60.00
# Seed 4 | Episode 912 | Reward 61.00
# Seed 4 | Episode 913 | Reward 60.00
# Seed 4 | Episode 914 | Reward 57.00
# Seed 4 | Episode 915 | Reward 49.00
# Seed 4 | Episode 916 | Reward 59.00
# Seed 4 | Episode 917 | Reward 59.00
# Seed 4 | Episode 918 | Reward 55.00
# Seed 4 | Episode 919 | Reward 48.00
# Seed 4 | Episode 920 | Reward 37.00
# Seed 4 | Episode 921 | Reward 40.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 49
#      46 total_reward = 0
#      48 for t in range(max_steps_per_episode):
# ---> 49     action = agent.agent_policy(state)
#      50     next_state, reward, done, info = env.step(action)
#      51     agent.remember(state, action, reward, next_state, done)
#
# Cell In[4], line 38, in DQNAgent.agent_policy(self, state)
#      36 if np.random.rand() < self.epsilon:
#      37     return np.random.randint(self.action_dim) # rand action
# ---> 38 state = torch.FloatTensor(state).unsqueeze(0).to(self.device) # convert state to tensor, then add batch dimension, then move to device
#      39 with torch.no_grad(): # dont calculate gradients, no need
#      40     q_values = self.q_nn(state)
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# save the rewards so can be loaded later instead of re training
torch.save(
    {
        "rewards": torch.tensor(all_rewards, dtype=torch.float32),
    },
    r"C:\Users\otten\Desktop\CMPUT655-Project\data\dqn_reward_seeds_0to250.pt"
)

num_seeds = all_rewards.shape[0]

# Compute mean and std across seeds
mean_rewards = np.mean(all_rewards, axis=0)
std_rewards = np.std(all_rewards, axis=0)

# 90% confidence interval
ci_90 = 1.645 * (std_rewards / np.sqrt(num_seeds))

plt.figure(figsize=(12,6))
sns.lineplot(x=np.arange(1, num_episodes+1), y=mean_rewards, label="Mean Reward")
plt.fill_between(np.arange(1, num_episodes+1), mean_rewards - ci_90, mean_rewards + ci_90,
                 alpha=0.3, color="blue", label="90% CI")
plt.title("DQN Training Rewards (Aggregated Across Seeds 0-19) - 90% CI")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.show()

# 95% confidence interval
ci_95 = 1.96 * (std_rewards / np.sqrt(num_seeds))

plt.figure(figsize=(14, 6))

sns.lineplot(
    x=np.arange(1, len(episode_rewards) + 1),
    y=episode_rewards,
    label="QRC Episode Reward",
    color="red"
)

plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('QRC Training on TruckBackerEnv_D')
plt.grid(True)
plt.legend()
plt.savefig('QRC_Discrete_TruckBackerEnv_D.png', dpi=300, bbox_inches='tight')
plt.show()
