# %%
import numpy as np
import matplotlib.pyplot as plt
import os, shutil
from tqdm import tqdm
from rl_glue import RLGlue

import torch
import torch.nn as nn
import torch.optim as optim
import random

from collections import deque

from tbu_gym.tbu_discrete import TruckBackerEnv_D

# %% [markdown]
# # Simplified QRC

# %%
import random
from collections import deque
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

class QRCAgent:
    def __init__(
        self,
        state_dim,
        action_dim,
        lr=1e-3,
        gamma=0.99,
        lam=0.9,                # kept for API compatibility (not used here)
        epsilon=1.0,
        epsilon_decay=0.995,
        min_epsilon=0.01,
        buffer_size=50000,
        batch_size=64,
        beta=1.0,               # regularization strength for h (matches JAX self.beta)
        device=None,
    ):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.lr = lr
        self.gamma = gamma
        self.lam = lam
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.min_epsilon = min_epsilon
        self.batch_size = batch_size
        self.beta = beta

        # Replay memory
        self.memory = deque(maxlen=buffer_size)

        # Device
        self.device = device or (torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu"))

        # Networks
        self.q_net = self.build_nn(output_dim=self.action_dim).to(self.device)
        self.target_net = self.build_nn(output_dim=self.action_dim).to(self.device)
        self.h_net = self.build_nn(output_dim=self.action_dim).to(self.device)

        # init target
        self.target_net.load_state_dict(self.q_net.state_dict())

        # Optimizers
        self.q_optimizer = optim.Adam(self.q_net.parameters(), lr=self.lr)
        self.h_optimizer = optim.Adam(self.h_net.parameters(), lr=self.lr)

        # Steps counter
        self.steps = 0

    def build_nn(self, output_dim):
        """2 hidden layers with 128 neurons each"""
        return nn.Sequential(
            nn.Linear(self.state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, output_dim)
        )

    def agent_policy(self, state):
        """Epsilon-greedy policy returning an int action"""
        if np.random.rand() < self.epsilon:
            return int(np.random.randint(self.action_dim))
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.q_net(state)
        return int(q_values.argmax(dim=1).item())

    def remember(self, state, action, reward, next_state, done):
        """Store transition tuple"""
        self.memory.append((state, action, reward, next_state, done))

    def train_with_mem(self):
        """Train using experience replay. Returns total loss (q_loss + h_loss) for logging."""
        if len(self.memory) < self.batch_size:
            return 0.0

        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.tensor(np.stack(states), dtype=torch.float32).to(self.device)         # (B, state_dim)
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)     # (B,1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)  # (B,1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)      # (B,1)

        # Current Q for taken actions (B,1)
        q_all = self.q_net(states)                                  # (B, A)
        q_values = q_all.gather(1, actions)                         # (B,1)

        # h-values for taken actions (B,1)
        h_all = self.h_net(states)
        h_values = h_all.gather(1, actions)                         # (B,1)

        # Next-state greedy value (use target_net), detach it
        with torch.no_grad():
            next_q_all = self.target_net(next_states)               # (B,A)
            # greedy next action value: max_a Q'(s', a)
            vtp1 = next_q_all.max(dim=1, keepdim=True)[0]          # (B,1)
            vtp1 = vtp1.detach()

            # Q target (standard Q-learning greedy target)
            target = rewards + self.gamma * vtp1 * (1.0 - dones)   # (B,1)
            target = target.detach()

        # TD error (not detached yet)
        delta = target - q_values                                   # (B,1)

        # Build v_loss and h_loss per-sample exactly like JAX:
        # v_loss_i = 0.5 * delta^2 + gamma * stop_gradient(delta_hat) * vtp1
        # h_loss_i = 0.5 * (stop_gradient(delta) - delta_hat)^2
        v_loss_terms = 0.5 * (delta ** 2) + self.gamma * h_values.detach() * vtp1
        h_loss_terms = 0.5 * (delta.detach() - h_values) ** 2

        v_loss = v_loss_terms.mean()
        h_loss = h_loss_terms.mean()

        # --- Update Q-network (q_net) ---
        self.q_optimizer.zero_grad()
        v_loss.backward(retain_graph=True)   # retain_graph because h_loss backward next might need graph if shared (here nets separate so optional)
        self.q_optimizer.step()

        # --- Update h-network (h_net) ---
        self.h_optimizer.zero_grad()
        h_loss.backward()
        self.h_optimizer.step()

        # --- Apply explicit decay / regularization on h parameters (beta term) ---
        # This approximates: params_h <- params_h - stepsize * beta * params_h
        # i.e. multiplicative shrinkage: p *= (1 - lr * beta)
        if self.beta != 0.0:
            decay_factor = 1.0 - (self.lr * self.beta)
            # clamp decay_factor to a sensible positive number
            decay_factor = max(decay_factor, 0.0)
            with torch.no_grad():
                for p in self.h_net.parameters():
                    p.mul_(decay_factor)

        # Decay epsilon
        if self.epsilon > self.min_epsilon:
            self.epsilon *= self.epsilon_decay
            if self.epsilon < self.min_epsilon:
                self.epsilon = self.min_epsilon

        total_loss = v_loss.item() + h_loss.item()
        return total_loss

    def update_target(self):
        """Hard update target network weights from q_net"""
        self.target_net.load_state_dict(self.q_net.state_dict())

# %% [markdown]
# # QRC with tracing

# %%
import torch
import torch.nn as nn
import numpy as np
from collections import deque
import random

def build_mlp(state_dim, output_dim, hidden=128):
    """Simple 2-layer MLP."""
    return nn.Sequential(
        nn.Linear(state_dim, hidden),
        nn.ReLU(),
        nn.Linear(hidden, hidden),
        nn.ReLU(),
        nn.Linear(hidden, output_dim)
    )

class QRCTraceAgent:
    def __init__(
        self,
        state_dim,
        action_dim,
        alpha_q=1e-3,
        alpha_h=1e-3,
        gamma=0.99,
        lam=0.9,
        epsilon=1.0,
        epsilon_decay=0.995,
        min_epsilon=0.01,
        tau=0.005,         # for soft update
        hard_update_interval=100,  # every N steps if using hard update
        device=None
    ):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.gamma = gamma
        self.lam = lam
        self.alpha_q = alpha_q
        self.alpha_h = alpha_h
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.min_epsilon = min_epsilon
        self.tau = tau
        self.hard_update_interval = hard_update_interval

        self.device = device or (torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu"))

        # networks
        self.q_net = build_mlp(state_dim, action_dim).to(self.device)
        self.h_net = build_mlp(state_dim, action_dim).to(self.device)

        # target network for Q
        self.target_q_net = build_mlp(state_dim, action_dim).to(self.device)
        self.target_q_net.load_state_dict(self.q_net.state_dict())

        # traces for q_net and h_net
        self.z_w = [torch.zeros_like(p.data, device=self.device) for p in self.q_net.parameters()]
        self.z_h = [torch.zeros_like(p.data, device=self.device) for p in self.h_net.parameters()]

        self.update_step_count = 0  # for hard update scheduling

    def agent_policy(self, state):
        """Epsilon-greedy action selection."""
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.action_dim)
        s = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            qvals = self.q_net(s)
        return int(qvals.argmax().item())

    def reset_traces(self):
        """Reset traces (on episode end or non-greedy action)."""
        with torch.no_grad():
            for z in self.z_w:
                z.zero_()
            for z in self.z_h:
                z.zero_()

    def step_update(self, state, action, reward, next_state, done, action_was_greedy):
        """Perform one-step QRC update with eligibility traces."""
        self.q_net.train()
        self.h_net.train()

        s = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        sp = torch.FloatTensor(next_state).unsqueeze(0).to(self.device)
        r_t = torch.tensor(float(reward), device=self.device)

        # ---- compute TD error ----
        q_s = self.q_net(s)[0, action]
        with torch.no_grad():
            q_sp_all = self.target_q_net(sp)
            vtp1 = q_sp_all.max(dim=1)[0][0]
        delta = r_t + self.gamma * vtp1 - q_s

        # ---- grads for Q-network ----
        grads_w = torch.autograd.grad(delta, self.q_net.parameters(), retain_graph=True, allow_unused=True)
        grads_w = [g if g is not None else torch.zeros_like(p) for g, p in zip(grads_w, self.q_net.parameters())]

        # ---- grads for H-network ----
        h_s_a = self.h_net(s)[0, action]
        h_loss = 0.5 * (delta.detach() - h_s_a) ** 2
        grads_h = torch.autograd.grad(h_loss, self.h_net.parameters(), retain_graph=False, allow_unused=True)
        grads_h = [g if g is not None else torch.zeros_like(p) for g, p in zip(grads_h, self.h_net.parameters())]

        # ---- update traces ----
        with torch.no_grad():
            for i, g in enumerate(grads_w):
                self.z_w[i].mul_(self.gamma * self.lam).add_(g)
            for i, g in enumerate(grads_h):
                self.z_h[i].mul_(self.gamma * self.lam).add_(g)

        # ---- parameter updates ----
        with torch.no_grad():
            for p, z in zip(self.q_net.parameters(), self.z_w):
                p.add_(self.alpha_q * z)
            for p, z in zip(self.h_net.parameters(), self.z_h):
                p.add_(self.alpha_h * z)

        # ---- trace reset condition ----
        if done or (not action_was_greedy):
            self.reset_traces()

        # ---- epsilon decay ----
        self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)

        # ---- target network update ----
        self.update_target(hard=False)  # set to True for hard updates

        self.update_step_count += 1
        return delta.item()

    def update_target(self, hard=False):
        """Update target Q-network (either hard or soft)."""
        with torch.no_grad():
            if hard:
                if self.update_step_count % self.hard_update_interval == 0:
                    self.target_q_net.load_state_dict(self.q_net.state_dict())
            else:
                # soft update (Polyak averaging)
                for param, target_param in zip(self.q_net.parameters(), self.target_q_net.parameters()):
                    target_param.data.mul_(1 - self.tau)
                    target_param.data.add_(self.tau * param.data)

    # ==================== MEMORY ====================
    def remember(self, state, action, reward, next_state, done):
        """Store transition in replay memory."""
        self.memory.append((state, action, reward, next_state, done))

    # ==================== TRAIN FROM MEMORY ====================
    def train_with_mem(self):
        """Train using random batch from replay memory."""
        if len(self.memory) < self.batch_size:
            return 0.0  # not enough samples yet

        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors
        states = torch.tensor(np.stack(states), dtype=torch.float32).to(self.device)
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.long).unsqueeze(1).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1).to(self.device)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(1).to(self.device)

        # Q(s, a)
        q_values = self.q_net(states).gather(1, actions)

        # target = r + γ * max_a' Q'(s', a') * (1 - done)
        with torch.no_grad():
            next_q = self.target_q_net(next_states).max(1, keepdim=True)[0]
            target = rewards + self.gamma * next_q * (1 - dones)

        errors = target - q_values
        loss = (errors ** 2).mean()

        # Update Q network
        self.q_net.zero_grad()
        loss.backward()
        for p in self.q_net.parameters():
            p.data.add_(self.alpha_q * p.grad)

        # Soft target update
        self.update_target(hard=False)

        # Epsilon decay
        self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)

        return loss.item()

# %%
# --- 1. Hyperparameters ---

num_episodes = 1000
max_steps_per_episode = 500
gamma = 0.99
learning_rate = 1e-3
epsilon_start = 1.0
epsilon_decay = 0.99997
epsilon_min = 0.01
batch_size = 64
target_update_freq = 5  # Update target net every few episodes

# QRC Specific Parameters
alpha = 1.0
sigma_min = 0.0
sigma_max = 1.0

# %%
# --- 2. Environment Setup ---
env = TruckBackerEnv_D(render_mode=None)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

# --- 3. Agent Initialization ---
agent = QRCAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    lr=learning_rate,
    gamma=gamma,
    epsilon=epsilon_start,
    epsilon_decay=epsilon_decay,
    min_epsilon=epsilon_min,
    batch_size=batch_size
)

# --- 4. Training Loop ---
episode_rewards = []
recent_loss = 0.0

for episode in range(1, num_episodes + 1):
    reset_output = env.reset()
    if isinstance(reset_output, tuple):
        state, _ = reset_output
    else:
        state = reset_output

    total_reward = 0

    for t in range(max_steps_per_episode):
        # Select action
        action = agent.agent_policy(state)

        # Step environment (compatible with Gym / Gymnasium)
        # break
        step_result = env.step(action)
        if len(step_result) == 5:
            next_state, reward, terminated, truncated, _ = step_result
            done = terminated or truncated
        else:
            next_state, reward, done, _ = step_result

        total_reward += reward

        # Store transition and train
        agent.remember(state, action, reward, next_state, done)
        loss = agent.train_with_mem()
        if loss != 0.0:
            recent_loss = loss

        state = next_state
        if done:
            break

    # Update target network every few episodes
    if episode % target_update_freq == 0:
        agent.update_target()

    # Record and print progress
    episode_rewards.append(total_reward)
    print(f"Episode {episode:4d}/{num_episodes}, Reward: {total_reward:7.2f}, "
          f"Epsilon: {agent.epsilon:.5f}, Loss: {recent_loss:.5f}")

# --- 5. Plotting Results ---
plt.figure(figsize=(14, 6))
plt.plot(episode_rewards, label="QRC Episode Reward")
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('QRC Training on TruckBackerEnv_D')
plt.legend()
plt.grid(True)
plt.savefig('QRC_Discrete_TruckBackerEnv_D.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# action  2
# Episode    1/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode    2/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode    3/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode    4/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode    5/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode    6/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode    7/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode    8/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode    9/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   10/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   11/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   12/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   13/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   14/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   15/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   16/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   17/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   18/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   19/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   20/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   21/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   22/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   23/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   24/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   25/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   26/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   27/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   28/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   29/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   30/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   31/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   32/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   33/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   34/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   35/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   36/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   37/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   38/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   39/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   40/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   41/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   42/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   43/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   44/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   45/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   46/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   47/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   48/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   49/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   50/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   51/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   52/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   53/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   54/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   55/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   56/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   57/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   58/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   59/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   60/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   61/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   62/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   63/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   64/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  0
# Episode   65/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   66/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   67/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   68/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  2
# Episode   69/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Episode   70/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   71/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   72/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   73/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  4
# Episode   74/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  3
# Episode   75/1000, Reward:    0.00, Epsilon: 1.00000, Loss: 0.00000
# action  1
# Epis
png', dpi=300, bbox_inches='tight')

plt.show()

# %%
window = 50
smoothed = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')

# Plotting Results
plt.figure(figsize=(10, 6))
# plt.plot(episode_rewards)
plt.plot(smoothed)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('QRC Training on TruckBackerEnv_D')
plt.grid(True)

# Save the plot to a file
plt.savefig('QRC_Discrete_TruckBackerEnv_D.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# replay_wrapper.py

import random
from collections import deque
import numpy as np


class ReplayWrapper:
    def __init__(self, agent, buffer_size=50000, batch_size=64):
        self.agent = agent
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size

    def remember(self, s, a, r, sp, done):
        """Store one transition."""
        self.memory.append((s, a, r, sp, done))

    def sample_and_train(self):
        """Randomly sample a mini-batch and train agent."""
        if len(self.memory) < self.batch_size:
            return 0.0

        batch = random.sample(self.memory, self.batch_size)
        td_errors = []

        for s, a, r, sp, done in batch:
            td_error = self.agent.step_update(s, a, r, sp, done)
            td_errors.append(abs(td_error))

        return np.mean(td_errors)

# %%
# --- 2. Environment Setup ---
env = TruckBackerEnv_D(render_mode=None)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

# --- 3. Agent Initialization ---
agent = QRCTraceAgent(
    state_dim=state_dim,
    action_dim=action_dim,
    gamma=gamma,
    epsilon=epsilon_start,
    epsilon_decay=epsilon_decay,
    min_epsilon=epsilon_min,
)

# --- 4. Training Loop ---
episode_rewards = []
recent_loss = 0.0


for episode in range(1, num_episodes + 1):
    reset_output = env.reset()
    if isinstance(reset_output, tuple):
        state, _ = reset_output
    else:
        state = reset_output

    total_reward = 0

    for t in range(max_steps_per_episode):
        # Select action
        action = agent.agent_policy(state)

        # Step environment (compatible with Gym / Gymnasium)
        # break
        step_result = env.step(action)
        if len(step_result) == 5:
            next_state, reward, terminated, truncated, _ = step_result
            done = terminated or truncated
        else:
            next_state, reward, done, _ = step_result

        total_reward += reward

        # Store transition and train
        agent.remember(state, action, reward, next_state, done)
        loss = agent.train_with_mem()
        if loss != 0.0:
            recent_loss = loss

        state = next_state
        if done:
            break

    # Update target network every few episodes
    if episode % target_update_freq == 0:
        agent.update_target()

    # Record and print progress
    episode_rewards.append(total_reward)
    print(f"Episode {episode:4d}/{num_episodes}, Reward: {total_reward:7.2f}, "
          f"Epsilon: {agent.epsilon:.5f}, Loss: {recent_loss:.5f}")

# --- 5. Plotting Results ---
plt.figure(figsize=(14, 6))
plt.plot(episode_rewards, label="QRC Episode Reward")
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('QRC Training on TruckBackerEnv_D')
plt.legend()
plt.grid(True)
plt.savefig('QRC_Discrete_TruckBackerEnv_D.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 36
#      32 action = agent.agent_policy(state)
#      34 # Step environment (compatible with Gym / Gymnasium)
#      35 # break
# ---> 36 step_result = env.step(action)
#      37 if len(step_result) == 5:
#      38     next_state, reward, terminated, truncated, _ = step_result
#
# File ~/Desktop/University of Alberta/RL/Project - DQN vs QRC/CMPUT655-Project/DQN and QRC/tbu_gym/tbu_discrete.py:73, in TruckBackerEnv_D.step(self, action)
#      71 def step(self, action):
#      72     # Adding a step to the counter
# ---> 73     action = action/2 - 1
#      74     self.step_counter += 1
#      75     self.had_recent_stochastic = False
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'int'

# %%
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

print("state_dim =", state_dim)
print("action_dim =", action_dim)
# Out:
# state_dim = 4
# action_dim = 5
